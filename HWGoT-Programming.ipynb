# %% [markdown]
# <style  type="text/css">
# cool {
#   width: 100px;
#   height: 100px;
#   background-color: red;
#   position: relative;
#   -webkit-animation-name: example; /* Safari 4.0 - 8.0 */
#   -webkit-animation-duration: 4s; /* Safari 4.0 - 8.0 */
#   -webkit-animation-iteration-count: infinite; /* Safari 4.0 - 8.0 */
#   animation-name: example;
#   animation-duration: 4s;
#   animation-iteration-count: infinite;
# }
#
# /* Safari 4.0 - 8.0 */
# @-webkit-keyframes example {
#   0%   {background-color:red; left:0px; top:0px;}
#   25%  {background-color:yellow; left:200px; top:0px;}
#   50%  {background-color:blue; left:200px; top:200px;}
#   75%  {background-color:green; left:0px; top:200px;}
#   100% {background-color:red; left:0px; top:0px;}
# }
#
# /* Standard syntax */
# @keyframes example {
#   0%   {background-color:red; left:0px; top:0px;}
#   25%  {background-color:yellow; left:200px; top:0px;}
#   50%  {background-color:blue; left:200px; top:200px;}
#   75%  {background-color:green; left:0px; top:200px;}
#   100% {background-color:red; left:0px; top:0px;}
# }
# </style>
#
# <b><center>
# <span style="font-size: 24pt; line-height: 1.2">
# COMS W4111: Introduction to Databases<br>
# Spring 2020, Sections 002, H02, V02
# </span>
# </center></b>
# </span><br>
# <p>
# <i><center>
# <span style="font-size: 20pt; line-height: 1.2">
# Programming Project Notebook<br>
# </span>
# </center></i>

# %% [markdown]
# # Introduction
#
# - This notebook defines HW1, Part C for the programming track.
#
#
# - Submission instructions:
#     - Submit a zip file containing all of the files in the HW project directory that you clone (see below).
#     - Much of your work is completing sections of this notebook, but you MUST edit the copy in the project directory.
#     - If you reference or create any files, please create in the project directory.
#     - The name of your zip file MUST be ```uni_W4111_s20_hw1c,```  replace ```uni``` with you UNI. My submission would be ```dff9_W4111_s20_hw1c.```
#     - The homework is due on 23-February-2020 at 11:59 PM. You MAY use late days.
#
# - We will use the pinned [Piazza post](https://piazza.com/class/k5grpo7gmn71pj?cid=301) to clarify the homework and answer questions.
#
#
# # Common Setup
#
# Both tracks should:
# - MySQL: Install
#     - [MySQL Server Community Edition](https://dev.mysql.com/doc/mysql-installation-excerpt/8.0/en/)
#     - [MySQL Workbench](https://dev.mysql.com/doc/workbench/en/)
#     - In addition to the official links, there are many operating specific tutorials.
#
#
# - Create a [Lucidchart educational account.](https://lucidchart.zendesk.com/hc/en-us/articles/207324096-Get-Started-with-an-Educational-Account)
#
#
# - Project template:
#     - If you do not have ```Git``` on your computer, please install it.
#     - Homework 1 setup instructions recommended that you create a folder ```/IntroToDB``` on your desktop.
#     - Under this directory, create a folder ```HW1C.```
#     - Open terminal shell or Git enabled command prompt.
#     - CD to the directory you created and enter ```git clone https://github.com/donald-f-ferguson/GoTHW```
#     - This will create the project template for you.
#
# | <img src="./got_hw_project.png"> |
# | :---: |
# | __HW1C Project Template__ |

# %% [markdown]
# - Run the following cells. Your answers WILL BE different than the sample output.

# %%
import sys
import os
import platform
import psutil

print("="*40, "Path Information", "="*40)
print("Path = ", os.getcwd())

print("="*40, "System Information", "="*40)
uname = platform.uname()
print(f"System: {uname.system}")
print(f"Node Name: {uname.node}")
print(f"Release: {uname.release}")
print(f"Version: {uname.version}")
print(f"Machine: {uname.machine}")
print(f"Processor: {uname.processor}")

print("="*40, "Network Information", "="*40)

import socket    
hostname = socket.gethostname()    
IPAddr = socket.gethostbyname(hostname)    
print("Your Computer Name is:" + hostname)    
print("Your Computer IP Address is:" + IPAddr) 

import uuid
print ("Your MAC address is:", hex(uuid.getnode()))
# Out:
# ======================================== Path Information ========================================
# Path =  /Users/kelanox/Desktop
# ======================================== System Information ========================================
# System: Darwin
# Node Name: dyn-160-39-195-169.dyn.columbia.edu
# Release: 19.0.0
# Version: Darwin Kernel Version 19.0.0: Thu Oct 17 16:17:15 PDT 2019; root:xnu-6153.41.3~29/RELEASE_X86_64
# Machine: x86_64
# Processor: i386
# ======================================== Network Information ========================================
# Your Computer Name is:dyn-160-39-195-169.dyn.columbia.edu
# Your Computer IP Address is:160.39.195.169
# Your MAC address is: 0xacde48001122

# %% [markdown]
# # Programming
#
# ## Overview
#
# - Ensuring that programming track students build core skills is essential. Programming track assignments will contain a subset of the broader, more complete tasks assigned in the No programming assignments. So, there is a common core section to the programming track homework.
#
#
# - Additionally, the programming track will have tasks that reinforce skills necessary for programming and databases.
#
#
# ## Tasks
#
# - Data Import: Import the tables in the Data/csv folder
#
#
# - Data Cleanup: Clean up the imported tables
#
#
# - Schema Improvement: For the following tables, perform the schema improvement tasks
#     1. ```characters```
#     2. ```scenes```
#     3. ```scenes_characters```
#
#
# - Views: Create the following views
#     1. Implement the view "Character Interactions."
#     2. Define, explain and implement a view of you choosing.
#
#
# - Programming Section: Complete the implementation for the BaseDataTable and RDBDataTable classes

# %% [markdown]
# ## Task 1: Initial Data Import
#
# ### Task
#
# - The folder in the project ```Data/csv``` contains several CSV files:
#     - ```'character_relationships.csv```
#     - ```characters.csv```
#     - ```characters_actors.csv```
#     - ```episodes.csv```
#     - ```locations.csv```
#     - ```scenes.csv```
#     - ```scenes_characters.csv```
#
#
# - Use MySQL Workbench:
#     - Create a new schema ```W4111GoTSolution``` and set as the default schema.
#     - Use the MySQL [Workbench Table Data Import Wizard](https://dev.mysql.com/doc/workbench/en/wb-admin-export-import-table.html) and import each of the files. Choose the option to create a new table.

# %% [markdown]
# ### Tests

# %%
# %load_ext sql
# %sql mysql+pymysql://dbuser:dbuserdbuser@localhost/W4111GoTSolution
# Out:
# 'Connected: dbuser@W4111GoTSolution'

# %% [markdown]
# ```1.``` Find all the characters with last name ```Stark.```

# %%
# %sql select * from characters where characterName like("% Stark")
# Out:
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
# 14 rows affected.
# [(15, 'Arya Stark', '/character/ch0158604/', 'Maisie Williams', '/name/nm3586035/', 'CH_15', '', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTk5MTYwNDc0OF5BMl5BanBnXkFtZTcwOTg2NDg1Nw@@._V1._SX100_SY140_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTk5MTYwNDc0OF5BMl5BanBnXkFtZTcwOTg2NDg1Nw@@._V1_SY1000_CR0,0,665,1000_AL_.jpg', '', ''),
#  (20, 'Benjen Stark', '/character/ch0153996/', 'Joseph Mawle', '/name/nm1152798/', 'CH_20', '', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjFiY2M5MjgtZmRiMS00ZTAyLTk2Y2UtMjdjZTRkZmVlYTMyXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjFiY2M5MjgtZmRiMS00ZTAyLTk2Y2UtMjdjZTRkZmVlYTMyXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', '', ''),
#  (28, 'Brandon Stark', '', '', '', 'CH_28', '', '', '', '', ''),
#  (29, 'Bran Stark', '/character/ch0234897/', 'Isaac Hempstead Wright', '/name/nm3652842/', 'CH_29', 'True', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTA1NTg0NTI3MTBeQTJeQWpwZ15BbWU3MDEyNjg4OTQ@._V1._SX100_SY140_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTA1NTg0NTI3MTBeQTJeQWpwZ15BbWU3MDEyNjg4OTQ@._V1_SX1500_CR0,0,1500,999_AL_.jpg', '', ''),
#  (36, 'Catelyn Stark', '/character/ch0145135/', 'Michelle Fairley', '/name/nm0265610/', 'CH_36', '', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTY2ODc4MTkxMV5BMl5BanBnXkFtZTcwNjM3MTg4OQ@@._V1._SX100_SY140_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTY2ODc4MTkxMV5BMl5BanBnXkFtZTcwNjM3MTg4OQ@@._V1_SY1000_CR0,0,915,1000_AL_.jpg', '', ''),
#  (59, 'Eddard Stark', '/character/ch0154681/', 'Sean Bean', '/name/nm0000293/', 'CH_59', '', 'https://images-na.ssl-images-amazon.com/images/M/MV5BODcwMjg0MDQ5MF5BMl5BanBnXkFtZTcwMTk2NDk4OQ@@._V1._SX100_SY140_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BODcwMjg0MDQ5MF5BMl5BanBnXkFtZTcwMTk2NDk4OQ@@._V1_SY1000_CR0,0,827,1000_AL_.jpg', 'Ned', ''),
#  (183, 'Lyanna Stark', '/character/ch0543804/', 'Aisling Franciosi', '/name/nm4957233/', 'CH_183', '', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTE5NTczY2QtNmQxYS00NTAwLWE2ZTAtYzc1MTkyZGU5MzRkL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMTE5NTczY2QtNmQxYS00NTAwLWE2ZTAtYzc1MTkyZGU5MzRkL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', '', ''),
#  (284, 'Rickard Stark', '', '', '', 'CH_284', '', '', '', '', ''),
#  (285, 'Rickon Stark', '/character/ch0233141/', 'Art Parkinson', '/name/nm3280686/', 'CH_285', '', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMWZiOGNjMDAtOTRlNi00MDJmLWEyMTMtOGEwZTM5ODJlNDAyXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1._SX100_SY140_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMWZiOGNjMDAtOTRlNi00MDJmLWEyMTMtOGEwZTM5ODJlNDAyXkEyXkFqcGdeQXVyMjk3NTUyOTc@._V1_.jpg', '', ''),
#  (286, 'Robb Stark', '/character/ch0158596/', 'Richard Madden', '/name/nm0534635/', 'CH_286', 'True', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjI2NDE1NzczNF5BMl5BanBnXkFtZTcwNjcwODg4OQ@@._V1._SX100_SY140_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BMjI2NDE1NzczNF5BMl5BanBnXkFtZTcwNjcwODg4OQ@@._V1_SY1000_CR0,0,845,1000_AL_.jpg', '', ''),
#  (300, 'Sansa Stark', '/character/ch0158137/', 'Sophie Turner', '/name/nm3849842/', 'CH_300', 'True', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNjAwMjE2NDExNF5BMl5BanBnXkFtZTcwODAwODg4OQ@@._V1._SX100_SY140_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNjAwMjE2NDExNF5BMl5BanBnXkFtZTcwODAwODg4OQ@@._V1_SY1000_CR0,0,806,1000_AL_.jpg', '', ''),
#  (381, 'Young Benjen Stark', '/character/ch0153996/', 'Matteo Elezi', '/name/nm5502295/', 'CH_381', '', '', '', '', ''),
#  (383, 'Young Lyanna Stark', '/character/ch0543804/', 'Cordelia Hill', '/name/nm8108764/', 'CH_383', '', '', '', '', ''),
#  (386, 'Young Ned Stark', '/character/ch0154681/', 'Sebastian Croft', '/name/nm7509185/', 'CH_386', '', '', '', '', '')]

# %% [markdown]
# ```2.``` Find all of the information about scenes in season 1, episode 1.

# %%
# %sql select * from scenes where episodeNum=1 and seasonNum=1
# Out:
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
# 36 rows affected.
# [(0, 1, 1, 1, '0:00:40', '0:01:45', 'The Wall', 'Castle Black', '', '', '', ''),
#  (1, 1, 1, 2, '0:01:45', '0:03:24', 'North of the Wall', 'The Haunted Forest', '', '', '', ''),
#  (2, 1, 1, 3, '0:03:24', '0:03:31', 'North of the Wall', 'The Haunted Forest', '', '', '', ''),
#  (3, 1, 1, 4, '0:03:31', '0:03:38', 'North of the Wall', 'The Haunted Forest', '', '', '', ''),
#  (4, 1, 1, 5, '0:03:38', '0:03:44', 'North of the Wall', 'The Haunted Forest', '', '', '', ''),
#  (5, 1, 1, 6, '0:03:44', '0:05:36', 'North of the Wall', 'The Haunted Forest', '', '', '', ''),
#  (6, 1, 1, 7, '0:05:36', '0:05:41', 'North of the Wall', 'The Haunted Forest', '', '', '', ''),
#  (7, 1, 1, 8, '0:05:41', '0:05:48', 'North of the Wall', 'The Haunted Forest', '', '', '', ''),
#  (8, 1, 1, 9, '0:05:48', '0:05:58', 'North of the Wall', 'The Haunted Forest', '', '', '', ''),
#  (9, 1, 1, 10, '0:05:58', '0:06:21', 'North of the Wall', 'The Haunted Forest', '', '', '', ''),
#  (10, 1, 1, 11, '0:06:21', '0:06:39', 'North of the Wall', 'The Haunted Forest', '', '', '', ''),
#  (11, 1, 1, 12, '0:06:39', '0:06:49', 'North of the Wall', 'The Haunted Forest', '', '', '', ''),
#  (12, 1, 1, 13, '0:06:49', '0:07:45', 'North of the Wall', 'The Haunted Forest', '', '', '', ''),
#  (13, 1, 1, 14, '0:09:27', '0:12:38', 'The North', 'Winterfell', '', '', '', ''),
#  (14, 1, 1, 15, '0:12:38', '0:15:41', 'The North', 'Outside Winterfell', '', '', '', ''),
#  (15, 1, 1, 16, '0:15:41', '0:18:44', 'The North', 'Outside Winterfell', '', '', '', ''),
#  (16, 1, 1, 17, '0:18:44', '0:20:45', 'The Crownlands', "King's Landing", '', '', '', ''),
#  (17, 1, 1, 18, '0:20:45', '0:22:43', 'The North', 'Winterfell', '', '', '', ''),
#  (18, 1, 1, 19, '0:22:43', '0:23:09', 'The North', 'Winterfell', '', '', '', ''),
#  (19, 1, 1, 20, '0:23:09', '0:23:39', 'The North', 'Winterfell', '', '', '', ''),
#  (20, 1, 1, 21, '0:23:39', '0:29:16', 'The North', 'Winterfell', '', '', '', ''),
#  (21, 1, 1, 22, '0:29:16', '0:30:47', 'The North', 'Winterfell', '', '', '', ''),
#  (22, 1, 1, 23, '0:30:47', '0:32:57', 'The North', 'Winterfell', '', '', '', ''),
#  (23, 1, 1, 24, '0:32:57', '0:33:45', 'The North', 'Winterfell', '', '', '', ''),
#  (24, 1, 1, 25, '0:33:45', '0:36:17', 'Pentos', '', '', '', '', ''),
#  (25, 1, 1, 26, '0:36:17', '0:38:23', 'Pentos', '', '', '', '', ''),
#  (26, 1, 1, 27, '0:38:23', '0:40:05', 'Pentos', '', '', '', '', ''),
#  (27, 1, 1, 28, '0:40:05', '0:40:56', 'The North', 'Winterfell', '', '', '', ''),
#  (28, 1, 1, 29, '0:40:56', '0:41:19', 'The North', 'Winterfell', '', '', '', ''),
#  (29, 1, 1, 30, '0:41:19', '0:44:14', 'The North', 'Winterfell', '', '', '', ''),
#  (30, 1, 1, 31, '0:44:14', '0:47:28', 'The North', 'Winterfell', '', '', '', ''),
#  (31, 1, 1, 32, '0:47:28', '0:50:29', 'The North', 'Winterfell', '', '', '', ''),
#  (32, 1, 1, 33, '0:50:29', '0:56:05', 'Pentos', '', '', '', '', ''),
#  (33, 1, 1, 34, '0:56:05', '0:57:48', 'Pentos', '', '', '', '', ''),
#  (34, 1, 1, 35, '0:57:48', '0:59:06', 'The North', 'Winterfell', '', '', '', ''),
#  (35, 1, 1, 36, '0:59:06', '1:00:57', 'The North', 'Winterfell', '', '', '', '')]

# %% [markdown]
# ```3.``` Find all of the characters and actors who played them.

# %%
# %%sql
# SELECT
#     character_id,
#     (select characterName from characters where characters.character_id=
#          characters_actors.character_id) as characterName,
#     actorName, season
# FROM W4111GoTSolution.characters_actors;
# Out:
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
# 408 rows affected.
# [('CH_0', 'Addam Marbrand', 'B.J. Hogg', ''),
#  ('CH_2', 'Aeron Greyjoy', 'Michael Feast', ''),
#  ('CH_3', 'Aerys II Targaryen', 'David Rintoul', ''),
#  ('CH_4', 'Akho', 'Chuku Modu', ''),
#  ('CH_5', 'Alliser Thorne', 'Owen Teale', ''),
#  ('CH_6', 'Alton Lannister', 'Karl Davies', ''),
#  ('CH_7', 'Alys Karstark', 'Megan Parkinson', ''),
#  ('CH_8', 'Amory Lorch', 'Fintan McKeown', ''),
#  ('CH_9', 'Anguy', 'Philip McGinley', ''),
#  ('CH_10', 'Archmaester Marwyn', 'Jim Broadbent', ''),
#  ('CH_11', 'Areo Hotah', 'Deobia Oparei', ''),
#  ('CH_12', 'Armeca', 'Sahara Knite', ''),
#  ('CH_13', 'Arthur', 'Nathanael Saleh', ''),
#  ('CH_14', 'Arthur Dayne', 'Luke Roberts', ''),
#  ('CH_15', 'Arya Stark', 'Maisie Williams', ''),
#  ('CH_16', 'Baby Sam', 'William Wilson', '7.0'),
#  ('CH_16', 'Baby Sam', 'James Wilson', '7.0'),
#  ('CH_17', 'Balon Greyjoy', 'Patrick Malahide', ''),
#  ('CH_18', 'Baratheon Guard', 'Phil Barnhill', ''),
#  ('CH_19', 'Barristan Selmy', 'Ian McElhinney', ''),
#  ('CH_20', 'Benjen Stark', 'Joseph Mawle', ''),
#  ('CH_21', 'Beric Dondarrion', 'Richard Dormer', '3.0'),
#  ('CH_21', 'Beric Dondarrion', 'Richard Dormer', '6.0'),
#  ('CH_21', 'Beric Dondarrion', 'Richard Dormer', '7.0'),
#  ('CH_21', 'Beric Dondarrion', 'Richard Dormer', '8.0'),
#  ('CH_21', 'Beric Dondarrion', 'David Michael Scott', '1.0'),
#  ('CH_22', 'Bianca', 'Eline Powell', ''),
#  ('CH_23', 'Biter', 'Gerard Jordan', ''),
#  ('CH_24', 'Black Lorren', 'Forbes KB', ''),
#  ('CH_25', 'Black Walder Rivers', 'Tim Plester', ''),
#  ('CH_26', 'Bobono', 'Leigh Gill', ''),
#  ('CH_27', 'Bowen Marsh', 'Michael Condron', ''),
#  ('CH_29', 'Bran Stark', 'Isaac Hempstead Wright', ''),
#  ('CH_30', 'Brea', 'Gemita Samarra', ''),
#  ('CH_31', 'Brienne of Tarth', 'Gwendoline Christie', ''),
#  ('CH_32', 'Bronn', 'Jerome Flynn', ''),
#  ('CH_33', 'Brother Ray', 'Ian McShane', ''),
#  ('CH_34', 'Brynden Tully', 'Clive Russell', ''),
#  ('CH_35', 'Captain of the Archers', 'Michael Grennell', ''),
#  ('CH_36', 'Catelyn Stark', 'Michelle Fairley', ''),
#  ('CH_37', 'Catspaw Assassin', 'Lalor Roddy', ''),
#  ('CH_38', 'Cersei Lannister', 'Lena Headey', ''),
#  ('CH_39', 'Child of the Forest', 'Alice Hewkin', ''),
#  ('CH_40', 'Citadel Maester', 'Frank Hvam', ''),
#  ('CH_41', 'Colen of Greenpools', 'Darren Killeen', ''),
#  ('CH_42', 'Craster', 'Robert Pugh', ''),
#  ('CH_43', 'Daario Naharis', 'Ed Skrein', '3.0'),
#  ('CH_43', 'Daario Naharis', 'Michiel Huisman', '4.0'),
#  ('CH_43', 'Daario Naharis', 'Michiel Huisman', '5.0'),
#  ('CH_43', 'Daario Naharis', 'Michiel Huisman', '6.0'),
#  ('CH_44', 'Daenerys Targaryen', 'Emilia Clarke', ''),
#  ('CH_45', 'Dagmer Cleftjaw', 'Ralph Ineson', ''),
#  ('CH_46', 'Daisy', 'Maisie Dee', ''),
#  ('CH_47', 'Davos Seaworth', 'Liam Cunningham', ''),
#  ('CH_48', 'Dickon Tarly', 'Freddie Stroma', '6.0'),
#  ('CH_48', 'Dickon Tarly', 'Tom Hopper', '7.0'),
#  ('CH_49', 'Dongo the Giant', 'Ian Whyte', ''),
#  ('CH_50', 'Donnel Waynwood', 'Alisdair Simpson', ''),
#  ('CH_51', 'Dontos Hollard', 'Tony Way', ''),
#  ('CH_52', 'Doran Martell', 'Alexander Siddig', ''),
#  ('CH_53', 'Doreah', 'Roxanne McKee', ''),
#  ('CH_54', 'Dothraki Bloodrider #1', 'Diogo Sales', ''),
#  ('CH_55', 'Dothraki Bloodrider #2', 'Junade Khan', ''),
#  ('CH_56', 'Drennan', 'David Coakley', ''),
#  ('CH_58', 'Drowned Priest', 'Jonathan Ryan', ''),
#  ('CH_59', 'Eddard Stark', 'Sean Bean', ''),
#  ('CH_60', 'Eddison Tollett', 'Ben Crompton', ''),
#  ('CH_61', 'Edmure Tully', 'Tobias Menzies', ''),
#  ('CH_62', 'Ellaria Sand', 'Indira Varma', ''),
#  ('CH_64', 'Eon Hunter', 'Barrington Cullen', ''),
#  ('CH_65', 'Euron Greyjoy', 'Pilou Asbæk', ''),
#  ('CH_66', 'Faceless Man', 'Cedric Henderson', ''),
#  ('CH_67', 'Farlen', 'Peter Ballance', ''),
#  ('CH_68', 'Gared', 'Dermot Keaney', ''),
#  ('CH_69', 'Gatins', 'Ricky Champ', ''),
#  ('CH_70', 'Gendry', 'Joe Dempsie', ''),
#  ('CH_71', 'Gerold Hightower', 'Eddie Eyre', ''),
#  ('CH_73', 'Gilly', 'Hannah Murray', ''),
#  ('CH_74', 'Goldcloak', 'Alan Paris', ''),
#  ('CH_75', 'Goldcloak', 'Sam Callis', ''),
#  ('CH_76', 'Goldcloak #1', 'Nikovich Sammut', ''),
#  ('CH_77', 'Goldcloak #2', 'Seamus Kelly', ''),
#  ('CH_78', 'Grand Maester Pycelle', 'Julian Glover', ''),
#  ('CH_79', 'Great Master #1', 'Emilio Doorgasingh', '4.0'),
#  ('CH_79', 'Great Master #1', 'Gianpiero Cognoli', '5.0'),
#  ('CH_80', 'Great Master #2', 'Derek Horsham', '4.0'),
#  ('CH_80', 'Great Master #2', 'Bobby Asghar', '5.0'),
#  ('CH_81', 'Great Master #3', 'Peter Silverleaf', ''),
#  ('CH_82', 'Great Master #4', 'Davor Jozinovic', ''),
#  ('CH_83', 'Great Master #5', 'Ivan Peric', ''),
#  ('CH_84', 'Great Master #6', 'Hadi Kermani', ''),
#  ('CH_85', 'Great Master #7', 'Tonci Banov', ''),
#  ('CH_86', 'Greatjon Umber', 'Clive Mantle', ''),
#  ('CH_87', 'Gregor Clegane', 'Ian Whyte', '2.0'),
#  ('CH_87', 'Gregor Clegane', 'Conan Stevens', '1.0'),
#  ('CH_87', 'Gregor Clegane', 'Hafþór Júlíus Björnsson', '4.0'),
#  ('CH_87', 'Gregor Clegane', 'Hafþór Júlíus Björnsson', '5.0'),
#  ('CH_87', 'Gregor Clegane', 'Hafþór Júlíus Björnsson', '6.0'),
#  ('CH_87', 'Gregor Clegane', 'Hafþór Júlíus Björnsson', '7.0'),
#  ('CH_87', 'Gregor Clegane', 'Hafþór Júlíus Björnsson', '8.0'),
#  ('CH_88', 'Greizhen mo Ullhor', 'Cliff Barry', ''),
#  ('CH_89', 'Grenn', 'Mark Stanley', ''),
#  ('CH_91', 'Grey Worm', 'Jacob Anderson', ''),
#  ('CH_92', 'Hallyne', 'Roy Dotrice', ''),
#  ('CH_93', 'Handmaid', 'Sabrina Bartlett', ''),
#  ('CH_94', 'Handmaid', 'Sara Dylan', ''),
#  ('CH_95', 'Harald Karstark', 'Paul Rattray', ''),
#  ('CH_96', 'Harry Strickland', 'Marc Rissmann', ''),
#  ('CH_97', 'High Priestess', 'Souad Faress', ''),
#  ('CH_98', 'High Septon', 'David Verrey', ''),
#  ('CH_99', 'High Septon', 'Paul Bentley', ''),
#  ('CH_100', 'High Sparrow', 'Jonathan Pryce', ''),
#  ('CH_101', 'Hizdahr zo Loraq', 'Joel Fry', ''),
#  ('CH_102', 'Hodor', 'Kristian Nairn', ''),
#  ('CH_103', 'Hoster Tully', 'Christopher Newman', ''),
#  ('CH_104', 'Hot Pie', 'Ben Hawkey', ''),
#  ('CH_105', 'Howland Reed', 'Leo Woodruff', ''),
#  ('CH_106', 'Hugh of the Vale', 'Jefferson Hall', ''),
#  ('CH_107', 'Illyrio Mopatis', 'Roger Allam', ''),
#  ('CH_108', 'Ilyn Payne', 'Wilko Johnson', ''),
#  ('CH_109', 'Irri', 'Amrita Acharia', ''),
#  ('CH_110', 'Izembaro', 'Richard E. Grant', ''),
#  ('CH_111', 'Jacks', 'Paul Caddell', ''),
#  ('CH_113', 'Jaime Lannister', 'Nikolaj Coster-Waldau', ''),
#  ('CH_114', 'Janos Slynt', 'Dominic Carter', ''),
#  ('CH_115', "Jaqen H'ghar", 'Tom Wlaschiha', ''),
#  ('CH_116', "Jaqen's Disguise", "Patrick O'Kane", ''),
#  ('CH_117', 'Jaremy Rykker', "Jeffrey O'Brien", ''),
#  ('CH_118', 'Jeor Mormont', 'James Cosmo', ''),
#  ('CH_119', 'Jhiqui', 'Sarita Piotrowski', ''),
#  ('CH_120', 'Joffrey Baratheon', 'Jack Gleeson', ''),
#  ('CH_121', 'Jojen Reed', 'Thomas Brodie-Sangster', ''),
#  ('CH_122', 'Jon Arryn', 'John Standing', ''),
#  ('CH_123', 'Jon Snow', 'Kit Harington', ''),
#  ('CH_124', 'Jonos Bracken', "Gerry O'Brien", ''),
#  ('CH_125', 'Jorah Mormont', 'Iain Glen', ''),
#  ('CH_126', 'Jory Cassel', 'Jamie Sives', ''),
#  ('CH_127', 'Joyeuse Erenford', 'Kelly Long', ''),
#  ('CH_128', 'Karl Tanner', 'Burn Gorman', ''),
#  ('CH_129', 'Karsi', 'Birgitte Hjort Sørensen', ''),
#  ('CH_130', 'Kayla', 'Pixie Le Knot', ''),
#  ('CH_131', 'Kegs', 'Tim Landers', ''),
#  ('CH_132', 'Kevan Lannister', 'Ian Gelder', ''),
#  ('CH_133', 'Khal Drogo', 'Jason Momoa', ''),
#  ('CH_134', 'Khal Moro', 'Joseph Naufahu', ''),
#  ('CH_135', 'Khal Rhalko', 'Andrei Claude', ''),
#  ('CH_136', 'King Joffrey Baratheon Dwarf', 'Raymond Griffiths', ''),
#  ('CH_137', 'King Renly Baratheon Dwarf', 'Dean Whatton', ''),
#  ('CH_138', 'King Robb Stark Dwarf', 'George Appleby', ''),
#  ('CH_139', 'King Stannis Baratheon Dwarf', 'Maxwell Laird', ''),
#  ('CH_140', "King's Landing Rioter #1", 'Reg Wayment', ''),
#  ('CH_141', "King's Landing Rioter #2", 'Marko Juraga', ''),
#  ('CH_142', "King's Landing Rioter #3", 'Rea Separovic', ''),
#  ('CH_143', 'Kinvara', 'Ania Bukstein', ''),
#  ('CH_144', 'Kitty Frey', 'Lucy Hayes', ''),
#  ('CH_145', 'Knight of House Frey', 'Patrick Ryan', ''),
#  ('CH_146', 'Knight of House Lynderly', 'Paddy Rocks', ''),
#  ('CH_147', 'Kovarro', 'Steven Cole', ''),
#  ('CH_148', 'Kraznys mo Nakloz', 'Dan Hildebrand', ''),
#  ('CH_149', 'Kurleket', 'Kevin Keenan', ''),
#  ('CH_151', 'Lady Crane', 'Essie Davis', ''),
#  ('CH_152', 'Lancel Lannister', 'Eugene Simon', ''),
#  ('CH_153', 'Lannister Captain', 'Aiden Condron', ''),
#  ('CH_154', 'Lannister Captain', 'Richard Laing', ''),
#  ('CH_155', 'Lannister Guardsman', 'Conor Delaney', ''),
#  ('CH_156', 'Lannister Messenger', 'Simon Stewart', ''),
#  ('CH_157', 'Lannister Scout', 'Chris Gallagher', ''),
#  ('CH_158', 'Lead Dornish Guard', 'Christian Vit', ''),
#  ('CH_159', 'Leaf', 'Kae Alexander', '6.0'),
#  ('CH_159', 'Leaf', 'Octavia Selena Alexandru', '4.0'),
#  ('CH_160', 'Lem Lemoncloak', 'Jóhannes Haukur Jóhannesson', ''),
#  ('CH_161', 'Leo Lefford', 'Vinnie McCabe', ''),
#  ('CH_162', 'Lhara', 'Sarine Sofair', ''),
#  ('CH_163', 'Little Bird', 'Samuel Paul Small', ''),
#  ('CH_164', 'Little Bird', 'Tristan Mercieca', ''),
#  ('CH_165', 'Little Bird #3', 'Michael Nevin', ''),
#  ('CH_166', 'Little Bird #4', 'Jesse Magee', ''),
#  ('CH_167', 'Little Bird #5', 'Iona Clarke', ''),
#  ('CH_168', 'Little Bird #6', 'Lucy Gallagher', ''),
#  ('CH_169', 'Little Bird #7', 'Fionn Kernan', ''),
#  ('CH_170', 'Loboda', 'Zachary Baharov', ''),
#  ('CH_171', 'Locke', 'Noah Taylor', ''),
#  ('CH_172', 'Lollys Stokeworth', 'Elizabeth Cadwallader', ''),
#  ('CH_173', 'Lommy Greenhands', 'Eros Vlahos', ''),
#  ('CH_174', 'Loras Tyrell', 'Finn Jones', ''),
#  ('CH_175', 'Lord Galbart Glover', 'Mark Coney', ''),
#  ('CH_176', 'Lord Portan', 'Gordon Fulton', ''),
#  ('CH_177', 'Lord Varys', 'Conleth Hill', ''),
#  ('CH_178', 'Lordsport Dockhand', "Jer O'Leary", ''),
#  ('CH_179', 'Lothar Frey', 'Daniel Tuite', '6.0'),
#  ('CH_179', 'Lothar Frey', 'Tom Brooke', '3.0'),
#  ('CH_180', "Loyal Night's Watchman #1", 'Steve Cash', ''),
#  ('CH_181', "Loyal Night's Watchman #2", 'Robert Fawsitt', ''),
#  ('CH_182', 'Lyanna Mormont', 'Bella Ramsey', ''),
#  ('CH_183', 'Lyanna Stark', 'Aisling Franciosi', ''),
#  ('CH_184', 'Lysa Arryn', 'Kate Dickie', ''),
#  ('CH_185', 'Mace Tyrell', 'Roger Ashton-Griffiths', ''),
#  ('CH_186', 'Maester Aemon', 'Peter Vaughan', ''),
#  ('CH_187', 'Maester Cressen', 'Oliver Ford Davies', ''),
#  ('CH_188', 'Maester Luwin', 'Donald Sumpter', ''),
#  ('CH_189', 'Maester Wolkan', 'Richard Rycroft', ''),
#  ('CH_190', 'Mag the Mighty', 'Neil Fingleton', ''),
#  ('CH_191', 'Maggy', 'Jodhi May', ''),
#  ('CH_192', 'Mago', 'Ivailo Dimitrov', ''),
#  ('CH_193', 'Male Prostitute', 'Dennis Stokes', ''),
#  ('CH_194', 'Malko', 'Adewale Akinnuoye-Agbaje', ''),
#  ('CH_195', 'Mance Rayder', 'Ciarán Hinds', ''),
#  ('CH_196', 'Mandon Moore', 'James Doran', ''),
#  ('CH_197', 'Manservant', 'Conor Watters', ''),
#  ('CH_198', 'Marei', 'Josephine Gillan', ''),
#  ('CH_199', 'Margaery Tyrell', 'Natalie Dormer', ''),
#  ('CH_200', "Margaery's Handmaiden", 'Aisling Jarrett-Gavin', ''),
#  ('CH_201', 'Marillion', 'Emun Elliott', ''),
#  ('CH_202', 'Martyn Lannister', 'Dean-Charles Chapman', ''),
#  ('CH_203', 'Masha Heddle', 'Susie Kelly', ''),
#  ('CH_204', 'Matthos Seaworth', 'Kerr Logan', ''),
#  ('CH_205', 'Meera Reed', 'Ellie Kendrick', ''),
#  ('CH_206', 'Meereen Slave Master', 'Laurence Doherty', ''),
#  ('CH_207', 'Melessa Tarly', 'Samantha Spiro', ''),
#  ('CH_208', 'Melisandre', 'Carice van Houten', ''),
#  ('CH_209', 'Merchant Captain', 'Gary Pillai', ''),
#  ('CH_210', 'Mero', 'Mark Killeen', ''),
#  ('CH_211', 'Meryn Trant', 'Ian Beattie', ''),
#  ('CH_212', 'Mhaegen', 'Antonia Christophers', ''),
#  ('CH_213', 'Mikken', 'Boyd Rankin', ''),
#  ('CH_214', 'Mirelle', 'Elisa Lasowski', ''),
#  ('CH_215', 'Mirri Maz Duur', 'Mia Soteriou', ''),
#  ('CH_216', 'Missandei', 'Nathalie Emmanuel', ''),
#  ('CH_217', 'Mord', 'Ciaran Bermingham', ''),
#  ('CH_218', 'Mossador', 'Reece Noi', ''),
#  ('CH_219', 'Musician #1', 'Nanna Bryndís Hilmarsdóttir', ''),
#  ('CH_220', 'Musician #1', 'Jon Thor Birgisson', ''),
#  ('CH_221', 'Musician #2', 'Ragnar Þórhallsson', ''),
#  ('CH_222', 'Musician #2', 'Orri P. Dyrason', ''),
#  ('CH_223', 'Musician #3', 'Georg Holm', ''),
#  ('CH_224', 'Musician #3', 'Arnar Rosenkranz Hilmarsson', ''),
#  ('CH_225', 'Musician #4', 'Brynjar Leifsson', ''),
#  ('CH_226', 'Musician #5', 'Kristján Kristjánsson', ''),
#  ('CH_227', 'Mycah', 'Rhodri Hosking', ''),
#  ('CH_228', 'Myranda', 'Charlotte Hope', ''),
#  ('CH_229', 'Myrcella Baratheon', 'Aimee Richardson', '1.0'),
#  ('CH_229', 'Myrcella Baratheon', 'Aimee Richardson', '2.0'),
#  ('CH_229', 'Myrcella Baratheon', 'Nell Tiger Free', '5.0'),
#  ('CH_229', 'Myrcella Baratheon', 'Nell Tiger Free', '6.0'),
#  ('CH_230', 'Ned Umber', 'Harry Grasby', ''),
#  ('CH_231', "Night's Watch Deserter", "Barry John O'Connor", ''),
#  ('CH_232', "Night's Watch Messenger", "Frank O'Sullivan", ''),
#  ('CH_233', "Night's Watch Officer", 'Dennis McKeever', ''),
#  ('CH_234', "Night's Watch Officer", 'Michael Stuart', ''),
#  ('CH_235', "Night's Watchman", 'Marcus Lamb', ''),
#  ('CH_236', "Night's Watchman", 'Michael Hooley', ''),
#  ('CH_237', "Night's Watchman", 'Patrick J Molloy', ''),
#  ('CH_238', "Night's Watchman #1", 'Michael Hayes', ''),
#  ('CH_239', "Night's Watchman #2", 'Ruairí Heading', ''),
#  ('CH_240', "Night's Watchman #2", 'Tony Flynn', ''),
#  ('CH_241', 'Northman Rioter', 'Jed Murray', ''),
#  ('CH_243', 'Nymeria Sand', 'Jessica Henwick', ''),
#  ('CH_244', 'Obara Sand', 'Keisha Castle-Hughes', ''),
#  ('CH_245', 'Oberyn Martell', 'Pedro Pascal', ''),
#  ('CH_246', 'Old Nan', 'Margaret John', ''),
#  ('CH_247', 'Old Woman Prisoner', 'Gina Moxley', ''),
#  ('CH_248', 'Olenna Tyrell', 'Diana Rigg', ''),
#  ('CH_249', 'Olly', "Brenock O'Connor", ''),
#  ('CH_250', 'Olyvar', 'Will Tudor', ''),
#  ('CH_251', 'Orell', 'Mackenzie Crook', ''),
#  ('CH_252', 'Ornela', 'Hannah John-Kamen', ''),
#  ('CH_253', 'Osha', 'Natalia Tena', ''),
#  ('CH_254', 'Othell Yarwyck', 'Brian Fortune', ''),
#  ('CH_256', 'Pentoshi Servant', 'Rania Zouari', ''),
#  ('CH_257', 'Petyr Baelish', 'Aidan Gillen', ''),
#  ('CH_258', 'Podrick Payne', 'Daniel Portman', ''),
#  ('CH_259', 'Polliver', 'Andy Kellegher', ''),
#  ('CH_260', 'Prendahl na Ghezn', 'Ramon Tikaram', ''),
#  ('CH_261', 'Pyat Pree', 'Ian Hanmore', ''),
#  ('CH_262', 'Pypar', 'Josef Altin', ''),
#  ('CH_263', 'Qhono', 'Staz Nair', ''),
#  ('CH_264', 'Qhorin Halfhand', 'Simon Armstrong', ''),
#  ('CH_265', 'Qotho', 'Dar Salim', ''),
#  ('CH_266', 'Quaithe', 'Laura Pradelska', ''),
#  ('CH_267', 'Qyburn', 'Anton Lesser', ''),
#  ('CH_268', 'Rakharo', 'Elyes Gabel', ''),
#  ('CH_269', 'Ramsay Snow', 'Iwan Rheon', ''),
#  ('CH_270', 'Randyll Tarly', 'James Faulkner', ''),
#  ('CH_271', 'Rast', 'Luke Barnes', ''),
#  ('CH_272', 'Rattleshirt', 'Edward Dogliani', '2.0'),
#  ('CH_272', 'Rattleshirt', 'Edward Dogliani', '3.0'),
#  ('CH_272', 'Rattleshirt', "Ross O'Hennessy", '5.0'),
#  ('CH_273', 'Razdal mo Eraz', 'George Georgiou', ''),
#  ('CH_274', 'Red Keep Stableboy', 'Hugo Culverhouse', ''),
#  ('CH_275', 'Red Priestess', 'Melanie Liburd', ''),
#  ('CH_276', 'Red Priestess', 'Rila Fukushima', ''),
#  ('CH_277', 'Renly Baratheon', 'Gethin Anthony', ''),
#  ('CH_283', 'Rickard Karstark', 'John Stahl', '2.0'),
#  ('CH_283', 'Rickard Karstark', 'John Stahl', '3.0'),
#  ('CH_283', 'Rickard Karstark', 'Steve Blount', '1.0'),
#  ('CH_285', 'Rickon Stark', 'Art Parkinson', ''),
#  ('CH_286', 'Robb Stark', 'Richard Madden', ''),
#  ('CH_287', 'Robert Baratheon', 'Mark Addy', ''),
#  ('CH_288', 'Robett Glover', 'Tim McInnerny', ''),
#  ('CH_289', 'Robin Arryn', 'Lino Facioli', ''),
#  ('CH_290', 'Rodrik Cassel', 'Ron Donachie', ''),
#  ('CH_291', 'Roose Bolton', 'Michael McElhatton', ''),
#  ('CH_292', 'Rorge', 'Andy Beckwith', ''),
#  ('CH_293', 'Ros', 'Esmé Bianco', ''),
#  ('CH_294', 'Roslin Frey', 'Alexandra Dowling', ''),
#  ('CH_295', 'Royal Steward', 'Robert Sterne', ''),
#  ('CH_296', 'Ryger Rivers', 'Bryan McCaugherty', ''),
#  ('CH_297', 'Salladhor Saan', 'Lucian Msamati', ''),
#  ('CH_298', 'Samwell Tarly', 'John Bradley', ''),
#  ('CH_299', 'Sandor Clegane', 'Rory McCann', ''),
#  ('CH_300', 'Sansa Stark', 'Sophie Turner', ''),
#  ('CH_301', 'Selyse Baratheon', 'Tara Fitzgerald', '3.0'),
#  ('CH_301', 'Selyse Baratheon', 'Tara Fitzgerald', '4.0'),
#  ('CH_301', 'Selyse Baratheon', 'Tara Fitzgerald', '5.0'),
#  ('CH_301', 'Selyse Baratheon', 'Sarah MacKeever', '2.0'),
#  ('CH_302', 'Septa Moelle', 'Maggie Hayes', ''),
#  ('CH_303', 'Septa Mordane', 'Susan Brown', ''),
#  ('CH_304', 'Septa Scolera', 'Mary Jordan', ''),
#  ('CH_305', 'Septa Unella', 'Hannah Waddingham', ''),
#  ('CH_306', 'Septon', 'Kenneth Hadley', ''),
#  ('CH_307', 'Septon', 'Terry Byrne', ''),
#  ('CH_308', 'Ser Endrew Tarth', 'Dez McMahon', ''),
#  ('CH_309', 'Shae', 'Sibel Kekilli', ''),
#  ('CH_310', 'Shagga', 'Mark Lewis Jones', ''),
#  ('CH_312', 'Shireen Baratheon', 'Kerry Ingram', ''),
#  ('CH_313', 'Silk King', 'Slavko Juraga', ''),
#  ('CH_314', 'Smalljon Umber', 'Dean S. Jagger', ''),
#  ('CH_315', 'Spice King', 'Nicholas Blane', ''),
#  ('CH_316', 'Stannis Baratheon', 'Stephen Dillane', ''),
#  ('CH_317', 'Stark Bannerman', 'Michael Stuart', ''),
#  ('CH_318', 'Stark Guard', 'Faolan Morgan', ''),
#  ('CH_319', 'Stark Guard', 'Rick Burn', ''),
#  ('CH_320', 'Stark Guard', 'David Sheehan', ''),
#  ('CH_321', 'Stark Guard', 'Paul Monahan', ''),
#  ('CH_322', 'Steelshanks Walton', 'Jamie Michie', ''),
#  ('CH_323', 'Stevron Frey', 'Colin Carnegie', ''),
#  ('CH_324', 'Stiv', 'Stephen Don', ''),
#  ('CH_325', 'Styr', 'Yuri Kolokolnikov', ''),
#  ('CH_327', 'Syrio Forel', 'Miltos Yerolemou', ''),
#  ('CH_328', 'Talisa Maegyr', 'Oona Chaplin', ''),
#  ('CH_329', 'Talla Tarly', 'Rebecca Benson', ''),
#  ('CH_330', 'Ternesio Terys', 'Gary Oliver', ''),
#  ('CH_331', 'The Bear', 'Bart the Bear', ''),
#  ('CH_332', 'The Night King', 'Richard Brake', '4.0'),
#  ('CH_332', 'The Night King', 'Richard Brake', '5.0'),
#  ('CH_332', 'The Night King', "Vladimir 'Furdo' Furdik", '6.0'),
#  ('CH_332', 'The Night King', "Vladimir 'Furdo' Furdik", '7.0'),
#  ('CH_332', 'The Night King', "Vladimir 'Furdo' Furdik", '8.0'),
#  ('CH_333', 'The Tickler', 'Anthony Morris', ''),
#  ('CH_334', 'The Waif', 'Faye Marsay', ''),
#  ('CH_335', 'Thenn Warg', 'Joseph Gatt', ''),
#  ('CH_336', 'Theon Greyjoy', 'Alfie Allen', ''),
#  ('CH_337', 'Thin Man', 'Oengus MacNamara', ''),
#  ('CH_338', 'Thoros of Myr', 'Paul Kaye', ''),
#  ('CH_339', 'Three-Eyed Raven', 'Struan Rodger', '4.0'),
#  ('CH_339', 'Three-Eyed Raven', 'Max von Sydow', '6.0'),
#  ('CH_340', 'Timett', 'Tobias Winter', ''),
#  ('CH_341', 'Tobho Mott', 'Andrew Wilde', ''),
#  ('CH_342', 'Todder', "Will O'Connell", ''),
#  ('CH_343', 'Tomard', 'Phil Dixon', ''),
#  ('CH_344', 'Tommen Baratheon', 'Callum Wharry', '1.0'),
#  ('CH_344', 'Tommen Baratheon', 'Callum Wharry', '2.0'),
#  ('CH_344', 'Tommen Baratheon', 'Dean-Charles Chapman', '4.0'),
#  ('CH_344', 'Tommen Baratheon', 'Dean-Charles Chapman', '5.0'),
#  ('CH_344', 'Tommen Baratheon', 'Dean-Charles Chapman', '6.0'),
#  ('CH_345', 'Tormund Giantsbane', 'Kristofer Hivju', ''),
#  ('CH_346', 'Trystane Martell', 'Toby Sebastian', ''),
#  ('CH_347', 'Tycho Nestoris', 'Mark Gatiss', ''),
#  ('CH_348', 'Tyene Sand', 'Rosabell Laurenti Sellers', ''),
#  ('CH_349', 'Tyrion Lannister', 'Peter Dinklage', ''),
#  ('CH_350', 'Tywin Lannister', 'Charles Dance', ''),
#  ('CH_351', 'Vala', 'Meena Rayann', ''),
#  ('CH_352', 'Vardis Egen', 'Brendan McCormack', ''),
#  ('CH_353', 'Varly', 'Graham Charles', ''),
#  ('CH_355', 'Viserys Targaryen', 'Harry Lloyd', ''),
#  ('CH_356', 'Walda Bolton', 'Elizabeth Webster', ''),
#  ('CH_357', 'Walder Frey', 'David Bradley', ''),
#  ('CH_358', 'Wallen', "Barry O'Connor", ''),
#  ('CH_359', 'Warlock', 'Lottie Steer', ''),
#  ('CH_360', 'Waymar Royce', 'Rob Ostlere', ''),
#  ('CH_361', 'Wedding Band', 'Sigur Rós', ''),
#  ('CH_362', 'White Walker', 'Ian Whyte', ''),
#  ('CH_363', 'White Walker', 'Ross Mullan', ''),
#  ('CH_364', 'White Walker', 'Tim Loane', ''),
#  ('CH_365', 'White Walker #2', 'Spencer Wilding', ''),
#  ('CH_366', 'Wight Wildling Girl', 'Claire Wright', ''),
#  ('CH_367', 'Wildling Rioter', 'Michael Patrick', ''),
#  ('CH_368', 'Will', 'Bronson Webb', ''),
#  ('CH_369', 'Willem Lannister', 'Timothy Gibbons', ''),
#  ('CH_370', 'Willis Wode', 'Ryan McKenna', ''),
#  ('CH_371', 'Wine Merchant', 'Simon Lowe', ''),
#  ('CH_372', 'Winterfell Shepherd', 'Donagh Deeney', ''),
#  ('CH_373', 'Wun Wun', 'Ian Whyte', ''),
#  ('CH_374', 'Wyllis', 'Sam Coleman', ''),
#  ('CH_375', 'Xaro Xhoan Daxos', 'Nonso Anozie', ''),
#  ('CH_376', 'Yara Greyjoy', 'Gemma Whelan', ''),
#  ('CH_377', 'Yezzan zo Qaggaz', 'Enzo Cilenti', ''),
#  ('CH_378', 'Ygritte', 'Rose Leslie', ''),
#  ('CH_379', 'Yohn Royce', 'Rupert Vansittart', ''),
#  ('CH_380', 'Yoren', 'Francis Magee', ''),
#  ('CH_381', 'Young Benjen Stark', 'Matteo Elezi', ''),
#  ('CH_382', 'Young Cersei Lannister', 'Nell Williams', ''),
#  ('CH_383', 'Young Lyanna Stark', 'Cordelia Hill', ''),
#  ('CH_384', 'Young Nan', 'Annette Tierney', ''),
#  ('CH_385', 'Young Ned', 'Robert Aramayo', ''),
#  ('CH_386', 'Young Ned Stark', 'Sebastian Croft', ''),
#  ('CH_387', 'Young Rodrik Cassel', 'Fergus Leathem', ''),
#  ('CH_388', 'Zanrush', 'Gerald Lepkowski', '')]

# %% [markdown]
# ## Data Cleanup
#
# ### Task 2
#
# - CSV files are _text_ files, and all data is character strings.
#
#
# - Spreadsheet applications, like Excel, and the data import tools in databases can _infer_ column types in some cases. For example, consider the table definition created for importing ```scenes_characters.```
#
# ```
# CREATE TABLE `scenes_characters` (
#   `id` int(11) DEFAULT NULL,
#   `seasonNum` int(11) DEFAULT NULL,
#   `episodeNum` int(11) DEFAULT NULL,
#   `sceneNo` int(11) DEFAULT NULL,
#   `characterName` text
# ) ENGINE=InnoDB DEFAULT CHARSET=utf8mb4 COLLATE=utf8mb4_0900_ai_ci;
#
# ```
#
#
# - The import process inferred that some columns in the CSV file are text representations of integers, and performed conversion.
#
#
# - The process is unreliable, and does not always work.
#
#
# - For this task, you must modify column definitions and data valaues to represent the correct the meaning of the data. We will cover keys in the next task.
#
#
# - Execute your DDL and DML SQL in cells below. You can add Markdown cells to explain what you are doing.
#
#
# - My approach is to create a new schema with corrected table definitions and cleaned copies of the data. This preserves the original data for data lineage and avoids possible information loss.
#
#
# - Call your new schema ```W4111GoTSolutionClean.```
#
#
# - An example using a table called groups is given below
#
#
# - __NOTE:__ You can use MySQL Workbench or other tools to help you write the DDL and DML statements, but you MUST execute the statements in the cells below.

# %% [markdown]
# - Create the Schema:

# %%
# %sql CREATE SCHEMA `W4111GoTSolutionClean` ;
# Out:
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
# 1 rows affected.
# []

# %% [markdown]
# #### Example: Groups
#
# - You should have similar queries for the tables that you are cleaning up.
#
# - Create a table with clean data
#
# %%sql
# create table W4111GotSolutionClean.groups (id int, groupName varchar(32), characterName varchar(32))
#
# - Insert the data into the new table from the original
#
# %%sql insert into W4111GotSolutionClean.groups
# select id, groupName, `character` from W4111GotSolution.groups;
#
# - Check to make sure the data imported successfully
#
# %sql select count(*) from W4111GotSolution.groups
#
#  - ```''``` is a common way to represent "unknown" or "not applicable" in text data.[Codd's Rule no. 3](https://www.webopedia.com/TERM/C/Codds_Rules.html) defines the systmatic treatment of unknown or  not applicable data. So we should update this accordingly.
#
# %%sql update W4111GoTSolutionClean.groups set characterName=NULL where characterName=''

# %% [markdown]
# ## Answers

# %%
# %load_ext sql
# %sql mysql+pymysql://dbuser:dbuserdbuser@localhost/W4111GoTSolutionClean
# Out:
# 'Connected: dbuser@W4111GoTSolutionClean'

# %% [markdown]
# __characters__

# %% [markdown]
# - Setting Datatypes of columns

# %%
# %%sql
# SELECT MAX(LENGTH(characterName)) AS characterName_length,
#     MAX(LENGTH(characterLink)) AS characterLink_length,
#     MAX(LENGTH(actorName)) AS actorName_length,
#     MAX(LENGTH(actorLink)) AS actorLink_length,
#     MAX(LENGTH(character_id)) AS character_id_length,
#     MAX(LENGTH(characterimageThumb)) AS characterimageThumb_length,
#     MAX(LENGTH(characterimageFull)) AS characterimageFull_length,
#     MAX(LENGTH(nickname)) AS nickname_length
#     FROM W4111GoTSolution.characters
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 1 rows affected.
# [(28, 37, 29, 16, 6, 167, 250, 14)]

# %%
# %%sql CREATE TABLE W4111GoTSolutionClean.characters
#     AS SELECT * FROM W4111GoTSolution.characters
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 389 rows affected.
# []

# %%
# %%sql
# ALTER TABLE `W4111GoTSolutionClean`.`characters`
# CHANGE COLUMN `characterName` `characterName` VARCHAR(32) NULL DEFAULT NULL ,
# CHANGE COLUMN `characterLink` `characterLink` VARCHAR(64) NULL DEFAULT NULL ,
# CHANGE COLUMN `actorName` `actorName` VARCHAR(32) NULL DEFAULT NULL ,
# CHANGE COLUMN `actorLink` `actorLink` VARCHAR(64) NULL DEFAULT NULL ,
# CHANGE COLUMN `character_id` `character_id` VARCHAR(16) NULL DEFAULT NULL ,
# CHANGE COLUMN `characterImageThumb` `characterImageThumb` VARCHAR(256) NULL DEFAULT NULL ,
# CHANGE COLUMN `characterImageFull` `characterImageFull` VARCHAR(256) NULL DEFAULT NULL ,
# CHANGE COLUMN `nickname` `nickname` VARCHAR(32) NULL DEFAULT NULL ;
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 389 rows affected.
# []

# %% [markdown]
# - Determine some columns not NULL, unique, binary and keys.

# %%
# %%sql
# ALTER TABLE `W4111GoTSolutionClean`.`characters`
# CHANGE COLUMN `id` `id` INT NOT NULL ,
# CHANGE COLUMN `characterName` `characterName` VARCHAR(32) NOT NULL ,
# CHANGE COLUMN `character_id` `character_id` VARCHAR(16) NOT NULL ,
# ADD PRIMARY KEY (`id`),
# ADD UNIQUE INDEX `character_id_UNIQUE` (`character_id` ASC) VISIBLE;
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 0 rows affected.
# []

# %% [markdown]
# - Systematic treatment of NULL. "" is not the same as NULL

# %%
# %%sql
# update characters set actorName=NULL where actorName="";
# update characters set characterLink=NULL where characterLink="";
# update characters set actorLink=NULL where actorLink="";
# update characters set characterImageThumb=NULL where characterImageThumb="";
# update characters set characterImageFull=NULL where characterImageFull="";
# update characters set nickname=NULL where nickname="";
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 35 rows affected.
# 21 rows affected.
# 36 rows affected.
# 134 rows affected.
# 134 rows affected.
# 380 rows affected.
# []

# %% [markdown]
# - The intent of ```royal``` and ```kingsguard``` is that they are boolean, and not the string "True" or ""

# %%
# %%sql
# update characters set royal=1 where royal="True";
# update characters set royal=0 where royal="";
# update characters set kingsguard=1 where kingsguard="True";
# update characters set kingsguard=0 where kingsguard="";
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 17 rows affected.
# 372 rows affected.
# 5 rows affected.
# 384 rows affected.
# []

# %% [markdown]
# - Converting booleans from text and setting default value.

# %%
# %%sql
# ALTER TABLE `W4111GoTSolutionClean`.`characters`
# CHANGE COLUMN `royal` `royal` TINYINT NOT NULL DEFAULT 0 ,
# CHANGE COLUMN `kingsguard` `kingsguard` TINYINT NOT NULL DEFAULT 0 ;
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 389 rows affected.
# []

# %%
# %sql describe characters;
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 11 rows affected.
# [('id', 'int', 'NO', 'PRI', None, ''),
#  ('characterName', 'varchar(32)', 'NO', '', None, ''),
#  ('characterLink', 'varchar(64)', 'YES', '', None, ''),
#  ('actorName', 'varchar(32)', 'YES', '', None, ''),
#  ('actorLink', 'varchar(64)', 'YES', '', None, ''),
#  ('character_id', 'varchar(16)', 'NO', 'UNI', None, ''),
#  ('royal', 'tinyint', 'NO', '', '0', ''),
#  ('characterImageThumb', 'varchar(256)', 'YES', '', None, ''),
#  ('characterImageFull', 'varchar(256)', 'YES', '', None, ''),
#  ('nickname', 'varchar(32)', 'YES', '', None, ''),
#  ('kingsguard', 'tinyint', 'NO', '', '0', '')]

# %% [markdown]
# __character_relationships__
#
# - There is some serialized JSON in the ```value``` column for ```actor.```
#
#
# - Also, ```actor``` is redundant and we will need to remove later. It is here because we have to do some additional processing code to better align character relationships with scene information. We know ```character-actor``` mapping but until we factor in scenes, we are not sure which actor if there was more than one.

# %%
# %%sql CREATE TABLE W4111GoTSolutionClean.character_relationships
#     AS SELECT * FROM W4111GoTSolution.character_relationships
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 890 rows affected.
# []

# %%
# %%sql SELECT MAX(LENGTH(id)) AS id_length,
#     MAX(LENGTH(character_id)) AS character_id_length,
#     MAX(LENGTH(characterName)) AS characterName_length,
#     MAX(LENGTH(label)) AS label_length,
#     MAX(LENGTH(value)) AS value_length
#     FROM character_relationships
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 1 rows affected.
# [(3, 6, 24, 14, 112)]

# %%
# %%sql
# ALTER TABLE `W4111GoTSolutionClean`.`character_relationships`
# CHANGE COLUMN `id` `id` INT NOT NULL ,
# CHANGE COLUMN `character_id` `character_id` VARCHAR(16) NULL DEFAULT NULL ,
# CHANGE COLUMN `characterName` `characterName` VARCHAR(32) NULL DEFAULT NULL ,
# CHANGE COLUMN `label` `label` VARCHAR(16) NULL DEFAULT NULL ,
# CHANGE COLUMN `value` `value` VARCHAR(128) NULL DEFAULT NULL ,
# ADD PRIMARY KEY (`id`);
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 890 rows affected.
# []

# %%
# %%sql
# ALTER TABLE `W4111GoTSolutionClean`.`character_relationships`
# CHANGE COLUMN `character_id` `character_id` VARCHAR(16) NOT NULL ,
# CHANGE COLUMN `characterName` `characterName` VARCHAR(32) NOT NULL ,
# CHANGE COLUMN `label` `label` VARCHAR(16) NOT NULL ,
# CHANGE COLUMN `value` `value` VARCHAR(128) NOT NULL ,
# DROP PRIMARY KEY,
# ADD PRIMARY KEY (`id`, `character_id`);
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 0 rows affected.
# []

# %%
# %sql describe character_relationships;
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 5 rows affected.
# [('id', 'int', 'NO', 'PRI', None, ''),
#  ('character_id', 'varchar(16)', 'NO', 'PRI', None, ''),
#  ('characterName', 'varchar(32)', 'NO', '', None, ''),
#  ('label', 'varchar(16)', 'NO', '', None, ''),
#  ('value', 'varchar(128)', 'NO', '', None, '')]

# %% [markdown]
# __characters_actors__

# %% [markdown]
# - Setting Datatypes of columns

# %%
# %%sql CREATE TABLE W4111GoTSolutionClean.characters_actors
#     AS SELECT * FROM W4111GoTSolution.characters_actors
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 408 rows affected.
# []

# %%
# %%sql SELECT MAX(LENGTH(id)) AS id_length,
#     MAX(LENGTH(character_id)) AS character_id_length,
#     MAX(LENGTH(actorName)) AS actorName_length,
#     MAX(LENGTH(actorLink)) AS actorLink_length,
#     MAX(LENGTH(season)) AS season_length
#     FROM characters_actors
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 1 rows affected.
# [(3, 6, 29, 16, 3)]

# %%
# %%sql
# ALTER TABLE `W4111GoTSolutionClean`.`characters_actors`
# CHANGE COLUMN `id` `id` INT NOT NULL ,
# CHANGE COLUMN `character_id` `character_id` VARCHAR(8) NULL DEFAULT NULL ,
# CHANGE COLUMN `actorName` `actorName` VARCHAR(32) NOT NULL ,
# CHANGE COLUMN `actorLink` `actorLink` VARCHAR(32) NOT NULL ,
# ADD PRIMARY KEY (`id`);
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 408 rows affected.
# []

# %% [markdown]
# - Setting the season column to int type.

# %%
# %%sql
# update characters_actors set season=1 where season='1.0';
# update characters_actors set season=2 where season='2.0';
# update characters_actors set season=3 where season='3.0';
# update characters_actors set season=4 where season='4.0';
# update characters_actors set season=5 where season='5.0';
# update characters_actors set season=6 where season='6.0';
# update characters_actors set season=7 where season='7.0';
# update characters_actors set season=8 where season='8.0';
# update characters_actors set season=NULL where season='';
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 5 rows affected.
# 6 rows affected.
# 6 rows affected.
# 9 rows affected.
# 9 rows affected.
# 10 rows affected.
# 6 rows affected.
# 3 rows affected.
# 354 rows affected.
# []

# %% [markdown]
# - Systematic treatment of NULL. "" is not the same as NULL

# %%
# %sql update characters_actors set actorLink=NULL where actorLink="";
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 1 rows affected.
# []

# %%
# %%sql
# ALTER TABLE `W4111GoTSolutionClean`.`characters_actors`
# CHANGE COLUMN `id` `id` INT NOT NULL ,
# CHANGE COLUMN `character_id` `character_id` VARCHAR(8) NOT NULL ,
# CHANGE COLUMN `actorName` `actorName` VARCHAR(32) NOT NULL ,
# CHANGE COLUMN `actorLink` `actorLink` VARCHAR(32) NULL DEFAULT NULL ,
# CHANGE COLUMN `season` `season` INT NULL DEFAULT NULL ,
# ADD PRIMARY KEY (`id`);
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 408 rows affected.
# []

# %%
# %sql describe characters_actors;
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 5 rows affected.
# [('id', 'int', 'NO', 'PRI', None, ''),
#  ('character_id', 'varchar(8)', 'NO', '', None, ''),
#  ('actorName', 'varchar(32)', 'NO', '', None, ''),
#  ('actorLink', 'varchar(32)', 'YES', '', None, ''),
#  ('season', 'int', 'YES', '', None, '')]

# %% [markdown]
# __scenes__

# %%
# %%sql CREATE TABLE W4111GoTSolutionClean.scenes
#     AS SELECT * FROM W4111GoTSolution.scenes
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 4165 rows affected.
# []

# %%
# %%sql
# SELECT MAX(LENGTH(seasonNum)) AS seasonNum_length,
#     MAX(LENGTH(episodeNum)) AS episodeNum_length,
#     MAX(LENGTH(sceneNo)) AS sceneNo_length,
#     MAX(LENGTH(sceneStart)) AS sceneStart_length,
#     MAX(LENGTH(sceneEnd)) AS sceneEnd_length,
#     MAX(LENGTH(location)) AS location_length,
#     MAX(LENGTH(subLocation)) AS subLocation_length,
#     MAX(LENGTH(greensight)) AS greensight_length,
#     MAX(LENGTH(altLocation)) AS altLocation_length,
#     MAX(LENGTH(warg)) AS warg_length,
#     MAX(LENGTH(flashback)) AS flashback_length
#     FROM W4111GoTSolution.scenes
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 1 rows affected.
# [(1, 2, 3, 7, 7, 17, 37, 4, 24, 4, 4)]

# %% [markdown]
# - The intent of ```greensight``` ,```flashback```and ```warg``` is that they are boolean, and not the string "True" or ""

# %%
# %%sql
# update scenes set greensight=1 where greensight="True";
# update scenes set greensight=0 where greensight="";
# update scenes set flashback=1 where flashback="True";
# update scenes set flashback=0 where flashback="";
# update scenes set warg=1 where warg="True";
# update scenes set warg=0 where warg="";
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 16 rows affected.
# 4149 rows affected.
# 41 rows affected.
# 4124 rows affected.
# 7 rows affected.
# 4158 rows affected.
# []

# %% [markdown]
# - Systematic treatment of NULL. "" is not the same as NULL

# %%
# %%sql
# update scenes set subLocation=NULL where subLocation="";
# update scenes set altLocation=NULL where altLocation="";
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 495 rows affected.
# 4130 rows affected.
# []

# %% [markdown]
# - Setting Datatypes of columns and determine some columns not NULL, unique, binary and keys.

# %%
# %%sql
# ALTER TABLE `W4111GoTSolutionClean`.`scenes`
# CHANGE COLUMN `seasonNum` `seasonNum` INT NOT NULL ,
# CHANGE COLUMN `episodeNum` `episodeNum` INT NOT NULL ,
# CHANGE COLUMN `sceneNo` `sceneNo` INT NOT NULL ,
# CHANGE COLUMN `sceneStart` `sceneStart` TIME NOT NULL ,
# CHANGE COLUMN `sceneEnd` `sceneEnd` TIME NULL ,
# CHANGE COLUMN `location` `location` VARCHAR(32) NULL DEFAULT NULL ,
# CHANGE COLUMN `subLocation` `subLocation` VARCHAR(64) NULL DEFAULT NULL ,
# CHANGE COLUMN `greensight` `greensight` TINYINT(4) NOT NULL ,
# CHANGE COLUMN `altLocation` `altLocation` VARCHAR(32) NULL DEFAULT NULL ,
# CHANGE COLUMN `warg` `warg` TINYINT(4) NOT NULL ,
# CHANGE COLUMN `flashback` `flashback` TINYINT(4) NOT NULL ,
# ADD PRIMARY KEY (`seasonNum`, `episodeNum`, `sceneNo`);
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 4165 rows affected.
# /Users/kelanox/opt/anaconda3/lib/python3.7/site-packages/pymysql/cursors.py:170: Warning: (1681, 'Integer display width is deprecated and will be removed in a future release.')
#   result = self._query(query)
# []

# %%
# %%sql
# ALTER TABLE `W4111GoTSolutionClean`.`scenes`
# CHANGE COLUMN `id` `id` INT NOT NULL ,
# CHANGE COLUMN `sceneEnd` `sceneEnd` TIME NOT NULL ;
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 0 rows affected.
# []

# %%
# %sql describe scenes;
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 12 rows affected.
# [('id', 'int', 'NO', '', None, ''),
#  ('seasonNum', 'int', 'NO', 'PRI', None, ''),
#  ('episodeNum', 'int', 'NO', 'PRI', None, ''),
#  ('sceneNo', 'int', 'NO', 'PRI', None, ''),
#  ('sceneStart', 'time', 'NO', '', None, ''),
#  ('sceneEnd', 'time', 'NO', '', None, ''),
#  ('location', 'varchar(32)', 'YES', '', None, ''),
#  ('subLocation', 'varchar(64)', 'YES', '', None, ''),
#  ('greensight', 'tinyint', 'NO', '', None, ''),
#  ('altLocation', 'varchar(32)', 'YES', '', None, ''),
#  ('warg', 'tinyint', 'NO', '', None, ''),
#  ('flashback', 'tinyint', 'NO', '', None, '')]

# %% [markdown]
# __scenes_characters__

# %%
# %%sql CREATE TABLE W4111GoTSolutionClean.scenes_characters
#     AS SELECT * FROM W4111GoTSolution.scenes_characters
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 12114 rows affected.
# []

# %%
# %%sql SELECT MAX(LENGTH(id)) AS id_length,
#     MAX(LENGTH(seasonNum)) AS seasonNum_length,
#     MAX(LENGTH(episodeNum)) AS episodeNum_length,
#     MAX(LENGTH(sceneNo)) AS sceneNo_length,
#     MAX(LENGTH(characterName)) AS characterName_length
#     FROM scenes_characters
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 1 rows affected.
# [(5, 1, 2, 3, 34)]

# %% [markdown]
# - Setting Datatypes of columns and determine some columns not NULL, unique, binary and keys.

# %%
# %%sql
# ALTER TABLE `W4111GoTSolutionClean`.`scenes_characters`
# CHANGE COLUMN `id` `id` INT NOT NULL ,
# CHANGE COLUMN `seasonNum` `seasonNum` INT NOT NULL ,
# CHANGE COLUMN `episodeNum` `episodeNum` INT NOT NULL ,
# CHANGE COLUMN `sceneNo` `sceneNo` INT NOT NULL ,
# CHANGE COLUMN `characterName` `characterName` VARCHAR(64) NOT NULL ,
# ADD PRIMARY KEY (`id`);
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 12114 rows affected.
# []

# %%
# %sql describe scenes_characters;
# Out:
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 6 rows affected.
# [('id', 'int', 'NO', 'PRI', None, ''),
#  ('seasonNum', 'int', 'NO', '', None, ''),
#  ('episodeNum', 'int', 'NO', '', None, ''),
#  ('sceneNo', 'int', 'NO', '', None, ''),
#  ('characterName', 'varchar(64)', 'NO', '', None, ''),
#  ('character_id', 'varchar(16)', 'YES', '', None, '')]

# %% [markdown]
# __episodes__

# %%
# %%sql
#     SELECT MAX(LENGTH(id)) AS id_length,
#     MAX(LENGTH(seasonNum)) AS seasonNum_length,
#     MAX(LENGTH(episodeNum)) AS episodeNum_length,
#     MAX(LENGTH(episodeTitle)) AS episodeTitle_length,
#     MAX(LENGTH(episodeLink)) AS episodeLink_length,
#     MAX(LENGTH(episodeAirDate)) AS episodeAirDate_length,
#     MAX(LENGTH(episodeDescription)) AS episodeDescription_length
#     FROM W4111GoTSolution.episodes;
# Out:
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 1 rows affected.
# [(2, 1, 2, 37, 17, 10, 238)]

# %% [markdown]
# - Setting Datatypes of columns and determine some columns not NULL, unique, binary and keys.

# %%
# %%sql
# ALTER TABLE `W4111GoTSolutionClean`.`episodes`
# CHANGE COLUMN `id` `id` INT NOT NULL ,
# CHANGE COLUMN `seasonNum` `seasonNum` INT NOT NULL ,
# CHANGE COLUMN `episodeNum` `episodeNum` INT NOT NULL ,
# CHANGE COLUMN `episodeTitle` `episodeTitle` TEXT NOT NULL ,
# CHANGE COLUMN `episodeLink` `episodeLink` TEXT NOT NULL ,
# CHANGE COLUMN `episodeAirDate` `episodeAirDate` TEXT NOT NULL ,
# CHANGE COLUMN `episodeDescription` `episodeDescription` TEXT NOT NULL ;
# Out:
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 0 rows affected.
# []

# %%
# %%sql
# ALTER TABLE `W4111GoTSolutionClean`.`episodes`
# CHANGE COLUMN `episodeTitle` `episodeTitle` VARCHAR(64) NOT NULL ,
# CHANGE COLUMN `episodeLink` `episodeLink` VARCHAR(64) NOT NULL ,
# CHANGE COLUMN `episodeAirDate` `episodeAirDate` DATE NOT NULL ,
# CHANGE COLUMN `episodeDescription` `episodeDescription` VARCHAR(512) NOT NULL ,
# ADD PRIMARY KEY (`id`);
# Out:
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 0 rows affected.
# []

# %%
# %sql describe episodes;
# Out:
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 7 rows affected.
# [('id', 'int', 'NO', 'PRI', None, ''),
#  ('seasonNum', 'int', 'NO', '', None, ''),
#  ('episodeNum', 'int', 'NO', '', None, ''),
#  ('episodeTitle', 'varchar(64)', 'NO', '', None, ''),
#  ('episodeLink', 'varchar(64)', 'NO', '', None, ''),
#  ('episodeAirDate', 'date', 'NO', '', None, ''),
#  ('episodeDescription', 'varchar(512)', 'NO', '', None, '')]

# %% [markdown]
# __locations__

# %%
# %%sql CREATE TABLE W4111GoTSolutionClean.locations
#     AS SELECT * FROM W4111GoTSolution.locations
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 129 rows affected.
# []

# %%
# %%sql
#     SELECT MAX(LENGTH(id)) AS id_length,
#     MAX(LENGTH(location)) AS location_length,
#     MAX(LENGTH(subLocation)) AS subLocation_length
#     FROM W4111GoTSolution.locations
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 1 rows affected.
# [(3, 17, 37)]

# %%
# %sql update locations set subLocation=NULL where subLocation="";
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 26 rows affected.
# []

# %% [markdown]
# - Setting Datatypes of columns

# %%
# %%sql
# ALTER TABLE `W4111GoTSolutionClean`.`locations`
# CHANGE COLUMN `id` `id` INT NOT NULL ,
# CHANGE COLUMN `location` `location` VARCHAR(32) NOT NULL ,
# CHANGE COLUMN `subLocation` `subLocation` VARCHAR(64) NULL DEFAULT NULL ,
# ADD PRIMARY KEY (`id`);
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 129 rows affected.
# []

# %%
# %sql describe locations;
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 3 rows affected.
# [('id', 'int', 'NO', 'PRI', None, ''),
#  ('location', 'varchar(32)', 'NO', '', None, ''),
#  ('subLocation', 'varchar(64)', 'YES', '', None, '')]

# %% [markdown]
# ## Task 3
#
# ### Keys and Data Integrity
#
# - Correct analysis and management of the data requires defining keys and integrity constraints.
#
#
# - Use DML statements to modify the schema to create the constraints you think best.
#
#
# - The following diagram is my definition, but this is an example and may not be correct. It is simply to help you get started.
#
# | <img src="./got_er_model.png"> |
# | :---: |
# |__GoT ER Model__ |

# %% [markdown]
# - Characters

# %%
# %sql drop table if exists character_ids;
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 0 rows affected.
# []

# %%
# %%sql
# CREATE TABLE `W4111GoTSolutionClean`.`character_ids` (
#   `auto_id` INT NOT NULL AUTO_INCREMENT,
#   `characterName` VARCHAR(128) NULL,
#   `real_id` INT NULL,
#   `character_id` VARCHAR(16) GENERATED ALWAYS AS (concat("CH_", real_id)) STORED,
#   PRIMARY KEY (`auto_id`));
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 0 rows affected.
# []

# %%
# %%sql
# insert into character_ids(characterName, real_id)
#     select characterName, id from characters order by id asc;
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 389 rows affected.
# []

# %%
# %%sql
# insert into character_ids(characterName)
#     SELECT distinct characterName FROM W4111GoTSolution.scenes_characters
#             where
#                 characterName not in (select characterName from characters);
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 238 rows affected.
# []

# %%
# %%sql
# update character_ids
#     set real_id = auto_id-1 where real_id is NULL;
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 238 rows affected.
# []

# %%
# %%sql ALTER TABLE `W4111GoTSolutionClean`.`characters`
#     CHANGE COLUMN `characterName` `characterName` VARCHAR(64) CHARACTER SET 'utf8mb4' COLLATE 'utf8mb4_bin' NOT NULL ;
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 389 rows affected.
# []

# %%
# %%sql INSERT INTO characters(id, characterName, character_id)
#     SELECT real_id, characterName, character_id FROM character_ids
#     WHERE characterName NOT IN (SELECT characterName FROM characters);
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 238 rows affected.
# []

# %%
# %sql describe characters;
# Out:
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 11 rows affected.
# [('id', 'int', 'NO', 'PRI', None, ''),
#  ('characterName', 'varchar(64)', 'NO', '', None, ''),
#  ('characterLink', 'varchar(64)', 'YES', '', None, ''),
#  ('actorName', 'varchar(32)', 'YES', '', None, ''),
#  ('actorLink', 'varchar(64)', 'YES', '', None, ''),
#  ('character_id', 'varchar(16)', 'NO', 'UNI', None, ''),
#  ('royal', 'tinyint', 'NO', '', '0', ''),
#  ('characterImageThumb', 'varchar(256)', 'YES', '', None, ''),
#  ('characterImageFull', 'varchar(256)', 'YES', '', None, ''),
#  ('nickname', 'varchar(32)', 'YES', '', None, ''),
#  ('kingsguard', 'tinyint', 'NO', '', '0', '')]

# %% [markdown]
# - Scenes

# %%
# %%sql
# ALTER TABLE `W4111GoTSolutionClean`.`scenes`
# ADD CONSTRAINT `s_to_episodes`
#   FOREIGN KEY (`seasonNum` , `episodeNum`)
#   REFERENCES `W4111GoTSolutionClean`.`episodes` (`seasonNum` , `episodeNum`)
#   ON DELETE NO ACTION
#   ON UPDATE NO ACTION;
# Out:
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 4165 rows affected.
# []

# %%
# %%sql
# ALTER TABLE `W4111GoTSolutionClean`.`locations_fixed`
# ADD COLUMN `id` INT NOT NULL AUTO_INCREMENT FIRST,
# ADD PRIMARY KEY (`id`);
# Out:
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 0 rows affected.
# []

# %%
# %%sql
# update scenes
#     set location_id = (select id from locations_fixed
#                        where locations_fixed.location = scenes.location);
# Out:
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 4165 rows affected.
# []

# %%
# %%sql
# ALTER TABLE `W4111GoTSolutionClean`.`scenes`
# CHANGE COLUMN `location_id` `location_id` INT NOT NULL ;
# Out:
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 0 rows affected.
# []

# %%
# %%sql
# ALTER TABLE `W4111GoTSolutionClean`.`scenes`
# ADD INDEX `s_to_location_idx` (`location_id` ASC) VISIBLE;
#
# ALTER TABLE `W4111GoTSolutionClean`.`scenes`
# ADD CONSTRAINT `s_to_location`
#   FOREIGN KEY (`location_id`)
#   REFERENCES `W4111GoTSolutionClean`.`locations_fixed` (`id`)
#   ON DELETE NO ACTION
#   ON UPDATE NO ACTION;
# Out:
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 0 rows affected.
# 4165 rows affected.
# []

# %%
# %%sql
# update sublocations_fixed
#  set location_id =
#   (select id from locations_fixed
#    where locations_fixed.location = sublocations_fixed.location);
# Out:
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 103 rows affected.
# []

# %%
# %%sql
# ALTER TABLE `W4111GoTSolutionClean`.`scenes`
# ADD COLUMN `sublocation_id` INT NULL AFTER `location_id`;
# Out:
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 0 rows affected.
# []

# %%
# %sql describe scenes;
# Out:
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 14 rows affected.
# [('id', 'int', 'NO', '', None, ''),
#  ('seasonNum', 'int', 'NO', 'PRI', None, ''),
#  ('episodeNum', 'int', 'NO', 'PRI', None, ''),
#  ('sceneNo', 'int', 'NO', 'PRI', None, ''),
#  ('sceneStart', 'time', 'NO', '', None, ''),
#  ('sceneEnd', 'time', 'NO', '', None, ''),
#  ('location', 'varchar(32)', 'NO', '', None, ''),
#  ('subLocation', 'varchar(64)', 'YES', '', None, ''),
#  ('greensight', 'tinyint', 'NO', '', None, ''),
#  ('altLocation', 'varchar(32)', 'YES', '', None, ''),
#  ('warg', 'tinyint', 'NO', '', None, ''),
#  ('flashback', 'tinyint', 'NO', '', None, ''),
#  ('location_id', 'int', 'NO', 'MUL', None, ''),
#  ('sublocation_id', 'int', 'YES', '', None, '')]

# %% [markdown]
# - Scenes and Characters

# %%
# %%sql
# create table bad_characters
#     as
#     select characterName
#     from
#       (select characterName, count(*) as count
#         from
#         characters
#         group by characterName
#         having count>1) as a;
# Out:
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 15 rows affected.
# []

# %%
# %%sql
# update scenes_characters
#   set character_id =
#     (select character_id from characters
#         where characters.characterName=scenes_characters.characterName
#           and scenes_characters.characterName
#             not in (select characterName from bad_characters));
# Out:
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 12114 rows affected.
# []

# %%
# %%sql
# ALTER TABLE `W4111GoTSolutionClean`.`scenes_characters`
# ADD CONSTRAINT `scc_to_sc`
#   FOREIGN KEY (`seasonNum` , `episodeNum` , `sceneNo`)
#   REFERENCES `W4111GoTSolutionClean`.`scenes` (`seasonNum` , `episodeNum` , `sceneNo`)
#   ON DELETE NO ACTION
#   ON UPDATE NO ACTION;
# Out:
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 12114 rows affected.
# []

# %%
# %%sql
# ALTER TABLE `W4111GoTSolutionClean`.`scenes_characters`
# ADD INDEX `sc_to_character_idx1` (`character_id` ASC) VISIBLE;
#
# ALTER TABLE `W4111GoTSolutionClean`.`scenes_characters`
# ADD CONSTRAINT `sc_to_character`
#   FOREIGN KEY (`character_id`)
#   REFERENCES `W4111GoTSolutionClean`.`characters` (`character_id`)
#   ON DELETE NO ACTION
#   ON UPDATE NO ACTION;
# Out:
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 0 rows affected.
# 12114 rows affected.
# []

# %%
# %sql describe scenes_characters;
# Out:
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 6 rows affected.
# [('id', 'int', 'NO', 'PRI', None, ''),
#  ('seasonNum', 'int', 'NO', 'MUL', None, ''),
#  ('episodeNum', 'int', 'NO', '', None, ''),
#  ('sceneNo', 'int', 'NO', '', None, ''),
#  ('characterName', 'varchar(64)', 'NO', '', None, ''),
#  ('character_id', 'varchar(16)', 'YES', 'MUL', None, '')]

# %% [markdown]
# ## Task 4
#
# ### Views

# %% [markdown]
# #### Character Interactions
#
# - ```Characters``` interacted if they appeared in the same ```scene.```
#
#
# - Create the following view:
#     - ```characterName_1```
#     - ```character_id_1```
#     - ```characterName_2```
#     - ```character_id_2```
#     - ```scene_count,``` number of scenes containing both ```characters.```
#     - Order by ```scene_count``` descending.
#
# - Each pair should appear only once, that is the table should not contain two rows of the form:
#     - ```character_1, character_2, scene_count```
#     - ```character_2, character_1, scene_count```
#
#
# <u>Answer:</u>

# %%
# %%sql
# ALTER TABLE `W4111GoTSolutionClean`.`scenes_characters`
# ADD COLUMN `character_id` VARCHAR(16) NULL AFTER `characterName`;
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 0 rows affected.
# []

# %%
# %%sql update scenes_characters
# set scenes_characters.character_id = (select character_id from characters
#                                       where scenes_characters.characterName = characters.characterName limit 1);
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 12114 rows affected.
# []

# %%
# %%sql
# CREATE VIEW `character_interations` AS
# SELECT
#   a.characterName as characterName_1,
#   a.character_id as character_id_1,
#   a.character_id as character_id_2,
#   b.characterName as characterName_2,
#   count(*) as count
# FROM
#   w4111gotsolutionclean.scenes_characters as a
#   JOIN
#   w4111gotsolutionclean.scenes_characters as b
# USING(seasonNum, episodeNum, sceneNo)
# where a.characterName < b.characterName and a.characterName != b.characterName
# group by characterName_1, characterName_2, character_id_1, character_id_2
# order by count desc;
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 0 rows affected.
# []

# %%
# %sql SELECT * FROM W4111GoTSolutionClean.character_interations;
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 4236 rows affected.
# [('Daenerys Targaryen', 'CH_44', 'CH_44', 'Drogon', 172),
#  ('Daenerys Targaryen', 'CH_44', 'CH_44', 'Jorah Mormont', 148),
#  ('Jon Snow', 'CH_123', 'CH_123', 'Tormund Giantsbane', 145),
#  ('Lord Varys', 'CH_177', 'CH_177', 'Tyrion Lannister', 141),
#  ('Davos Seaworth', 'CH_47', 'CH_47', 'Jon Snow', 136),
#  ('Daenerys Targaryen', 'CH_44', 'CH_44', 'Missandei', 131),
#  ('Daenerys Targaryen', 'CH_44', 'CH_44', 'Jon Snow', 119),
#  ('Daenerys Targaryen', 'CH_44', 'CH_44', 'Tyrion Lannister', 116),
#  ('Missandei', 'CH_216', 'CH_216', 'Tyrion Lannister', 97),
#  ('Brienne of Tarth', 'CH_31', 'CH_31', 'Jaime Lannister', 91),
#  ('Grey Worm', 'CH_91', 'CH_91', 'Missandei', 86),
#  ('Jon Snow', 'CH_123', 'CH_123', 'Tyrion Lannister', 82),
#  ('Cersei Lannister', 'CH_38', 'CH_38', 'Tyrion Lannister', 82),
#  ('Daenerys Targaryen', 'CH_44', 'CH_44', 'Grey Worm', 82),
#  ('Cersei Lannister', 'CH_38', 'CH_38', 'Jaime Lannister', 81),
#  ('Eddison Tollett', 'CH_60', 'CH_60', 'Jon Snow', 81),
#  ('Brienne of Tarth', 'CH_31', 'CH_31', 'Podrick Payne', 81),
#  ('Jon Snow', 'CH_123', 'CH_123', 'Samwell Tarly', 80),
#  ('Sansa Stark', 'CH_300', 'CH_300', 'Tyrion Lannister', 80),
#  ('Bran Stark', 'CH_29', 'CH_29', 'Hodor', 76),
#  ('Podrick Payne', 'CH_258', 'CH_258', 'Tyrion Lannister', 75),
#  ('Jaime Lannister', 'CH_113', 'CH_113', 'Tyrion Lannister', 74),
#  ('Davos Seaworth', 'CH_47', 'CH_47', 'Tyrion Lannister', 70),
#  ('Bran Stark', 'CH_29', 'CH_29', 'Meera Reed', 68),
#  ('Arya Stark', 'CH_15', 'CH_15', 'Sandor Clegane', 67),
#  ('Cersei Lannister', 'CH_38', 'CH_38', 'Gregor Clegane', 67),
#  ('Cersei Lannister', 'CH_38', 'CH_38', 'Tommen Baratheon', 65),
#  ('Grey Worm', 'CH_91', 'CH_91', 'Tyrion Lannister', 65),
#  ('Jon Snow', 'CH_123', 'CH_123', 'Sansa Stark', 64),
#  ('Drogon', 'CH_57', 'CH_57', 'Rhaegal', 64),
#  ('Jorah Mormont', 'CH_125', 'CH_125', 'Missandei', 64),
#  ('Lord Varys', 'CH_177', 'CH_177', 'Missandei', 64),
#  ('Daenerys Targaryen', 'CH_44', 'CH_44', 'Lord Varys', 64),
#  ('Gilly', 'CH_73', 'CH_73', 'Samwell Tarly', 62),
#  ('Barristan Selmy', 'CH_19', 'CH_19', 'Daenerys Targaryen', 62),
#  ('Cersei Lannister', 'CH_38', 'CH_38', 'Joffrey Baratheon', 60),
#  ('Daenerys Targaryen', 'CH_44', 'CH_44', 'Rhaegal', 59),
#  ('Bronn', 'CH_32', 'CH_32', 'Tyrion Lannister', 59),
#  ('Petyr Baelish', 'CH_257', 'CH_257', 'Sansa Stark', 58),
#  ('Cersei Lannister', 'CH_38', 'CH_38', 'Qyburn', 58),
#  ('Cersei Lannister', 'CH_38', 'CH_38', 'Tywin Lannister', 57),
#  ('Jorah Mormont', 'CH_125', 'CH_125', 'Tyrion Lannister', 57),
#  ('Daario Naharis', 'CH_43', 'CH_43', 'Daenerys Targaryen', 56),
#  ('Jon Snow', 'CH_123', 'CH_123', 'Jorah Mormont', 56),
#  ('Beric Dondarrion', 'CH_21', 'CH_21', 'Sandor Clegane', 53),
#  ('Joffrey Baratheon', 'CH_120', 'CH_120', 'Tyrion Lannister', 52),
#  ('Joffrey Baratheon', 'CH_120', 'CH_120', 'Sansa Stark', 51),
#  ('Hodor', 'CH_102', 'CH_102', 'Meera Reed', 51),
#  ('Rhaegal', 'CH_278', 'CH_278', 'Viserion', 50),
#  ('Arya Stark', 'CH_15', 'CH_15', 'Gendry', 50),
#  ('Cersei Lannister', 'CH_38', 'CH_38', 'Margaery Tyrell', 50),
#  ('Bronn', 'CH_32', 'CH_32', 'Jaime Lannister', 50),
#  ('Beric Dondarrion', 'CH_21', 'CH_21', 'Tormund Giantsbane', 50),
#  ('Jon Snow', 'CH_123', 'CH_123', 'Lord Varys', 49),
#  ('Cersei Lannister', 'CH_38', 'CH_38', 'Sansa Stark', 48),
#  ('Jon Snow', 'CH_123', 'CH_123', 'Ygritte', 48),
#  ('Cersei Lannister', 'CH_38', 'CH_38', 'Grand Maester Pycelle', 47),
#  ('Tyrion Lannister', 'CH_349', 'CH_349', 'Tywin Lannister', 47),
#  ('Brienne of Tarth', 'CH_31', 'CH_31', 'Sansa Stark', 47),
#  ('Gregor Clegane', 'CH_87', 'CH_87', 'Qyburn', 47),
#  ('Baby Sam', 'CH_16', 'CH_16', 'Gilly', 47),
#  ('Jon Snow', 'CH_123', 'CH_123', 'Missandei', 46),
#  ('Grenn', 'CH_89', 'CH_89', 'Jon Snow', 45),
#  ('Eddison Tollett', 'CH_60', 'CH_60', 'Samwell Tarly', 45),
#  ('Barristan Selmy', 'CH_19', 'CH_19', 'Jorah Mormont', 45),
#  ('Brienne of Tarth', 'CH_31', 'CH_31', 'Tyrion Lannister', 45),
#  ('Catelyn Stark', 'CH_36', 'CH_36', 'Robb Stark', 44),
#  ('Bran Stark', 'CH_29', 'CH_29', 'Jojen Reed', 44),
#  ('Cersei Lannister', 'CH_38', 'CH_38', 'Mace Tyrell', 44),
#  ('Jorah Mormont', 'CH_125', 'CH_125', 'Sandor Clegane', 44),
#  ('Grey Worm', 'CH_91', 'CH_91', 'Jon Snow', 44),
#  ('Barristan Selmy', 'CH_19', 'CH_19', 'Missandei', 43),
#  ('Sandor Clegane', 'CH_299', 'CH_299', 'Tormund Giantsbane', 43),
#  ('Davos Seaworth', 'CH_47', 'CH_47', 'Lord Varys', 43),
#  ('Arya Stark', 'CH_15', 'CH_15', 'Sansa Stark', 42),
#  ('Jon Snow', 'CH_123', 'CH_123', 'Sandor Clegane', 42),
#  ('Brienne of Tarth', 'CH_31', 'CH_31', 'Davos Seaworth', 42),
#  ('Davos Seaworth', 'CH_47', 'CH_47', 'Tormund Giantsbane', 42),
#  ('Grey Worm', 'CH_91', 'CH_91', 'Lord Varys', 42),
#  ('Davos Seaworth', 'CH_47', 'CH_47', 'Missandei', 42),
#  ('Eddison Tollett', 'CH_60', 'CH_60', 'Grenn', 41),
#  ('Brienne of Tarth', 'CH_31', 'CH_31', 'Jon Snow', 41),
#  ('Drogon', 'CH_57', 'CH_57', 'Jon Snow', 41),
#  ('Daenerys Targaryen', 'CH_44', 'CH_44', 'Viserion', 40),
#  ('Drogon', 'CH_57', 'CH_57', 'Viserion', 40),
#  ('Cersei Lannister', 'CH_38', 'CH_38', 'Lord Varys', 40),
#  ('Joffrey Baratheon', 'CH_120', 'CH_120', 'Margaery Tyrell', 39),
#  ('Daario Naharis', 'CH_43', 'CH_43', 'Missandei', 39),
#  ('Eddison Tollett', 'CH_60', 'CH_60', 'Tormund Giantsbane', 39),
#  ('Daenerys Targaryen', 'CH_44', 'CH_44', 'Davos Seaworth', 39),
#  ('Bran Stark', 'CH_29', 'CH_29', 'Three-Eyed Raven', 38),
#  ('Davos Seaworth', 'CH_47', 'CH_47', 'Melisandre', 38),
#  ('Robb Stark', 'CH_286', 'CH_286', 'Talisa Maegyr', 38),
#  ('Baby Sam', 'CH_16', 'CH_16', 'Samwell Tarly', 38),
#  ('Alliser Thorne', 'CH_5', 'CH_5', 'Jon Snow', 37),
#  ('Loras Tyrell', 'CH_174', 'CH_174', 'Margaery Tyrell', 37),
#  ('Jojen Reed', 'CH_121', 'CH_121', 'Meera Reed', 37),
#  ('Jon Snow', 'CH_123', 'CH_123', 'Rhaegal', 37),
#  ('Ghost', 'CH_72', 'CH_72', 'Jon Snow', 36),
#  ('Jorah Mormont', 'CH_125', 'CH_125', 'Tormund Giantsbane', 36),
#  ('Bran Stark', 'CH_29', 'CH_29', 'Summer', 35),
#  ('Davos Seaworth', 'CH_47', 'CH_47', 'Stannis Baratheon', 35),
#  ('Drogon', 'CH_57', 'CH_57', 'Tyrion Lannister', 35),
#  ('Bran Stark', 'CH_29', 'CH_29', 'Jon Snow', 34),
#  ('Arya Stark', 'CH_15', 'CH_15', "Jaqen H'ghar", 34),
#  ('Hodor', 'CH_102', 'CH_102', 'Jojen Reed', 34),
#  ('Davos Seaworth', 'CH_47', 'CH_47', 'Sansa Stark', 34),
#  ('Beric Dondarrion', 'CH_21', 'CH_21', 'Jorah Mormont', 34),
#  ('Lord Varys', 'CH_177', 'CH_177', 'Sansa Stark', 33),
#  ('Theon Greyjoy', 'CH_336', 'CH_336', 'Yara Greyjoy', 33),
#  ('Sansa Stark', 'CH_300', 'CH_300', 'Shae', 33),
#  ('Gendry', 'CH_70', 'CH_70', 'Sandor Clegane', 33),
#  ('Beric Dondarrion', 'CH_21', 'CH_21', 'Thoros of Myr', 33),
#  ('Tormund Giantsbane', 'CH_345', 'CH_345', 'Ygritte', 33),
#  ('Margaery Tyrell', 'CH_199', 'CH_199', 'Tommen Baratheon', 33),
#  ('Sansa Stark', 'CH_300', 'CH_300', 'Tormund Giantsbane', 33),
#  ('Beric Dondarrion', 'CH_21', 'CH_21', 'Jon Snow', 33),
#  ('Bran Stark', 'CH_29', 'CH_29', 'Theon Greyjoy', 32),
#  ('Bran Stark', 'CH_29', 'CH_29', 'Tyrion Lannister', 32),
#  ('Melisandre', 'CH_208', 'CH_208', 'Stannis Baratheon', 32),
#  ('Margaery Tyrell', 'CH_199', 'CH_199', 'Olenna Tyrell', 32),
#  ('Grey Worm', 'CH_91', 'CH_91', 'Jorah Mormont', 32),
#  ('Daario Naharis', 'CH_43', 'CH_43', 'Jorah Mormont', 32),
#  ('Podrick Payne', 'CH_258', 'CH_258', 'Sansa Stark', 32),
#  ('Mace Tyrell', 'CH_185', 'CH_185', 'Tywin Lannister', 32),
#  ('Mace Tyrell', 'CH_185', 'CH_185', 'Margaery Tyrell', 32),
#  ('Qhono', 'CH_263', 'CH_263', 'Tyrion Lannister', 32),
#  ('Jaime Lannister', 'CH_113', 'CH_113', 'Podrick Payne', 32),
#  ('Sandor Clegane', 'CH_299', 'CH_299', 'Sansa Stark', 31),
#  ('Joffrey Baratheon', 'CH_120', 'CH_120', 'Tommen Baratheon', 31),
#  ('Sandor Clegane', 'CH_299', 'CH_299', 'Tyrion Lannister', 31),
#  ('Bran Stark', 'CH_29', 'CH_29', 'Osha', 31),
#  ('Shae', 'CH_309', 'CH_309', 'Tyrion Lannister', 31),
#  ('Sandor Clegane', 'CH_299', 'CH_299', 'Thoros of Myr', 31),
#  ('Jon Snow', 'CH_123', 'CH_123', 'Olly', 31),
#  ('Daenerys Targaryen', 'CH_44', 'CH_44', 'Qhono', 31),
#  ('Bran Stark', 'CH_29', 'CH_29', 'Sansa Stark', 30),
#  ('Joffrey Baratheon', 'CH_120', 'CH_120', 'Sandor Clegane', 30),
#  ('Grenn', 'CH_89', 'CH_89', 'Samwell Tarly', 30),
#  ('Jaime Lannister', 'CH_113', 'CH_113', 'Tywin Lannister', 30),
#  ('Brienne of Tarth', 'CH_31', 'CH_31', 'Tormund Giantsbane', 30),
#  ('Davos Seaworth', 'CH_47', 'CH_47', 'Jorah Mormont', 30),
#  ('Sansa Stark', 'CH_300', 'CH_300', 'Tommen Baratheon', 29),
#  ('Joffrey Baratheon', 'CH_120', 'CH_120', 'Tywin Lannister', 29),
#  ('Podrick Payne', 'CH_258', 'CH_258', 'Tormund Giantsbane', 29),
#  ('Gendry', 'CH_70', 'CH_70', 'Tormund Giantsbane', 29),
#  ('Brienne of Tarth', 'CH_31', 'CH_31', 'Lord Varys', 29),
#  ('Sansa Stark', 'CH_300', 'CH_300', 'Yohn Royce', 29),
#  ('Barristan Selmy', 'CH_19', 'CH_19', 'Grey Worm', 28),
#  ('Jaime Lannister', 'CH_113', 'CH_113', 'Qyburn', 28),
#  ('Jon Snow', 'CH_123', 'CH_123', 'Qhono', 28),
#  ('Davos Seaworth', 'CH_47', 'CH_47', 'Grey Worm', 28),
#  ('Sansa Stark', 'CH_300', 'CH_300', 'Theon Greyjoy', 27),
#  ('Margaery Tyrell', 'CH_199', 'CH_199', 'Tywin Lannister', 27),
#  ('Gendry', 'CH_70', 'CH_70', 'Thoros of Myr', 27),
#  ('Mace Tyrell', 'CH_185', 'CH_185', 'Tyrion Lannister', 27),
#  ('Daenerys Targaryen', 'CH_44', 'CH_44', 'Hizdahr zo Loraq', 27),
#  ('Brienne of Tarth', 'CH_31', 'CH_31', 'Missandei', 27),
#  ('Daenerys Targaryen', 'CH_44', 'CH_44', 'Sansa Stark', 27),
#  ('Jon Snow', 'CH_123', 'CH_123', 'Theon Greyjoy', 26),
#  ('Jaime Lannister', 'CH_113', 'CH_113', 'Mace Tyrell', 26),
#  ('Jaime Lannister', 'CH_113', 'CH_113', 'Lord Varys', 26),
#  ('Gregor Clegane', 'CH_87', 'CH_87', 'Jaime Lannister', 26),
#  ('Jon Snow', 'CH_123', 'CH_123', 'Melisandre', 26),
#  ('Daenerys Targaryen', 'CH_44', 'CH_44', 'Jaime Lannister', 26),
#  ('Jorah Mormont', 'CH_125', 'CH_125', 'Lord Varys', 26),
#  ('Brienne of Tarth', 'CH_31', 'CH_31', 'Daenerys Targaryen', 26),
#  ('Drogon', 'CH_57', 'CH_57', 'Jorah Mormont', 25),
#  ('Hodor', 'CH_102', 'CH_102', 'Osha', 25),
#  ('Margaery Tyrell', 'CH_199', 'CH_199', 'Sansa Stark', 25),
#  ('Cersei Lannister', 'CH_38', 'CH_38', 'Olenna Tyrell', 25),
#  ('Ramsay Snow', 'CH_269', 'CH_269', 'Theon Greyjoy', 25),
#  ('Beric Dondarrion', 'CH_21', 'CH_21', 'Gendry', 25),
#  ('Tommen Baratheon', 'CH_344', 'CH_344', 'Tywin Lannister', 25),
#  ('Grand Maester Pycelle', 'CH_78', 'CH_78', 'Mace Tyrell', 25),
#  ('Oberyn Martell', 'CH_245', 'CH_245', 'Tyrion Lannister', 25),
#  ('High Sparrow', 'CH_100', 'CH_100', 'Margaery Tyrell', 25),
#  ('Gendry', 'CH_70', 'CH_70', 'Jon Snow', 25),
#  ('Brienne of Tarth', 'CH_31', 'CH_31', 'Jorah Mormont', 25),
#  ('Bran Stark', 'CH_29', 'CH_29', 'Daenerys Targaryen', 25),
#  ('Samwell Tarly', 'CH_298', 'CH_298', 'Tormund Giantsbane', 25),
#  ('Bran Stark', 'CH_29', 'CH_29', 'Rickon Stark', 24),
#  ('Hodor', 'CH_102', 'CH_102', 'Summer', 24),
#  ('Theon Greyjoy', 'CH_336', 'CH_336', 'Tyrion Lannister', 24),
#  ('Tommen Baratheon', 'CH_344', 'CH_344', 'Tyrion Lannister', 24),
#  ('Grand Maester Pycelle', 'CH_78', 'CH_78', 'Tyrion Lannister', 24),
#  ('Margaery Tyrell', 'CH_199', 'CH_199', 'Tyrion Lannister', 24),
#  ('Mace Tyrell', 'CH_185', 'CH_185', 'Tommen Baratheon', 24),
#  ('Bran Stark', 'CH_29', 'CH_29', 'Brienne of Tarth', 24),
#  ('Grand Maester Pycelle', 'CH_78', 'CH_78', 'Lord Varys', 23),
#  ('Joffrey Baratheon', 'CH_120', 'CH_120', 'Meryn Trant', 23),
#  ('Osha', 'CH_253', 'CH_253', 'Rickon Stark', 23),
#  ('Arya Stark', 'CH_15', 'CH_15', 'Hot Pie', 23),
#  ('Cersei Lannister', 'CH_38', 'CH_38', 'Loras Tyrell', 23),
#  ('Davos Seaworth', 'CH_47', 'CH_47', 'Qhono', 23),
#  ('Missandei', 'CH_216', 'CH_216', 'Qhono', 23),
#  ('Brienne of Tarth', 'CH_31', 'CH_31', 'Grey Worm', 23),
#  ('Arya Stark', 'CH_15', 'CH_15', 'Jon Snow', 22),
#  ('Catelyn Stark', 'CH_36', 'CH_36', 'Rodrik Cassel', 22),
#  ('Jaime Lannister', 'CH_113', 'CH_113', 'Jon Snow', 22),
#  ('Daenerys Targaryen', 'CH_44', 'CH_44', 'Khal Drogo', 22),
#  ('Gendry', 'CH_70', 'CH_70', 'Hot Pie', 22),
#  ('Barristan Selmy', 'CH_19', 'CH_19', 'Daario Naharis', 22),
#  ('Gregor Clegane', 'CH_87', 'CH_87', 'Tyrion Lannister', 22),
#  ('Jon Snow', 'CH_123', 'CH_123', 'Podrick Payne', 22),
#  ('Davos Seaworth', 'CH_47', 'CH_47', 'Lyanna Mormont', 22),
#  ('Jon Snow', 'CH_123', 'CH_123', 'Ramsay Snow', 22),
#  ('Cersei Lannister', 'CH_38', 'CH_38', 'Euron Greyjoy', 22),
#  ('Jon Snow', 'CH_123', 'CH_123', 'Viserion', 22),
#  ('The Night King', 'CH_332', 'CH_332', 'Viserion', 22),
#  ('Davos Seaworth', 'CH_47', 'CH_47', 'Jaime Lannister', 22),
#  ('Brienne of Tarth', 'CH_31', 'CH_31', 'Yohn Royce', 22),
#  ('Davos Seaworth', 'CH_47', 'CH_47', 'Yohn Royce', 22),
#  ('Arya Stark', 'CH_15', 'CH_15', 'Bran Stark', 21),
#  ('Robb Stark', 'CH_286', 'CH_286', 'Theon Greyjoy', 21),
#  ('Ghost', 'CH_72', 'CH_72', 'Samwell Tarly', 21),
#  ('Daario Naharis', 'CH_43', 'CH_43', 'Grey Worm', 21),
#  ('Catelyn Stark', 'CH_36', 'CH_36', 'Talisa Maegyr', 21),
#  ('Oberyn Martell', 'CH_245', 'CH_245', 'Tywin Lannister', 21),
#  ('Cersei Lannister', 'CH_38', 'CH_38', 'Oberyn Martell', 21),
#  ('Jaime Lannister', 'CH_113', 'CH_113', 'Margaery Tyrell', 21),
#  ('Alliser Thorne', 'CH_5', 'CH_5', 'Olly', 21),
#  ('Daario Naharis', 'CH_43', 'CH_43', 'Hizdahr zo Loraq', 21),
#  ('Gendry', 'CH_70', 'CH_70', 'Jorah Mormont', 21),
#  ('Bran Stark', 'CH_29', 'CH_29', 'Yohn Royce', 21),
#  ('Brienne of Tarth', 'CH_31', 'CH_31', 'Samwell Tarly', 21),
#  ('Hodor', 'CH_102', 'CH_102', 'Rickon Stark', 20),
#  ('Jaime Lannister', 'CH_113', 'CH_113', 'Sansa Stark', 20),
#  ('Jon Snow', 'CH_123', 'CH_123', 'Pypar', 20),
#  ('Alliser Thorne', 'CH_5', 'CH_5', 'Samwell Tarly', 20),
#  ('Robb Stark', 'CH_286', 'CH_286', 'Roose Bolton', 20),
#  ('Grand Maester Pycelle', 'CH_78', 'CH_78', 'Tywin Lannister', 20),
#  ('Drogon', 'CH_57', 'CH_57', 'Missandei', 20),
#  ('Olenna Tyrell', 'CH_248', 'CH_248', 'Sansa Stark', 20),
#  ('Olenna Tyrell', 'CH_248', 'CH_248', 'Tyrion Lannister', 20),
#  ('Janos Slynt', 'CH_114', 'CH_114', 'Jon Snow', 20),
#  ('Ellaria Sand', 'CH_62', 'CH_62', 'Oberyn Martell', 20),
#  ('Nymeria Sand', 'CH_243', 'CH_243', 'Obara Sand', 20),
#  ('Jon Snow', 'CH_123', 'CH_123', 'Lyanna Mormont', 20),
#  ('Euron Greyjoy', 'CH_65', 'CH_65', 'Gregor Clegane', 20),
#  ('Jorah Mormont', 'CH_125', 'CH_125', 'Thoros of Myr', 20),
#  ('Bran Stark', 'CH_29', 'CH_29', 'Davos Seaworth', 20),
#  ('Bran Stark', 'CH_29', 'CH_29', 'Grey Worm', 20),
#  ('Davos Seaworth', 'CH_47', 'CH_47', 'Gendry', 20),
#  ('Bran Stark', 'CH_29', 'CH_29', 'Jaime Lannister', 19),
#  ('Daenerys Targaryen', 'CH_44', 'CH_44', 'Doreah', 19),
#  ('Lord Varys', 'CH_177', 'CH_177', 'Petyr Baelish', 19),
#  ('Gregor Clegane', 'CH_87', 'CH_87', 'Sandor Clegane', 19),
#  ('Jon Snow', 'CH_123', 'CH_123', 'Othell Yarwyck', 19),
#  ('Lord Varys', 'CH_177', 'CH_177', 'Sandor Clegane', 19),
#  ('Bronn', 'CH_32', 'CH_32', 'Podrick Payne', 19),
#  ('Arya Stark', 'CH_15', 'CH_15', 'Thoros of Myr', 19),
#  ('Drogon', 'CH_57', 'CH_57', 'Grey Worm', 19),
#  ('Alliser Thorne', 'CH_5', 'CH_5', 'Janos Slynt', 19),
#  ('Mace Tyrell', 'CH_185', 'CH_185', 'Oberyn Martell', 19),
#  ('Alliser Thorne', 'CH_5', 'CH_5', 'Eddison Tollett', 19),
#  ('Arya Stark', 'CH_15', 'CH_15', 'The Waif', 19),
#  ('Jon Snow', 'CH_123', 'CH_123', 'Wun Wun', 19),
#  ('Tormund Giantsbane', 'CH_345', 'CH_345', 'Wun Wun', 19),
#  ('Thoros of Myr', 'CH_338', 'CH_338', 'Tormund Giantsbane', 19),
#  ('Jon Snow', 'CH_123', 'CH_123', 'Thoros of Myr', 19),
#  ('Davos Seaworth', 'CH_47', 'CH_47', 'Theon Greyjoy', 19),
#  ('Missandei', 'CH_216', 'CH_216', 'Theon Greyjoy', 19),
#  ('Lord Varys', 'CH_177', 'CH_177', 'Theon Greyjoy', 19),
#  ('Brienne of Tarth', 'CH_31', 'CH_31', 'Theon Greyjoy', 19),
#  ('Jon Snow', 'CH_123', 'CH_123', 'Yohn Royce', 19),
#  ('Grey Worm', 'CH_91', 'CH_91', 'Yohn Royce', 19),
#  ('Daenerys Targaryen', 'CH_44', 'CH_44', 'Irri', 18),
#  ('Grenn', 'CH_89', 'CH_89', 'Rast', 18),
#  ('Pypar', 'CH_262', 'CH_262', 'Samwell Tarly', 18),
#  ('Cersei Lannister', 'CH_38', 'CH_38', 'Meryn Trant', 18),
#  ('Arya Stark', 'CH_15', 'CH_15', 'Beric Dondarrion', 18),
#  ('Loras Tyrell', 'CH_174', 'CH_174', 'Mace Tyrell', 18),
#  ('Eddison Tollett', 'CH_60', 'CH_60', 'Olly', 18),
#  ('Ellaria Sand', 'CH_62', 'CH_62', 'Tyene Sand', 18),
#  ('Hizdahr zo Loraq', 'CH_101', 'CH_101', 'Missandei', 18),
#  ('Davos Seaworth', 'CH_47', 'CH_47', 'Eddison Tollett', 18),
#  ('Jorah Mormont', 'CH_125', 'CH_125', 'Qhono', 18),
#  ('Jon Snow', 'CH_123', 'CH_123', 'The Night King', 18),
#  ('Cersei Lannister', 'CH_38', 'CH_38', 'Missandei', 18),
#  ('Jaime Lannister', 'CH_113', 'CH_113', 'Missandei', 18),
#  ('Gregor Clegane', 'CH_87', 'CH_87', 'Missandei', 18),
#  ('Lord Varys', 'CH_177', 'CH_177', 'Qhono', 18),
#  ('Lyanna Mormont', 'CH_182', 'CH_182', 'Sansa Stark', 18),
#  ('Tyrion Lannister', 'CH_349', 'CH_349', 'Yohn Royce', 18),
#  ('Grey Worm', 'CH_91', 'CH_91', 'Jaime Lannister', 18),
#  ('Davos Seaworth', 'CH_47', 'CH_47', 'Samwell Tarly', 18),
#  ('Jaime Lannister', 'CH_113', 'CH_113', 'Tormund Giantsbane', 18),
#  ('Jaime Lannister', 'CH_113', 'CH_113', 'Joffrey Baratheon', 17),
#  ('Jaime Lannister', 'CH_113', 'CH_113', 'Tommen Baratheon', 17),
#  ('Jorah Mormont', 'CH_125', 'CH_125', 'Rhaegal', 17),
#  ('Eddard Stark', 'CH_59', 'CH_59', 'Petyr Baelish', 17),
#  ('Jeor Mormont', 'CH_118', 'CH_118', 'Jon Snow', 17),
#  ('Grenn', 'CH_89', 'CH_89', 'Pypar', 17),
#  ('Grand Maester Pycelle', 'CH_78', 'CH_78', 'Joffrey Baratheon', 17),
#  ('Grand Maester Pycelle', 'CH_78', 'CH_78', 'Tommen Baratheon', 17),
#  ('Jeor Mormont', 'CH_118', 'CH_118', 'Samwell Tarly', 17),
#  ('Meera Reed', 'CH_205', 'CH_205', 'Summer', 17),
#  ('Joffrey Baratheon', 'CH_120', 'CH_120', 'Olenna Tyrell', 17),
#  ('Ramsay Snow', 'CH_269', 'CH_269', 'Roose Bolton', 17),
#  ('Gregor Clegane', 'CH_87', 'CH_87', 'Lord Varys', 17),
#  ('Jon Snow', 'CH_123', 'CH_123', 'Stannis Baratheon', 17),
#  ('Brienne of Tarth', 'CH_31', 'CH_31', 'Sandor Clegane', 17),
#  ('Ramsay Snow', 'CH_269', 'CH_269', 'Tormund Giantsbane', 17),
#  ('Euron Greyjoy', 'CH_65', 'CH_65', 'Qyburn', 17),
#  ('Daenerys Targaryen', 'CH_44', 'CH_44', 'Tormund Giantsbane', 17),
#  ('Jaime Lannister', 'CH_113', 'CH_113', 'Jorah Mormont', 17),
#  ('Jorah Mormont', 'CH_125', 'CH_125', 'Theon Greyjoy', 17),
#  ('Lyanna Mormont', 'CH_182', 'CH_182', 'Yohn Royce', 17),
#  ('Missandei', 'CH_216', 'CH_216', 'Sansa Stark', 17),
#  ('Lord Varys', 'CH_177', 'CH_177', 'Podrick Payne', 17),
#  ('Bran Stark', 'CH_29', 'CH_29', 'Samwell Tarly', 17),
#  ('Jaime Lannister', 'CH_113', 'CH_113', 'Samwell Tarly', 17),
#  ('Cersei Lannister', 'CH_38', 'CH_38', 'Sandor Clegane', 16),
#  ('Alliser Thorne', 'CH_5', 'CH_5', 'Othell Yarwyck', 16),
#  ('Dagmer Cleftjaw', 'CH_45', 'CH_45', 'Theon Greyjoy', 16),
#  ('Sansa Stark', 'CH_300', 'CH_300', 'Tywin Lannister', 16),
#  ('Jaime Lannister', 'CH_113', 'CH_113', 'Locke', 16),
#  ('Olenna Tyrell', 'CH_248', 'CH_248', 'Tywin Lannister', 16),
#  ('Jaime Lannister', 'CH_113', 'CH_113', 'Oberyn Martell', 16),
#  ('Olly', 'CH_249', 'CH_249', 'Samwell Tarly', 16),
#  ('Petyr Baelish', 'CH_257', 'CH_257', 'Yohn Royce', 16),
#  ('Arya Stark', 'CH_15', 'CH_15', 'Brienne of Tarth', 16),
#  ('Bran Stark', 'CH_29', 'CH_29', 'Leaf', 16),
#  ('Ramsay Snow', 'CH_269', 'CH_269', 'Sansa Stark', 16),
#  ('Daenerys Targaryen', 'CH_44', 'CH_44', 'Sandor Clegane', 16),
#  ('The Night King', 'CH_332', 'CH_332', 'White Walker', 16),
#  ('Qyburn', 'CH_267', 'CH_267', 'Tyrion Lannister', 16),
#  ('Qhono', 'CH_263', 'CH_263', 'Theon Greyjoy', 16),
#  ('Cersei Lannister', 'CH_38', 'CH_38', 'Daenerys Targaryen', 16),
#  ('Davos Seaworth', 'CH_47', 'CH_47', 'Sandor Clegane', 16),
#  ('Daenerys Targaryen', 'CH_44', 'CH_44', 'Yohn Royce', 16),
#  ('Gendry', 'CH_70', 'CH_70', 'Samwell Tarly', 16),
#  ('Euron Greyjoy', 'CH_65', 'CH_65', 'Missandei', 16),
#  ('Jorah Mormont', 'CH_125', 'CH_125', 'Samwell Tarly', 16),
#  ('Rodrik Cassel', 'CH_290', 'CH_290', 'Theon Greyjoy', 15),
#  ('Eddard Stark', 'CH_59', 'CH_59', 'Jory Cassel', 15),
#  ('Jaime Lannister', 'CH_113', 'CH_113', 'Myrcella Baratheon', 15),
#  ('Grand Maester Pycelle', 'CH_78', 'CH_78', 'Petyr Baelish', 15),
#  ('Meryn Trant', 'CH_211', 'CH_211', 'Sansa Stark', 15),
#  ('Daenerys Targaryen', 'CH_44', 'CH_44', 'Kovarro', 15),
#  ('Podrick Payne', 'CH_258', 'CH_258', 'Sandor Clegane', 15),
#  ('Lord Varys', 'CH_177', 'CH_177', 'Tywin Lannister', 15),
#  ('Edmure Tully', 'CH_61', 'CH_61', 'Robb Stark', 15),
#  ('Catelyn Stark', 'CH_36', 'CH_36', 'Edmure Tully', 15),
#  ('Jon Snow', 'CH_123', 'CH_123', 'Orell', 15),
#  ('Olenna Tyrell', 'CH_248', 'CH_248', 'Tommen Baratheon', 15),
#  ('Obara Sand', 'CH_244', 'CH_244', 'Tyene Sand', 15),
#  ('Nymeria Sand', 'CH_243', 'CH_243', 'Tyene Sand', 15),
#  ('Brienne of Tarth', 'CH_31', 'CH_31', 'Qhono', 15),
#  ('Daenerys Targaryen', 'CH_44', 'CH_44', 'Gregor Clegane', 15),
#  ('Missandei', 'CH_216', 'CH_216', 'Sandor Clegane', 15),
#  ('Grey Worm', 'CH_91', 'CH_91', 'Sansa Stark', 15),
#  ('Bran Stark', 'CH_29', 'CH_29', 'Lord Varys', 15),
#  ('Brienne of Tarth', 'CH_31', 'CH_31', 'Lyanna Mormont', 15),
#  ('Samwell Tarly', 'CH_298', 'CH_298', 'Tyrion Lannister', 15),
#  ('Davos Seaworth', 'CH_47', 'CH_47', 'Podrick Payne', 15),
#  ('Podrick Payne', 'CH_258', 'CH_258', 'Samwell Tarly', 15),
#  ('Arya Stark', 'CH_15', 'CH_15', 'Daenerys Targaryen', 15),
#  ('Robb Stark', 'CH_286', 'CH_286', 'Rodrik Cassel', 14),
#  ('Maester Luwin', 'CH_188', 'CH_188', 'Theon Greyjoy', 14),
#  ('Sandor Clegane', 'CH_299', 'CH_299', 'Theon Greyjoy', 14),
#  ('Grenn', 'CH_89', 'CH_89', 'Jeor Mormont', 14),
#  ('Daenerys Targaryen', 'CH_44', 'CH_44', 'Rakharo', 14),
#  ('Rast', 'CH_271', 'CH_271', 'Samwell Tarly', 14),
#  ('Cersei Lannister', 'CH_38', 'CH_38', 'Petyr Baelish', 14),
#  ('Grand Maester Pycelle', 'CH_78', 'CH_78', 'Sansa Stark', 14),
#  ('Joffrey Baratheon', 'CH_120', 'CH_120', 'Lord Varys', 14),
#  ('Joffrey Baratheon', 'CH_120', 'CH_120', 'Podrick Payne', 14),
#  ('Brynden Tully', 'CH_34', 'CH_34', 'Edmure Tully', 14),
#  ('Orell', 'CH_251', 'CH_251', 'Ygritte', 14),
#  ('Catelyn Stark', 'CH_36', 'CH_36', 'Roose Bolton', 14),
#  ('Joffrey Baratheon', 'CH_120', 'CH_120', 'Mace Tyrell', 14),
#  ('Jon Snow', 'CH_123', 'CH_123', 'Mance Rayder', 14),
#  ('Kevan Lannister', 'CH_132', 'CH_132', 'Mace Tyrell', 14),
#  ('Grand Maester Pycelle', 'CH_78', 'CH_78', 'Qyburn', 14),
#  ('Missandei', 'CH_216', 'CH_216', 'Qyburn', 14),
#  ('Lord Varys', 'CH_177', 'CH_177', 'Qyburn', 14),
#  ('Daenerys Targaryen', 'CH_44', 'CH_44', 'Qyburn', 14),
#  ('Lord Varys', 'CH_177', 'CH_177', 'Yohn Royce', 14),
#  ('Arya Stark', 'CH_15', 'CH_15', 'Davos Seaworth', 14),
#  ('Bran Stark', 'CH_29', 'CH_29', 'The Night King', 14),
#  ('Grey Worm', 'CH_91', 'CH_91', 'Samwell Tarly', 14),
#  ('Bran Stark', 'CH_29', 'CH_29', 'Missandei', 14),
#  ('Daenerys Targaryen', 'CH_44', 'CH_44', 'Euron Greyjoy', 14),
#  ('Euron Greyjoy', 'CH_65', 'CH_65', 'Tyrion Lannister', 14),
#  ('Bran Stark', 'CH_29', 'CH_29', 'Young Ned Stark', 14),
#  ('Bran Stark', 'CH_29', 'CH_29', 'Robb Stark', 13),
#  ('Arya Stark', 'CH_15', 'CH_15', 'Eddard Stark', 13),
#  ('Bran Stark', 'CH_29', 'CH_29', 'Maester Luwin', 13),
#  ('Eddard Stark', 'CH_59', 'CH_59', 'Robert Baratheon', 13),
#  ('Jorah Mormont', 'CH_125', 'CH_125', 'Viserion', 13),
#  ('Doreah', 'CH_53', 'CH_53', 'Jorah Mormont', 13),
#  ('Doreah', 'CH_53', 'CH_53', 'Irri', 13),
#  ('Alliser Thorne', 'CH_5', 'CH_5', 'Grenn', 13),
#  ('Jorah Mormont', 'CH_125', 'CH_125', 'Rakharo', 13),
#  ('Catelyn Stark', 'CH_36', 'CH_36', 'Walder Frey', 13),
#  ('Meryn Trant', 'CH_211', 'CH_211', 'Tyrion Lannister', 13),
#  ('Brienne of Tarth', 'CH_31', 'CH_31', 'Catelyn Stark', 13),
#  ('Roose Bolton', 'CH_291', 'CH_291', 'Talisa Maegyr', 13),
#  ('Loras Tyrell', 'CH_174', 'CH_174', 'Tywin Lannister', 13),
#  ('Grand Maester Pycelle', 'CH_78', 'CH_78', 'Margaery Tyrell', 13),
#  ('Meera Reed', 'CH_205', 'CH_205', 'Osha', 13),
#  ('Jojen Reed', 'CH_121', 'CH_121', 'Summer', 13),
#  ('Anguy', 'CH_9', 'CH_9', 'Arya Stark', 13),
#  ('Brynden Tully', 'CH_34', 'CH_34', 'Catelyn Stark', 13),
#  ('Cersei Lannister', 'CH_38', 'CH_38', 'High Septon', 13),
#  ('Orell', 'CH_251', 'CH_251', 'Tormund Giantsbane', 13),
#  ('Styr', 'CH_325', 'CH_325', 'Ygritte', 13),
#  ('Ellaria Sand', 'CH_62', 'CH_62', 'Tyrion Lannister', 13),
#  ('Mace Tyrell', 'CH_185', 'CH_185', 'Olenna Tyrell', 13),
#  ('Eddison Tollett', 'CH_60', 'CH_60', 'Janos Slynt', 13),
#  ('Davos Seaworth', 'CH_47', 'CH_47', 'Ramsay Snow', 13),
#  ('Daenerys Targaryen', 'CH_44', 'CH_44', 'Theon Greyjoy', 13),
#  ('Brienne of Tarth', 'CH_31', 'CH_31', 'Gendry', 13),
#  ('Euron Greyjoy', 'CH_65', 'CH_65', 'Lord Varys', 13),
#  ('Arya Stark', 'CH_15', 'CH_15', 'Yohn Royce', 13),
#  ('Missandei', 'CH_216', 'CH_216', 'Yohn Royce', 13),
#  ('Jaime Lannister', 'CH_113', 'CH_113', 'Theon Greyjoy', 12),
#  ('Jorah Mormont', 'CH_125', 'CH_125', 'Khal Drogo', 12),
#  ('Irri', 'CH_109', 'CH_109', 'Jorah Mormont', 12),
#  ('Eddard Stark', 'CH_59', 'CH_59', 'Lord Varys', 12),
#  ('Loras Tyrell', 'CH_174', 'CH_174', 'Sansa Stark', 12),
#  ('Arya Stark', 'CH_15', 'CH_15', 'Yoren', 12),
#  ('Gilly', 'CH_73', 'CH_73', 'Jon Snow', 12),
#  ('Davos Seaworth', 'CH_47', 'CH_47', 'Matthos Seaworth', 12),
#  ('Selyse Baratheon', 'CH_301', 'CH_301', 'Stannis Baratheon', 12),
#  ('Daenerys Targaryen', 'CH_44', 'CH_44', 'Xaro Xhoan Daxos', 12),
#  ('Jojen Reed', 'CH_121', 'CH_121', 'Osha', 12),
#  ('Anguy', 'CH_9', 'CH_9', 'Thoros of Myr', 12),
#  ('Brienne of Tarth', 'CH_31', 'CH_31', 'Locke', 12),
#  ('Brynden Tully', 'CH_34', 'CH_34', 'Robb Stark', 12),
#  ('Loras Tyrell', 'CH_174', 'CH_174', 'Tyrion Lannister', 12),
#  ('High Septon', 'CH_98', 'CH_98', 'Joffrey Baratheon', 12),
#  ('Edmure Tully', 'CH_61', 'CH_61', 'Talisa Maegyr', 12),
#  ('Styr', 'CH_325', 'CH_325', 'Tormund Giantsbane', 12),
#  ('Janos Slynt', 'CH_114', 'CH_114', 'Samwell Tarly', 12),
#  ('Janos Slynt', 'CH_114', 'CH_114', 'Olly', 12),
#  ('Olly', 'CH_249', 'CH_249', 'Othell Yarwyck', 12),
#  ('Cersei Lannister', 'CH_38', 'CH_38', 'Septa Unella', 12),
#  ('Daario Naharis', 'CH_43', 'CH_43', 'Tyrion Lannister', 12),
#  ('Ramsay Snow', 'CH_269', 'CH_269', 'Smalljon Umber', 12),
#  ('Brienne of Tarth', 'CH_31', 'CH_31', 'Qyburn', 12),
#  ('Bran Stark', 'CH_29', 'CH_29', 'Lyanna Mormont', 12),
#  ('Gendry', 'CH_70', 'CH_70', 'Podrick Payne', 12),
#  ('Bran Stark', 'CH_29', 'CH_29', 'Podrick Payne', 12),
#  ('Daenerys Targaryen', 'CH_44', 'CH_44', 'Podrick Payne', 12),
#  ('Grey Worm', 'CH_91', 'CH_91', 'Podrick Payne', 12),
#  ('Areo Hotah', 'CH_11', 'CH_11', 'Doran Martell', 12),
#  ('Jaime Lannister', 'CH_113', 'CH_113', 'Yohn Royce', 12),
#  ('Eddard Stark', 'CH_59', 'CH_59', 'Sansa Stark', 11),
#  ('Catelyn Stark', 'CH_36', 'CH_36', 'Theon Greyjoy', 11),
#  ('Jon Snow', 'CH_123', 'CH_123', 'Rast', 11),
#  ('Jeor Mormont', 'CH_118', 'CH_118', 'Rast', 11),
#  ('Jon Snow', 'CH_123', 'CH_123', 'Maester Aemon', 11),
#  ('Arya Stark', 'CH_15', 'CH_15', 'Petyr Baelish', 11),
#  ('Loras Tyrell', 'CH_174', 'CH_174', 'Tommen Baratheon', 11),
#  ('Maester Aemon', 'CH_186', 'CH_186', 'Samwell Tarly', 11),
#  ('Othell Yarwyck', 'CH_254', 'CH_254', 'Samwell Tarly', 11),
#  ('Meryn Trant', 'CH_211', 'CH_211', 'Sandor Clegane', 11),
#  ('Dontos Hollard', 'CH_51', 'CH_51', 'Sansa Stark', 11),
#  ('Jorah Mormont', 'CH_125', 'CH_125', 'Kovarro', 11),
#  ('Melisandre', 'CH_208', 'CH_208', 'Selyse Baratheon', 11),
#  ('Brienne of Tarth', 'CH_31', 'CH_31', 'Petyr Baelish', 11),
#  ('High Septon', 'CH_98', 'CH_98', 'Margaery Tyrell', 11),
#  ('Mace Tyrell', 'CH_185', 'CH_185', 'Sansa Stark', 11),
#  ('Lord Varys', 'CH_177', 'CH_177', 'Mace Tyrell', 11),
#  ('Arya Stark', 'CH_15', 'CH_15', 'Podrick Payne', 11),
#  ('Myrcella Baratheon', 'CH_229', 'CH_229', 'Trystane Martell', 11),
#  ('Davos Seaworth', 'CH_47', 'CH_47', 'Ghost', 11),
#  ('Alliser Thorne', 'CH_5', 'CH_5', 'Bowen Marsh', 11),
#  ('Bobono', 'CH_26', 'CH_26', 'Izembaro', 11),
#  ('Rhaegal', 'CH_278', 'CH_278', 'Tyrion Lannister', 11),
#  ('Drogon', 'CH_57', 'CH_57', 'Lord Varys', 11),
#  ('Euron Greyjoy', 'CH_65', 'CH_65', 'Yara Greyjoy', 11),
#  ('Qhono', 'CH_263', 'CH_263', 'Sandor Clegane', 11),
#  ('Grey Worm', 'CH_91', 'CH_91', 'Lyanna Mormont', 11),
#  ('Missandei', 'CH_216', 'CH_216', 'Podrick Payne', 11),
#  ('Daenerys Targaryen', 'CH_44', 'CH_44', 'Samwell Tarly', 11),
#  ('Arya Stark', 'CH_15', 'CH_15', 'Tyrion Lannister', 11),
#  ('Arya Stark', 'CH_15', 'CH_15', 'Grey Worm', 11),
#  ('Margaery Tyrell', 'CH_199', 'CH_199', 'Oberyn Martell', 11),
#  ('Tormund Giantsbane', 'CH_345', 'CH_345', 'Tyrion Lannister', 11),
#  ('Jorah Mormont', 'CH_125', 'CH_125', 'Lyanna Mormont', 11),
#  ('Catelyn Stark', 'CH_36', 'CH_36', 'Eddard Stark', 10),
#  ('Daenerys Targaryen', 'CH_44', 'CH_44', 'Viserys Targaryen', 10),
#  ('Ilyn Payne', 'CH_108', 'CH_108', 'Sansa Stark', 10),
#  ('Eddard Stark', 'CH_59', 'CH_59', 'Grand Maester Pycelle', 10),
#  ('Alliser Thorne', 'CH_5', 'CH_5', 'Pypar', 10),
#  ('Pypar', 'CH_262', 'CH_262', 'Rast', 10),
#  ('Grand Maester Pycelle', 'CH_78', 'CH_78', 'Gregor Clegane', 10),
#  ('Arya Stark', 'CH_15', 'CH_15', 'Lord Varys', 10),
#  ('Catelyn Stark', 'CH_36', 'CH_36', 'Joyeuse Erenford', 10),
#  ('Jon Snow', 'CH_123', 'CH_123', 'White Walker', 10),
#  ('Eddison Tollett', 'CH_60', 'CH_60', 'Jeor Mormont', 10),
#  ('Cersei Lannister', 'CH_38', 'CH_38', 'Podrick Payne', 10),
#  ('Edmure Tully', 'CH_61', 'CH_61', 'Lothar Frey', 10),
#  ('Talisa Maegyr', 'CH_328', 'CH_328', 'Walder Frey', 10),
#  ('Robb Stark', 'CH_286', 'CH_286', 'Walder Frey', 10),
#  ('Cersei Lannister', 'CH_38', 'CH_38', 'Shae', 10),
#  ('Ellaria Sand', 'CH_62', 'CH_62', 'Jaime Lannister', 10),
#  ('Grand Maester Pycelle', 'CH_78', 'CH_78', 'Oberyn Martell', 10),
#  ('Loras Tyrell', 'CH_174', 'CH_174', 'Oberyn Martell', 10),
#  ('Jaime Lannister', 'CH_113', 'CH_113', 'Olenna Tyrell', 10),
#  ('Grenn', 'CH_89', 'CH_89', 'Janos Slynt', 10),
#  ('Alliser Thorne', 'CH_5', 'CH_5', 'Tormund Giantsbane', 10),
#  ('Cersei Lannister', 'CH_38', 'CH_38', 'Kevan Lannister', 10),
#  ('Myranda', 'CH_228', 'CH_228', 'Ramsay Snow', 10),
#  ('Cersei Lannister', 'CH_38', 'CH_38', 'High Sparrow', 10),
#  ('Eddison Tollett', 'CH_60', 'CH_60', 'Wun Wun', 10),
#  ('Margaery Tyrell', 'CH_199', 'CH_199', 'Septa Unella', 10),
#  ('Bowen Marsh', 'CH_27', 'CH_27', 'Othell Yarwyck', 10),
#  ('Bowen Marsh', 'CH_27', 'CH_27', 'Jon Snow', 10),
#  ('Arya Stark', 'CH_15', 'CH_15', 'Lady Crane', 10),
#  ('Leaf', 'CH_159', 'CH_159', 'Meera Reed', 10),
#  ('Leaf', 'CH_159', 'CH_159', 'Three-Eyed Raven', 10),
#  ('Dickon Tarly', 'CH_48', 'CH_48', 'Randyll Tarly', 10),
#  ('Lyanna Mormont', 'CH_182', 'CH_182', 'Tormund Giantsbane', 10),
#  ('Ramsay Snow', 'CH_269', 'CH_269', 'Wun Wun', 10),
#  ('High Sparrow', 'CH_100', 'CH_100', 'Mace Tyrell', 10),
#  ('Euron Greyjoy', 'CH_65', 'CH_65', 'Jaime Lannister', 10),
#  ('Drogon', 'CH_57', 'CH_57', 'The Night King', 10),
#  ('Rhaegal', 'CH_278', 'CH_278', 'The Night King', 10),
#  ('Daenerys Targaryen', 'CH_44', 'CH_44', 'The Night King', 10),
#  ('Brienne of Tarth', 'CH_31', 'CH_31', 'Cersei Lannister', 10),
#  ('Daenerys Targaryen', 'CH_44', 'CH_44', 'Lyanna Mormont', 10),
#  ('Samwell Tarly', 'CH_298', 'CH_298', 'Sansa Stark', 10),
#  ('Gendry', 'CH_70', 'CH_70', 'Tyrion Lannister', 10),
#  ('Gendry', 'CH_70', 'CH_70', 'Jaime Lannister', 10),
#  ('Gendry', 'CH_70', 'CH_70', 'Grey Worm', 10),
#  ('Arya Stark', 'CH_15', 'CH_15', 'Samwell Tarly', 10),
#  ('Ghost', 'CH_72', 'CH_72', 'Tormund Giantsbane', 10),
#  ('Robett Glover', 'CH_288', 'CH_288', 'Sansa Stark', 10),
#  ('Podrick Payne', 'CH_258', 'CH_258', 'Yohn Royce', 10),
#  ('Tormund Giantsbane', 'CH_345', 'CH_345', 'Yohn Royce', 10),
#  ('Robett Glover', 'CH_288', 'CH_288', 'Yohn Royce', 10),
#  ('Melisandre', 'CH_208', 'CH_208', 'Tormund Giantsbane', 10),
#  ('Jaime Lannister', 'CH_113', 'CH_113', 'Lyanna Mormont', 10),
#  ('Grey Worm', 'CH_91', 'CH_91', 'Tormund Giantsbane', 10),
#  ('Jon Snow', 'CH_123', 'CH_123', 'Rickon Stark', 9),
#  ('Sansa Stark', 'CH_300', 'CH_300', 'Septa Mordane', 9),
#  ('Hodor', 'CH_102', 'CH_102', 'Maester Luwin', 9),
#  ('Jaime Lannister', 'CH_113', 'CH_113', 'Sandor Clegane', 9),
#  ('Cersei Lannister', 'CH_38', 'CH_38', 'Eddard Stark', 9),
#  ('Cersei Lannister', 'CH_38', 'CH_38', 'Theon Greyjoy', 9),
#  ('Myrcella Baratheon', 'CH_229', 'CH_229', 'Tommen Baratheon', 9),
#  ('Petyr Baelish', 'CH_257', 'CH_257', 'Renly Baratheon', 9),
#  ('Irri', 'CH_109', 'CH_109', 'Rakharo', 9),
#  ('Joffrey Baratheon', 'CH_120', 'CH_120', 'Loras Tyrell', 9),
#  ('Grand Maester Pycelle', 'CH_78', 'CH_78', 'Loras Tyrell', 9),
#  ('Maester Luwin', 'CH_188', 'CH_188', 'Osha', 9),
#  ('Arya Stark', 'CH_15', 'CH_15', 'Meryn Trant', 9),
#  ('Joyeuse Erenford', 'CH_127', 'CH_127', 'Walder Frey', 9),
#  ('Cersei Lannister', 'CH_38', 'CH_38', 'Lancel Lannister', 9),
#  ('Arya Stark', 'CH_15', 'CH_15', 'Tywin Lannister', 9),
#  ('Eddison Tollett', 'CH_60', 'CH_60', 'Ghost', 9),
#  ('Hallyne', 'CH_92', 'CH_92', 'Tyrion Lannister', 9),
#  ('Lord Varys', 'CH_177', 'CH_177', 'Margaery Tyrell', 9),
#  ('Jojen Reed', 'CH_121', 'CH_121', 'Rickon Stark', 9),
#  ('Meera Reed', 'CH_205', 'CH_205', 'Rickon Stark', 9),
#  ('Anguy', 'CH_9', 'CH_9', 'Gendry', 9),
#  ('Black Walder Rivers', 'CH_25', 'CH_25', 'Lothar Frey', 9),
#  ('Lothar Frey', 'CH_179', 'CH_179', 'Walder Frey', 9),
#  ('Thenn Warg', 'CH_335', 'CH_335', 'Ygritte', 9),
#  ('Thenn Warg', 'CH_335', 'CH_335', 'Tormund Giantsbane', 9),
#  ('Styr', 'CH_325', 'CH_325', 'Thenn Warg', 9),
#  ('Grand Maester Pycelle', 'CH_78', 'CH_78', 'Jaime Lannister', 9),
#  ('Cersei Lannister', 'CH_38', 'CH_38', 'Ellaria Sand', 9),
#  ('Jaime Lannister', 'CH_113', 'CH_113', 'Loras Tyrell', 9),
#  ('Jon Snow', 'CH_123', 'CH_123', 'Locke', 9),
#  ('High Sparrow', 'CH_100', 'CH_100', 'Loras Tyrell', 9),
#  ('Tyrion Lannister', 'CH_349', 'CH_349', 'Yezzan zo Qaggaz', 9),
#  ('Selyse Baratheon', 'CH_301', 'CH_301', 'Shireen Baratheon', 9),
#  ('Harald Karstark', 'CH_95', 'CH_95', 'Ramsay Snow', 9),
#  ('Eddison Tollett', 'CH_60', 'CH_60', 'Melisandre', 9),
#  ('Bianca', 'CH_22', 'CH_22', 'Izembaro', 9),
#  ('Bianca', 'CH_22', 'CH_22', 'Bobono', 9),
#  ('Dickon Tarly', 'CH_48', 'CH_48', 'Jaime Lannister', 9),
#  ('Jaime Lannister', 'CH_113', 'CH_113', 'Randyll Tarly', 9),
#  ('Bronn', 'CH_32', 'CH_32', 'Drogon', 9),
#  ('Jaime Lannister', 'CH_113', 'CH_113', 'Qhono', 9),
#  ('Alys Karstark', 'CH_7', 'CH_7', 'Bran Stark', 9),
#  ('Eleanor', 'CH_740', 'CH_740', "Eleanor's Daughter", 9),
#  ('Samwell Tarly', 'CH_298', 'CH_298', 'Yohn Royce', 9),
#  ('Mance Rayder', 'CH_195', 'CH_195', 'Tormund Giantsbane', 9),
#  ("Jaqen H'ghar", 'CH_115', 'CH_115', 'The Waif', 9),
#  ('High Sparrow', 'CH_100', 'CH_100', 'Septa Unella', 9),
#  ('Bowen Marsh', 'CH_27', 'CH_27', 'Olly', 9),
#  ('Three-Eyed Raven', 'CH_339', 'CH_339', 'Young Ned Stark', 9),
#  ('Alys Karstark', 'CH_7', 'CH_7', 'Davos Seaworth', 9),
#  ('Jon Snow', 'CH_123', 'CH_123', 'Robett Glover', 9),
#  ('Alys Karstark', 'CH_7', 'CH_7', 'Yohn Royce', 9),
#  ('Maester Wolkan', 'CH_189', 'CH_189', 'Sansa Stark', 9),
#  ('Euron Greyjoy', 'CH_65', 'CH_65', 'Theon Greyjoy', 9),
#  ('Brynden Tully', 'CH_34', 'CH_34', 'Talisa Maegyr', 9),
#  ('Barristan Selmy', 'CH_19', 'CH_19', 'Hizdahr zo Loraq', 9),
#  ('Eddison Tollett', 'CH_60', 'CH_60', 'Othell Yarwyck', 9),
#  ('Jorah Mormont', 'CH_125', 'CH_125', 'Yohn Royce', 9),
#  ('Jorah Mormont', 'CH_125', 'CH_125', 'Podrick Payne', 9),
#  ('Bran Stark', 'CH_29', 'CH_29', 'Jorah Mormont', 9),
#  ('Lord Varys', 'CH_177', 'CH_177', 'Tormund Giantsbane', 9),
#  ('Doran Martell', 'CH_52', 'CH_52', 'Ellaria Sand', 9),
#  ('Bran Stark', 'CH_29', 'CH_29', 'Eddard Stark', 8),
#  ('Bran Stark', 'CH_29', 'CH_29', 'Catelyn Stark', 8),
#  ('Shaggydog', 'CH_311', 'CH_311', 'Summer', 8),
#  ('Eddard Stark', 'CH_59', 'CH_59', 'Joffrey Baratheon', 8),
#  ('Eddard Stark', 'CH_59', 'CH_59', 'Sandor Clegane', 8),
#  ('Cersei Lannister', 'CH_38', 'CH_38', 'Jon Snow', 8),
#  ('Cersei Lannister', 'CH_38', 'CH_38', 'Robert Baratheon', 8),
#  ('Arya Stark', 'CH_15', 'CH_15', 'Jaime Lannister', 8),
#  ('Cersei Lannister', 'CH_38', 'CH_38', 'Ilyn Payne', 8),
#  ('Eddard Stark', 'CH_59', 'CH_59', 'Renly Baratheon', 8),
#  ('Joffrey Baratheon', 'CH_120', 'CH_120', 'Petyr Baelish', 8),
#  ('Greatjon Umber', 'CH_86', 'CH_86', 'Theon Greyjoy', 8),
#  ('Greatjon Umber', 'CH_86', 'CH_86', 'Robb Stark', 8),
#  ('Osha', 'CH_253', 'CH_253', 'Shaggydog', 8),
#  ('Rickon Stark', 'CH_285', 'CH_285', 'Shaggydog', 8),
#  ('Petyr Baelish', 'CH_257', 'CH_257', 'Tyrion Lannister', 8),
#  ('Craster', 'CH_42', 'CH_42', 'Jeor Mormont', 8),
#  ('Davos Seaworth', 'CH_47', 'CH_47', 'Selyse Baratheon', 8),
#  ('Arya Stark', 'CH_15', 'CH_15', 'Polliver', 8),
#  ('Lancel Lannister', 'CH_152', 'CH_152', 'Sandor Clegane', 8),
#  ('Joffrey Baratheon', 'CH_120', 'CH_120', 'Lancel Lannister', 8),
#  ('Lancel Lannister', 'CH_152', 'CH_152', 'Tyrion Lannister', 8),
#  ('Osha', 'CH_253', 'CH_253', 'Summer', 8),
#  ('Eddison Tollett', 'CH_60', 'CH_60', 'Rast', 8),
#  ('Missandei', 'CH_216', 'CH_216', 'Rhaegal', 8),
#  ('Loras Tyrell', 'CH_174', 'CH_174', 'Olenna Tyrell', 8),
#  ('Grand Maester Pycelle', 'CH_78', 'CH_78', 'Olenna Tyrell', 8),
#  ('Lord Varys', 'CH_177', 'CH_177', 'Olenna Tyrell', 8),
#  ('High Septon', 'CH_98', 'CH_98', 'Tywin Lannister', 8),
#  ('Ellaria Sand', 'CH_62', 'CH_62', 'Tywin Lannister', 8),
#  ('Lord Varys', 'CH_177', 'CH_177', 'Oberyn Martell', 8),
#  ('Hodor', 'CH_102', 'CH_102', 'Three-Eyed Raven', 8),
#  ('Meera Reed', 'CH_205', 'CH_205', 'Three-Eyed Raven', 8),
#  ('Samwell Tarly', 'CH_298', 'CH_298', 'Stannis Baratheon', 8),
#  ('Ellaria Sand', 'CH_62', 'CH_62', 'Obara Sand', 8),
#  ('Ellaria Sand', 'CH_62', 'CH_62', 'Nymeria Sand', 8),
#  ('High Sparrow', 'CH_100', 'CH_100', 'Tommen Baratheon', 8),
#  ('Hizdahr zo Loraq', 'CH_101', 'CH_101', 'Jorah Mormont', 8),
#  ('Grand Maester Pycelle', 'CH_78', 'CH_78', 'Kevan Lannister', 8),
#  ('Bobono', 'CH_26', 'CH_26', 'Camello', 8),
#  ('Izembaro', 'CH_110', 'CH_110', 'Lady Crane', 8),
#  ('Bianca', 'CH_22', 'CH_22', 'Lady Crane', 8),
#  ('Bobono', 'CH_26', 'CH_26', 'Lady Crane', 8),
#  ('Arya Stark', 'CH_15', 'CH_15', 'Bianca', 8),
#  ('Arya Stark', 'CH_15', 'CH_15', 'Bobono', 8),
#  ('Hodor', 'CH_102', 'CH_102', 'Leaf', 8),
#  ('Smalljon Umber', 'CH_314', 'CH_314', 'Tormund Giantsbane', 8),
#  ('Jon Snow', 'CH_123', 'CH_123', 'Smalljon Umber', 8),
#  ('Ramsay Snow', 'CH_269', 'CH_269', 'Rickon Stark', 8),
#  ('Kevan Lannister', 'CH_132', 'CH_132', 'Margaery Tyrell', 8),
#  ('Bronn', 'CH_32', 'CH_32', 'Daenerys Targaryen', 8),
#  ('Drogon', 'CH_57', 'CH_57', 'Jaime Lannister', 8),
#  ('Beric Dondarrion', 'CH_21', 'CH_21', 'Daenerys Targaryen', 8),
#  ('Lyanna Mormont', 'CH_182', 'CH_182', 'Tyrion Lannister', 8),
#  ('Lord Varys', 'CH_177', 'CH_177', 'Lyanna Mormont', 8),
#  ('Gilly', 'CH_73', 'CH_73', 'Sansa Stark', 8),
#  ('Gilly', 'CH_73', 'CH_73', 'Lord Varys', 8),
#  ('Lord Varys', 'CH_177', 'CH_177', 'Samwell Tarly', 8),
#  ('Gregor Clegane', 'CH_87', 'CH_87', 'Grey Worm', 8),
#  ('Cersei Lannister', 'CH_38', 'CH_38', 'Grey Worm', 8),
#  ('Euron Greyjoy', 'CH_65', 'CH_65', 'Grey Worm', 8),
#  ('Drogon', 'CH_57', 'CH_57', 'Euron Greyjoy', 8),
#  ('Cersei Lannister', 'CH_38', 'CH_38', 'Drogon', 8),
#  ('Robin Arryn', 'CH_289', 'CH_289', 'Sansa Stark', 8),
#  ('Robin Arryn', 'CH_289', 'CH_289', 'Yohn Royce', 8),
#  ('Olly', 'CH_249', 'CH_249', 'Tormund Giantsbane', 8),
#  ('Petyr Baelish', 'CH_257', 'CH_257', 'Robin Arryn', 8),
#  ('High Septon', 'CH_98', 'CH_98', 'Tommen Baratheon', 8),
#  ('Alys Karstark', 'CH_7', 'CH_7', 'Brienne of Tarth', 8),
#  ('Davos Seaworth', 'CH_47', 'CH_47', 'Robett Glover', 8),
#  ('Lyanna Mormont', 'CH_182', 'CH_182', 'Robett Glover', 8),
#  ('Alys Karstark', 'CH_7', 'CH_7', 'Lyanna Mormont', 8),
#  ('Lyanna Mormont', 'CH_182', 'CH_182', 'Missandei', 8),
#  ('Beric Dondarrion', 'CH_21', 'CH_21', 'Eddison Tollett', 8),
#  ('Podrick Payne', 'CH_258', 'CH_258', 'Theon Greyjoy', 8),
#  ('Bran Stark', 'CH_29', 'CH_29', 'Wyllis', 8),
#  ('Davos Seaworth', 'CH_47', 'CH_47', 'Olly', 8),
#  ('Bran Stark', 'CH_29', 'CH_29', 'Shaggydog', 7),
#  ('Rickon Stark', 'CH_285', 'CH_285', 'Summer', 7),
#  ('Maester Luwin', 'CH_188', 'CH_188', 'Rickon Stark', 7),
#  ('Catelyn Stark', 'CH_36', 'CH_36', 'Jaime Lannister', 7),
#  ('Sandor Clegane', 'CH_299', 'CH_299', 'Tommen Baratheon', 7),
#  ('Khal Drogo', 'CH_133', 'CH_133', 'Viserys Targaryen', 7),
#  ('Daenerys Targaryen', 'CH_44', 'CH_44', 'Qotho', 7),
#  ('Khal Drogo', 'CH_133', 'CH_133', 'Qotho', 7),
#  ('Jorah Mormont', 'CH_125', 'CH_125', 'Viserys Targaryen', 7),
#  ('Irri', 'CH_109', 'CH_109', 'Khal Drogo', 7),
#  ('Khal Drogo', 'CH_133', 'CH_133', 'Rakharo', 7),
#  ('Gregor Clegane', 'CH_87', 'CH_87', 'Tommen Baratheon', 7),
#  ('Osha', 'CH_253', 'CH_253', 'Theon Greyjoy', 7),
#  ('Doreah', 'CH_53', 'CH_53', 'Rakharo', 7),
#  ('Alliser Thorne', 'CH_5', 'CH_5', 'Maester Aemon', 7),
#  ('Daenerys Targaryen', 'CH_44', 'CH_44', 'Mirri Maz Duur', 7),
#  ('Catelyn Stark', 'CH_36', 'CH_36', 'Greatjon Umber', 7),
#  ('Greatjon Umber', 'CH_86', 'CH_86', 'Rodrik Cassel', 7),
#  ('Rickard Karstark', 'CH_283', 'CH_283', 'Robb Stark', 7),
#  ('Meryn Trant', 'CH_211', 'CH_211', 'Tommen Baratheon', 7),
#  ('Bronn', 'CH_32', 'CH_32', 'Sandor Clegane', 7),
#  ('Balon Greyjoy', 'CH_17', 'CH_17', 'Yara Greyjoy', 7),
#  ('Jon Snow', 'CH_123', 'CH_123', 'Qhorin Halfhand', 7),
#  ('Dagmer Cleftjaw', 'CH_45', 'CH_45', 'Maester Luwin', 7),
#  ('Kovarro', 'CH_147', 'CH_147', 'Xaro Xhoan Daxos', 7),
#  ('Jon Snow', 'CH_123', 'CH_123', 'Rattleshirt', 7),
#  ('Hallyne', 'CH_92', 'CH_92', 'Joffrey Baratheon', 7),
#  ('Anguy', 'CH_9', 'CH_9', 'Sandor Clegane', 7),
#  ('Karl Tanner', 'CH_128', 'CH_128', 'Rast', 7),
#  ('Lothar Frey', 'CH_179', 'CH_179', 'Robb Stark', 7),
#  ('Missandei', 'CH_216', 'CH_216', 'Viserion', 7),
#  ('Edmure Tully', 'CH_61', 'CH_61', 'Walder Frey', 7),
#  ('Roose Bolton', 'CH_291', 'CH_291', 'Walder Frey', 7),
#  ('Janos Slynt', 'CH_114', 'CH_114', 'Maester Aemon', 7),
#  ('Davos Seaworth', 'CH_47', 'CH_47', 'Shireen Baratheon', 7),
#  ('Ellaria Sand', 'CH_62', 'CH_62', 'Olyvar', 7),
#  ('Oberyn Martell', 'CH_245', 'CH_245', 'Olyvar', 7),
#  ('Gregor Clegane', 'CH_87', 'CH_87', 'Mace Tyrell', 7),
#  ('Dongo the Giant', 'CH_49', 'CH_49', 'Mag the Mighty', 7),
#  ('Donnel Hill', 'CH_600', 'CH_600', 'Grenn', 7),
#  ('Cooper', 'CH_601', 'CH_601', 'Grenn', 7),
#  ('Cooper', 'CH_601', 'CH_601', 'Donnel Hill', 7),
#  ('Jaime Lannister', 'CH_113', 'CH_113', 'Trystane Martell', 7),
#  ('Hizdahr zo Loraq', 'CH_101', 'CH_101', 'Tyrion Lannister', 7),
#  ('Tormund Giantsbane', 'CH_345', 'CH_345', 'White Walker', 7),
#  ('Mace Tyrell', 'CH_185', 'CH_185', 'Meryn Trant', 7),
#  ('Shireen Baratheon', 'CH_312', 'CH_312', 'Stannis Baratheon', 7),
#  ('Baratheon General', 'CH_659', 'CH_659', 'Stannis Baratheon', 7),
#  ('Jon Snow', 'CH_123', 'CH_123', "Loyal Night's Watchman #1", 7),
#  ('Davos Seaworth', 'CH_47', 'CH_47', "Loyal Night's Watchman #1", 7),
#  ('Jon Snow', 'CH_123', 'CH_123', "Loyal Night's Watchman #2", 7),
#  ('Davos Seaworth', 'CH_47', 'CH_47', "Loyal Night's Watchman #2", 7),
#  ("Loyal Night's Watchman #1", 'CH_180', 'CH_180', "Loyal Night's Watchman #2", 7),
#  ('Brienne of Tarth', 'CH_31', 'CH_31', 'Eddison Tollett', 7),
#  ('Bianca', 'CH_22', 'CH_22', 'Clarenzo', 7),
#  ('Bobono', 'CH_26', 'CH_26', 'Clarenzo', 7),
#  ('Bianca', 'CH_22', 'CH_22', 'Camello', 7),
#  ('Clarenzo', 'CH_690', 'CH_690', 'Lady Crane', 7),
#  ('Camello', 'CH_689', 'CH_689', 'Lady Crane', 7),
#  ('Clarenzo', 'CH_690', 'CH_690', 'Izembaro', 7),
#  ('Arya Stark', 'CH_15', 'CH_15', 'Izembaro', 7),
#  ('Camello', 'CH_689', 'CH_689', 'Izembaro', 7),
#  ('Camello', 'CH_689', 'CH_689', 'Margaery Tyrell Mummer', 7),
#  ('Bobono', 'CH_26', 'CH_26', 'Margaery Tyrell Mummer', 7),
#  ('Harald Karstark', 'CH_95', 'CH_95', 'Smalljon Umber', 7),
#  ('Davos Seaworth', 'CH_47', 'CH_47', 'Wun Wun', 7),
#  ('Kevan Lannister', 'CH_132', 'CH_132', 'Loras Tyrell', 7),
#  ('High Sparrow', 'CH_100', 'CH_100', 'Lancel Lannister', 7),
#  ('Lord Varys', 'CH_177', 'CH_177', 'Rhaegal', 7),
#  ('Tyrion Lannister', 'CH_349', 'CH_349', 'Viserion', 7),
#  ('Drogon', 'CH_57', 'CH_57', 'Qhono', 7),
#  ('Drogon', 'CH_57', 'CH_57', 'Tormund Giantsbane', 7),
#  ('Drogon', 'CH_57', 'CH_57', 'Sandor Clegane', 7),
#  ('Gregor Clegane', 'CH_87', 'CH_87', 'Jon Snow', 7),
#  ('Cersei Lannister', 'CH_38', 'CH_38', 'Davos Seaworth', 7),
#  ('Cersei Lannister', 'CH_38', 'CH_38', 'Jorah Mormont', 7),
#  ('Gregor Clegane', 'CH_87', 'CH_87', 'Jorah Mormont', 7),
#  ('Qyburn', 'CH_267', 'CH_267', 'Theon Greyjoy', 7),
#  ('Gregor Clegane', 'CH_87', 'CH_87', 'Theon Greyjoy', 7),
#  ('Cersei Lannister', 'CH_38', 'CH_38', 'Qhono', 7),
#  ('Gregor Clegane', 'CH_87', 'CH_87', 'Qhono', 7),
#  ('Jon Snow', 'CH_123', 'CH_123', 'Qyburn', 7),
#  ('Davos Seaworth', 'CH_47', 'CH_47', 'Qyburn', 7),
#  ('Jorah Mormont', 'CH_125', 'CH_125', 'Qyburn', 7),
#  ('Qhono', 'CH_263', 'CH_263', 'Qyburn', 7),
#  ('Davos Seaworth', 'CH_47', 'CH_47', 'Gregor Clegane', 7),
#  ('Brienne of Tarth', 'CH_31', 'CH_31', 'Gregor Clegane', 7),
#  ('Qyburn', 'CH_267', 'CH_267', 'Sandor Clegane', 7),
#  ('Gilly', 'CH_73', 'CH_73', 'Tyrion Lannister', 7),
#  ('Gilly', 'CH_73', 'CH_73', 'Missandei', 7),
#  ('Missandei', 'CH_216', 'CH_216', 'Samwell Tarly', 7),
#  ('Davos Seaworth', 'CH_47', 'CH_47', 'Gilly', 7),
#  ('Grey Worm', 'CH_91', 'CH_91', 'Qyburn', 7),
#  ('Bronn', 'CH_32', 'CH_32', 'Obara Sand', 7),
#  ('Bronn', 'CH_32', 'CH_32', 'Tyene Sand', 7),
#  ('Bronn', 'CH_32', 'CH_32', 'Nymeria Sand', 7),
#  ('Karsi', 'CH_129', 'CH_129', 'Tormund Giantsbane', 7),
#  ('Jon Snow', 'CH_123', 'CH_123', 'Karsi', 7),
#  ('Alys Karstark', 'CH_7', 'CH_7', 'Jon Snow', 7),
#  ('Lyanna Mormont', 'CH_182', 'CH_182', 'Podrick Payne', 7),
#  ('Jon Snow', 'CH_123', 'CH_123', 'Petyr Baelish', 7),
#  ('Davos Seaworth', 'CH_47', 'CH_47', 'Drogon', 7),
#  ('Alys Karstark', 'CH_7', 'CH_7', 'Tyrion Lannister', 7),
#  ('Drogon', 'CH_57', 'CH_57', 'Gregor Clegane', 7),
#  ('Bronn', 'CH_32', 'CH_32', 'Davos Seaworth', 7),
#  ('Brienne of Tarth', 'CH_31', 'CH_31', 'Bronn', 7),
#  ('Olly', 'CH_249', 'CH_249', 'Stannis Baratheon', 7),
#  ('Aeron Greyjoy', 'CH_2', 'CH_2', 'Euron Greyjoy', 7),
#  ('Jorah Mormont', 'CH_125', 'CH_125', 'Sansa Stark', 7),
#  ('Arya Stark', 'CH_15', 'CH_15', 'Missandei', 7),
#  ('Eddison Tollett', 'CH_60', 'CH_60', 'Stannis Baratheon', 7),
#  ('Areo Hotah', 'CH_11', 'CH_11', 'Ellaria Sand', 7),
#  ('Areo Hotah', 'CH_11', 'CH_11', 'Myrcella Baratheon', 7),
#  ('Bowen Marsh', 'CH_27', 'CH_27', 'Eddison Tollett', 7),
#  ('Eddard Stark', 'CH_59', 'CH_59', 'Jon Snow', 6),
#  ('Jon Snow', 'CH_123', 'CH_123', 'Robb Stark', 6),
#  ('Eddard Stark', 'CH_59', 'CH_59', 'Theon Greyjoy', 6),
#  ('Bran Stark', 'CH_29', 'CH_29', 'Rodrik Cassel', 6),
#  ('Eddard Stark', 'CH_59', 'CH_59', 'Rodrik Cassel', 6),
#  ('Grey Wind', 'CH_90', 'CH_90', 'Robb Stark', 6),
#  ('Arya Stark', 'CH_15', 'CH_15', 'Joffrey Baratheon', 6),
#  ('Bran Stark', 'CH_29', 'CH_29', 'Sandor Clegane', 6),
#  ('Hodor', 'CH_102', 'CH_102', 'Theon Greyjoy', 6),
#  ('Joffrey Baratheon', 'CH_120', 'CH_120', 'Robert Baratheon', 6),
#  ('Benjen Stark', 'CH_20', 'CH_20', 'Jon Snow', 6),
#  ('Benjen Stark', 'CH_20', 'CH_20', 'Tyrion Lannister', 6),
#  ('Doreah', 'CH_53', 'CH_53', 'Drogon', 6),
#  ('Grand Maester Pycelle', 'CH_78', 'CH_78', 'Renly Baratheon', 6),
#  ('Janos Slynt', 'CH_114', 'CH_114', 'Petyr Baelish', 6),
#  ('Janos Slynt', 'CH_114', 'CH_114', 'Lord Varys', 6),
#  ('Ghost', 'CH_72', 'CH_72', 'Grenn', 6),
#  ('Catelyn Stark', 'CH_36', 'CH_36', 'Tyrion Lannister', 6),
#  ('Barristan Selmy', 'CH_19', 'CH_19', 'Eddard Stark', 6),
#  ('Loras Tyrell', 'CH_174', 'CH_174', 'Renly Baratheon', 6),
#  ('Robin Arryn', 'CH_289', 'CH_289', 'Tyrion Lannister', 6),
#  ('Maester Aemon', 'CH_186', 'CH_186', 'Othell Yarwyck', 6),
#  ('Jorah Mormont', 'CH_125', 'CH_125', 'Mirri Maz Duur', 6),
#  ('Catelyn Stark', 'CH_36', 'CH_36', 'Rickard Karstark', 6),
#  ('Arya Stark', 'CH_15', 'CH_15', 'Lommy Greenhands', 6),
#  ('Hot Pie', 'CH_104', 'CH_104', 'Lommy Greenhands', 6),
#  ('Gendry', 'CH_70', 'CH_70', 'Lommy Greenhands', 6),
#  ('Gendry', 'CH_70', 'CH_70', 'Yoren', 6),
#  ('Bronn', 'CH_32', 'CH_32', 'Myrcella Baratheon', 6),
#  ('Brienne of Tarth', 'CH_31', 'CH_31', 'Renly Baratheon', 6),
#  ('Gregor Clegane', 'CH_87', 'CH_87', 'Tywin Lannister', 6),
#  ('Rattleshirt', 'CH_272', 'CH_272', 'Ygritte', 6),
#  ('Hallyne', 'CH_92', 'CH_92', 'Podrick Payne', 6),
#  ('Mandon Moore', 'CH_196', 'CH_196', 'Tyrion Lannister', 6),
#  ('Samwell Tarly', 'CH_298', 'CH_298', 'White Walker', 6),
#  ('Karl Tanner', 'CH_128', 'CH_128', 'Samwell Tarly', 6),
#  ('Jeor Mormont', 'CH_118', 'CH_118', 'Karl Tanner', 6),
#  ('Anguy', 'CH_9', 'CH_9', 'Beric Dondarrion', 6),
#  ('Catelyn Stark', 'CH_36', 'CH_36', 'Lothar Frey', 6),
#  ('Black Walder Rivers', 'CH_25', 'CH_25', 'Edmure Tully', 6),
#  ('Missandei', 'CH_216', 'CH_216', 'Razdal mo Eraz', 6),
#  ('Grey Worm', 'CH_91', 'CH_91', 'Razdal mo Eraz', 6),
#  ('Grand Maester Pycelle', 'CH_78', 'CH_78', 'High Septon', 6),
#  ('Edmure Tully', 'CH_61', 'CH_61', 'Roslin Frey', 6),
#  ('Catelyn Stark', 'CH_36', 'CH_36', 'Roslin Frey', 6),
#  ('Roose Bolton', 'CH_291', 'CH_291', 'Roslin Frey', 6),
#  ('Lothar Frey', 'CH_179', 'CH_179', 'Talisa Maegyr', 6),
#  ('Joyeuse Erenford', 'CH_127', 'CH_127', 'Robb Stark', 6),
#  ('Edmure Tully', 'CH_61', 'CH_61', 'Roose Bolton', 6),
#  ('Black Walder Rivers', 'CH_25', 'CH_25', 'Walder Frey', 6),
#  ('Janos Slynt', 'CH_114', 'CH_114', 'Othell Yarwyck', 6),
#  ('Roose Bolton', 'CH_291', 'CH_291', 'Theon Greyjoy', 6),
#  ('Ellaria Sand', 'CH_62', 'CH_62', 'Mace Tyrell', 6),
#  ('Oberyn Martell', 'CH_245', 'CH_245', 'Tommen Baratheon', 6),
#  ('Ellaria Sand', 'CH_62', 'CH_62', 'Grand Maester Pycelle', 6),
#  ('Musician #1', 'CH_219', 'CH_219', 'Musician #2', 6),
#  ('Musician #1', 'CH_219', 'CH_219', 'Musician #3', 6),
#  ('Musician #2', 'CH_221', 'CH_221', 'Musician #3', 6),
#  ('Daenerys Targaryen', 'CH_44', 'CH_44', 'Oznak zo Pahl', 6),
#  ('Daario Naharis', 'CH_43', 'CH_43', 'Oznak zo Pahl', 6),
#  ('Grenn', 'CH_89', 'CH_89', 'Olly', 6),
#  ('High Sparrow', 'CH_100', 'CH_100', 'Olenna Tyrell', 6),
#  ('Alliser Thorne', 'CH_5', 'CH_5', 'Davos Seaworth', 6),
#  ('Ramsay Snow', 'CH_269', 'CH_269', 'Walda Bolton', 6),
#  ('Akho', 'CH_4', 'CH_4', 'Daenerys Targaryen', 6),
#  ('Akho', 'CH_4', 'CH_4', 'Qhono', 6),
#  ('Missandei', 'CH_216', 'CH_216', 'Yezzan zo Qaggaz', 6),
#  ('Grey Worm', 'CH_91', 'CH_91', 'Yezzan zo Qaggaz', 6),
#  ('Eddison Tollett', 'CH_60', 'CH_60', 'Sansa Stark', 6),
#  ('Arya Stark', 'CH_15', 'CH_15', 'Clarenzo', 6),
#  ('Arya Stark', 'CH_15', 'CH_15', 'Camello', 6),
#  ('Lady Crane', 'CH_151', 'CH_151', 'Margaery Tyrell Mummer', 6),
#  ('Izembaro', 'CH_110', 'CH_110', 'Margaery Tyrell Mummer', 6),
#  ('Bianca', 'CH_22', 'CH_22', 'Margaery Tyrell Mummer', 6),
#  ('Bran Stark', 'CH_29', 'CH_29', 'White Walker', 6),
#  ('Jaime Lannister', 'CH_113', 'CH_113', 'Lothar Frey', 6),
#  ('Davos Seaworth', 'CH_47', 'CH_47', 'Smalljon Umber', 6),
#  ('High Sparrow', 'CH_100', 'CH_100', 'Kevan Lannister', 6),
#  ('Arthur', 'CH_13', 'CH_13', 'Lancel Lannister', 6),
#  ('Little Bird #3', 'CH_165', 'CH_165', 'Qyburn', 6),
#  ('Bronn', 'CH_32', 'CH_32', 'Randyll Tarly', 6),
#  ('Bronn', 'CH_32', 'CH_32', 'Dickon Tarly', 6),
#  ('Rhaegal', 'CH_278', 'CH_278', 'Tormund Giantsbane', 6),
#  ('Beric Dondarrion', 'CH_21', 'CH_21', 'Drogon', 6),
#  ('The Night King', 'CH_332', 'CH_332', 'Tormund Giantsbane', 6),
#  ('Teela', 'CH_738', 'CH_738', 'Tyrion Lannister', 6),
#  ('Sansa Stark', 'CH_300', 'CH_300', 'Teela', 6),
#  ('Gilly', 'CH_73', 'CH_73', 'Teela', 6),
#  ('Lord Varys', 'CH_177', 'CH_177', 'Teela', 6),
#  ('Bran Stark', 'CH_29', 'CH_29', 'Gendry', 6),
#  ('Gendry', 'CH_70', 'CH_70', 'Sansa Stark', 6),
#  ('Gilly', 'CH_73', 'CH_73', 'Tormund Giantsbane', 6),
#  ('Arya Stark', 'CH_15', 'CH_15', 'Eleanor', 6),
#  ('Arya Stark', 'CH_15', 'CH_15', "Eleanor's Daughter", 6),
#  ('Gendry', 'CH_70', 'CH_70', 'Melisandre', 6),
#  ('Myranda', 'CH_228', 'CH_228', 'Theon Greyjoy', 6),
#  ('Grenn', 'CH_89', 'CH_89', 'Locke', 6),
#  ('Lord Varys', 'CH_177', 'CH_177', 'Tommen Baratheon', 6),
#  ('Petyr Baelish', 'CH_257', 'CH_257', 'Podrick Payne', 6),
#  ('High Septon', 'CH_98', 'CH_98', 'Mace Tyrell', 6),
#  ('Mace Tyrell', 'CH_185', 'CH_185', 'Qyburn', 6),
#  ('Areo Hotah', 'CH_11', 'CH_11', 'Tyene Sand', 6),
#  ('Daenerys Targaryen', 'CH_44', 'CH_44', 'High Priestess', 6),
#  ('High Priestess', 'CH_97', 'CH_97', 'Ornela', 6),
#  ('Daenerys Targaryen', 'CH_44', 'CH_44', 'Ornela', 6),
#  ('Leaf', 'CH_159', 'CH_159', 'The Night King', 6),
#  ('Brother Ray', 'CH_33', 'CH_33', 'Sandor Clegane', 6),
#  ('Gregor Clegane', 'CH_87', 'CH_87', 'Kevan Lannister', 6),
#  ('Alys Karstark', 'CH_7', 'CH_7', 'Sansa Stark', 6),
#  ('Petyr Baelish', 'CH_257', 'CH_257', 'Tormund Giantsbane', 6),
#  ('Brienne of Tarth', 'CH_31', 'CH_31', 'Robett Glover', 6),
#  ('Petyr Baelish', 'CH_257', 'CH_257', 'Robett Glover', 6),
#  ('Davos Seaworth', 'CH_47', 'CH_47', 'Rhaegal', 6),
#  ('Grey Worm', 'CH_91', 'CH_91', 'Hizdahr zo Loraq', 6),
#  ('Myranda', 'CH_228', 'CH_228', 'Sansa Stark', 6),
#  ('Drogon', 'CH_57', 'CH_57', 'Qyburn', 6),
#  ('Ned Umber', 'CH_230', 'CH_230', 'Sansa Stark', 6),
#  ('Jon Snow', 'CH_123', 'CH_123', 'Ned Umber', 6),
#  ('Alys Karstark', 'CH_7', 'CH_7', 'Lord Varys', 6),
#  ('Bran Stark', 'CH_29', 'CH_29', 'Tormund Giantsbane', 6),
#  ('Arya Stark', 'CH_15', 'CH_15', 'Tormund Giantsbane', 6),
#  ('Missandei', 'CH_216', 'CH_216', 'Tormund Giantsbane', 6),
#  ('Doran Martell', 'CH_52', 'CH_52', 'Myrcella Baratheon', 6),
#  ('Doran Martell', 'CH_52', 'CH_52', 'Trystane Martell', 6),
#  ('Areo Hotah', 'CH_11', 'CH_11', 'Trystane Martell', 6),
#  ('Areo Hotah', 'CH_11', 'CH_11', 'Jaime Lannister', 6),
#  ('High Sparrow', 'CH_100', 'CH_100', 'Jaime Lannister', 6),
#  ('Ghost', 'CH_72', 'CH_72', 'Jorah Mormont', 6),
#  ('Archmaester Ebrose', 'CH_724', 'CH_724', 'Samwell Tarly', 6),
#  ('Gared', 'CH_68', 'CH_68', 'Waymar Royce', 5),
#  ('Eddard Stark', 'CH_59', 'CH_59', 'Robb Stark', 5),
#  ('Arya Stark', 'CH_15', 'CH_15', 'Theon Greyjoy', 5),
#  ('Eddard Stark', 'CH_59', 'CH_59', 'Septa Mordane', 5),
#  ('Bran Stark', 'CH_29', 'CH_29', 'Ghost', 5),
#  ('Catelyn Stark', 'CH_36', 'CH_36', 'Maester Luwin', 5),
#  ('Myrcella Baratheon', 'CH_229', 'CH_229', 'Sandor Clegane', 5),
#  ('Robert Baratheon', 'CH_287', 'CH_287', 'Sansa Stark', 5),
#  ('Myrcella Baratheon', 'CH_229', 'CH_229', 'Sansa Stark', 5),
#  ('Arya Stark', 'CH_15', 'CH_15', 'Jory Cassel', 5),
#  ('Arya Stark', 'CH_15', 'CH_15', 'Cersei Lannister', 5),
#  ('Cersei Lannister', 'CH_38', 'CH_38', 'Myrcella Baratheon', 5),
#  ('Drogon', 'CH_57', 'CH_57', 'Khal Drogo', 5),
#  ('Jorah Mormont', 'CH_125', 'CH_125', 'Qotho', 5),
#  ('Khal Drogo', 'CH_133', 'CH_133', 'Rhaegal', 5),
#  ('Khal Drogo', 'CH_133', 'CH_133', 'Viserion', 5),
#  ('Doreah', 'CH_53', 'CH_53', 'Khal Drogo', 5),
#  ('Doreah', 'CH_53', 'CH_53', 'Viserys Targaryen', 5),
#  ('Irri', 'CH_109', 'CH_109', 'Viserys Targaryen', 5),
#  ('Ghost', 'CH_72', 'CH_72', 'Tyrion Lannister', 5),
#  ('Ghost', 'CH_72', 'CH_72', 'Rast', 5),
#  ('Eddard Stark', 'CH_59', 'CH_59', 'Royal Steward', 5),
#  ('Lord Varys', 'CH_177', 'CH_177', 'Renly Baratheon', 5),
#  ('Barristan Selmy', 'CH_19', 'CH_19', 'Robert Baratheon', 5),
#  ('Arya Stark', 'CH_15', 'CH_15', 'Syrio Forel', 5),
#  ('Renly Baratheon', 'CH_277', 'CH_277', 'Robert Baratheon', 5),
#  ('Barristan Selmy', 'CH_19', 'CH_19', 'Joffrey Baratheon', 5),
#  ('Petyr Baelish', 'CH_257', 'CH_257', 'Sandor Clegane', 5),
#  ('Arya Stark', 'CH_15', 'CH_15', 'Gregor Clegane', 5),
#  ('Barristan Selmy', 'CH_19', 'CH_19', 'Renly Baratheon', 5),
#  ('Bronn', 'CH_32', 'CH_32', 'Catelyn Stark', 5),
#  ('Bronn', 'CH_32', 'CH_32', 'Rodrik Cassel', 5),
#  ('Rodrik Cassel', 'CH_290', 'CH_290', 'Tyrion Lannister', 5),
#  ('Loras Tyrell', 'CH_174', 'CH_174', 'Petyr Baelish', 5),
#  ('Lysa Arryn', 'CH_184', 'CH_184', 'Robin Arryn', 5),
#  ('Petyr Baelish', 'CH_257', 'CH_257', 'Ros', 5),
#  ('Mirri Maz Duur', 'CH_215', 'CH_215', 'Rakharo', 5),
#  ('Matthos Seaworth', 'CH_204', 'CH_204', 'Stannis Baratheon', 5),
#  ('Brienne of Tarth', 'CH_31', 'CH_31', 'Margaery Tyrell', 5),
#  ('Amory Lorch', 'CH_8', 'CH_8', 'Arya Stark', 5),
#  ('Margaery Tyrell', 'CH_199', 'CH_199', 'Petyr Baelish', 5),
#  ('Daenerys Targaryen', 'CH_44', 'CH_44', 'Pyat Pree', 5),
#  ('Black Lorren', 'CH_24', 'CH_24', 'Theon Greyjoy', 5),
#  ('Black Lorren', 'CH_24', 'CH_24', 'Dagmer Cleftjaw', 5),
#  ('Hodor', 'CH_102', 'CH_102', 'Shaggydog', 5),
#  ('Mandon Moore', 'CH_196', 'CH_196', 'Podrick Payne', 5),
#  ('Craster', 'CH_42', 'CH_42', 'Karl Tanner', 5),
#  ('High Septon', 'CH_98', 'CH_98', 'Tyrion Lannister', 5),
#  ('Bronn', 'CH_32', 'CH_32', 'Lord Varys', 5),
#  ('Robb Stark', 'CH_286', 'CH_286', 'Roslin Frey', 5),
#  ('Roslin Frey', 'CH_294', 'CH_294', 'Walder Frey', 5),
#  ('Roslin Frey', 'CH_294', 'CH_294', 'Talisa Maegyr', 5),
#  ('Joyeuse Erenford', 'CH_127', 'CH_127', 'Talisa Maegyr', 5),
#  ('Shae', 'CH_309', 'CH_309', 'Tommen Baratheon', 5),
#  ('Ellaria Sand', 'CH_62', 'CH_62', 'Olenna Tyrell', 5),
#  ('Margaery Tyrell', 'CH_199', 'CH_199', 'Meryn Trant', 5),
#  ('Jaime Lannister', 'CH_113', 'CH_113', 'Meryn Trant', 5),
#  ('Missandei', 'CH_216', 'CH_216', 'Oznak zo Pahl', 5),
#  ('Barristan Selmy', 'CH_19', 'CH_19', 'Oznak zo Pahl', 5),
#  ('Jon Snow', 'CH_123', 'CH_123', 'Sissy', 5),
#  ('Ellaria Sand', 'CH_62', 'CH_62', 'Gregor Clegane', 5),
#  ('Ellaria Sand', 'CH_62', 'CH_62', 'Lord Varys', 5),
#  ('Mance Rayder', 'CH_195', 'CH_195', 'Stannis Baratheon', 5),
#  ('Eddison Tollett', 'CH_60', 'CH_60', 'Pypar', 5),
#  ('Janos Slynt', 'CH_114', 'CH_114', 'Pypar', 5),
#  ('Maester Aemon', 'CH_186', 'CH_186', 'Olly', 5),
#  ('Melisandre', 'CH_208', 'CH_208', 'Olly', 5),
#  ('Loras Tyrell', 'CH_174', 'CH_174', 'Olyvar', 5),
#  ('Grey Worm', 'CH_91', 'CH_91', 'Mossador', 5),
#  ('Melisandre', 'CH_208', 'CH_208', 'Samwell Tarly', 5),
#  ('Bronn', 'CH_32', 'CH_32', 'Trystane Martell', 5),
#  ('Daenerys Targaryen', 'CH_44', 'CH_44', 'Yezzan zo Qaggaz', 5),
#  ('Jorah Mormont', 'CH_125', 'CH_125', 'Yezzan zo Qaggaz', 5),
#  ('Jon Snow', 'CH_123', 'CH_123', 'Todder', 5),
#  ('Daario Naharis', 'CH_43', 'CH_43', 'Drogon', 5),
#  ('Razdal mo Eraz', 'CH_273', 'CH_273', 'Tyrion Lannister', 5),
#  ('Belicho Paenymion', 'CH_680', 'CH_680', 'Tyrion Lannister', 5),
#  ('Belicho Paenymion', 'CH_680', 'CH_680', 'Missandei', 5),
#  ...]

# %% [markdown]
# #### Interesting View
#
# - Create a view of the information that you think would be interesting to fans.
#
#
# - Explain what you view is producing.
#
# <u>Answer:</u>

# %% [markdown]
# ### Scenes and Locations
#
# Locations appear in the same scenes.
#
# Create a view of the form:
# - ```location```
# - ```scenesNo_1```
# - ```scenesNo_2```
# - ```count```
# - count of locations appear in the same scenes.

# %%
# %%sql
# CREATE VIEW `scenes_locations` AS
# select
#   a.location,
#   a.sceneNo as sceneNo_1,
#   b.sceneNo as sceneNo_2,
#   count(*) as count
# from
#   w4111gotsolutionclean.scenes as a
#   join
#   w4111gotsolutionclean.scenes as b
# using(seasonNum, episodeNum)
# where a.sceneNo = b.sceneNo
# group by location, sceneNo_1,sceneNo_2
# order by count desc;
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 0 rows affected.
# []

# %%
# %sql SELECT * FROM W4111GoTSolutionClean.scenes_locations;
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 1274 rows affected.
# [('The Crownlands', 25, 25, 30),
#  ('The Crownlands', 16, 16, 29),
#  ('The Crownlands', 24, 24, 29),
#  ('The Crownlands', 23, 23, 29),
#  ('The Crownlands', 10, 10, 27),
#  ('The Crownlands', 26, 26, 27),
#  ('The Crownlands', 13, 13, 26),
#  ('The Crownlands', 9, 9, 26),
#  ('The Crownlands', 18, 18, 26),
#  ('The Crownlands', 22, 22, 26),
#  ('The Crownlands', 17, 17, 25),
#  ('The Crownlands', 11, 11, 25),
#  ('The Crownlands', 14, 14, 25),
#  ('The Crownlands', 27, 27, 25),
#  ('The Crownlands', 21, 21, 25),
#  ('The Crownlands', 15, 15, 24),
#  ('The Crownlands', 12, 12, 24),
#  ('The Crownlands', 20, 20, 24),
#  ('The Crownlands', 3, 3, 22),
#  ('The Crownlands', 28, 28, 22),
#  ('The Crownlands', 1, 1, 21),
#  ('The Crownlands', 2, 2, 21),
#  ('The Crownlands', 4, 4, 21),
#  ('The Crownlands', 8, 8, 21),
#  ('The Crownlands', 19, 19, 21),
#  ('The Crownlands', 36, 36, 21),
#  ('The Crownlands', 5, 5, 20),
#  ('The Crownlands', 37, 37, 20),
#  ('The Crownlands', 6, 6, 19),
#  ('The North', 9, 9, 18),
#  ('The Crownlands', 34, 34, 18),
#  ('The Crownlands', 38, 38, 18),
#  ('The North', 14, 14, 17),
#  ('The North', 4, 4, 17),
#  ('The North', 12, 12, 17),
#  ('The North', 13, 13, 17),
#  ('The Crownlands', 7, 7, 17),
#  ('The Crownlands', 35, 35, 17),
#  ('The North', 5, 5, 16),
#  ('The North', 6, 6, 16),
#  ('The Crownlands', 29, 29, 16),
#  ('The Crownlands', 33, 33, 16),
#  ('The North', 15, 15, 15),
#  ('The North', 16, 16, 15),
#  ('The North', 18, 18, 15),
#  ('The North', 29, 29, 15),
#  ('The North', 30, 30, 15),
#  ('The North', 32, 32, 15),
#  ('The North', 8, 8, 15),
#  ('The North', 25, 25, 15),
#  ('The Crownlands', 32, 32, 15),
#  ('The North', 28, 28, 14),
#  ('The North', 31, 31, 14),
#  ('The North', 2, 2, 14),
#  ('The North', 3, 3, 14),
#  ('The North', 7, 7, 14),
#  ('The North', 10, 10, 14),
#  ('The North', 26, 26, 14),
#  ('The Crownlands', 30, 30, 14),
#  ('The Crownlands', 41, 41, 14),
#  ('The Crownlands', 39, 39, 14),
#  ('The North', 11, 11, 14),
#  ('The North', 19, 19, 13),
#  ('The North', 20, 20, 13),
#  ('The North', 24, 24, 13),
#  ('The North', 17, 17, 13),
#  ('The North', 33, 33, 13),
#  ('The Crownlands', 31, 31, 13),
#  ('The Crownlands', 40, 40, 13),
#  ('The Crownlands', 42, 42, 13),
#  ('The North', 27, 27, 12),
#  ('The North', 1, 1, 12),
#  ('The Crownlands', 45, 45, 12),
#  ('North of the Wall', 5, 5, 11),
#  ('The North', 22, 22, 11),
#  ('The North', 35, 35, 11),
#  ('The Riverlands', 7, 7, 11),
#  ('The Crownlands', 46, 46, 11),
#  ('North of the Wall', 4, 4, 10),
#  ('North of the Wall', 7, 7, 10),
#  ('The North', 21, 21, 10),
#  ('The North', 23, 23, 10),
#  ('The Riverlands', 23, 23, 10),
#  ('The Riverlands', 8, 8, 10),
#  ('The Riverlands', 19, 19, 10),
#  ('The North', 39, 39, 10),
#  ('The Crownlands', 47, 47, 10),
#  ('The Crownlands', 48, 48, 10),
#  ('The Wall', 1, 1, 9),
#  ('North of the Wall', 3, 3, 9),
#  ('North of the Wall', 9, 9, 9),
#  ('The North', 36, 36, 9),
#  ('The Riverlands', 21, 21, 9),
#  ('The North', 34, 34, 9),
#  ('The Riverlands', 2, 2, 9),
#  ('The Riverlands', 20, 20, 9),
#  ('The Riverlands', 1, 1, 9),
#  ('The North', 40, 40, 9),
#  ('The North', 43, 43, 9),
#  ('The North', 44, 44, 9),
#  ('The North', 38, 38, 9),
#  ('The Crownlands', 43, 43, 9),
#  ('The Crownlands', 44, 44, 9),
#  ('The Crownlands', 49, 49, 9),
#  ('The Crownlands', 50, 50, 9),
#  ('The Crownlands', 53, 53, 9),
#  ('The Wall', 2, 2, 9),
#  ('North of the Wall', 6, 6, 8),
#  ('North of the Wall', 11, 11, 8),
#  ('North of the Wall', 12, 12, 8),
#  ('The Riverlands', 22, 22, 8),
#  ('The Riverlands', 28, 28, 8),
#  ('The Wall', 19, 19, 8),
#  ('The Wall', 21, 21, 8),
#  ('The Wall', 30, 30, 8),
#  ('The North', 42, 42, 8),
#  ('The North', 41, 41, 8),
#  ('The Crownlands', 51, 51, 8),
#  ('The Crownlands', 52, 52, 8),
#  ('The Crownlands', 54, 54, 8),
#  ('The Crownlands', 55, 55, 8),
#  ('The Crownlands', 56, 56, 8),
#  ('North of the Wall', 36, 36, 8),
#  ('The Riverlands', 6, 6, 8),
#  ('North of the Wall', 29, 29, 8),
#  ('The Wall', 31, 31, 8),
#  ('North of the Wall', 8, 8, 7),
#  ('North of the Wall', 10, 10, 7),
#  ('North of the Wall', 13, 13, 7),
#  ('The Riverlands', 24, 24, 7),
#  ('The Riverlands', 26, 26, 7),
#  ('The Riverlands', 30, 30, 7),
#  ('The Wall', 12, 12, 7),
#  ('The Wall', 18, 18, 7),
#  ('The Wall', 5, 5, 7),
#  ('The Wall', 20, 20, 7),
#  ('North of the Wall', 19, 19, 7),
#  ('The Riverlands', 3, 3, 7),
#  ('The Riverlands', 4, 4, 7),
#  ('The Wall', 29, 29, 7),
#  ('North of the Wall', 34, 34, 7),
#  ('North of the Wall', 38, 38, 7),
#  ('The Crownlands', 57, 57, 7),
#  ('North of the Wall', 35, 35, 7),
#  ('North of the Wall', 32, 32, 7),
#  ('The Wall', 3, 3, 7),
#  ('The North', 37, 37, 7),
#  ('The Wall', 17, 17, 7),
#  ('The North', 67, 67, 7),
#  ('The North', 71, 71, 7),
#  ('The Wall', 15, 15, 6),
#  ('The Riverlands', 25, 25, 6),
#  ('The Wall', 22, 22, 6),
#  ('The Wall', 13, 13, 6),
#  ('The Wall', 6, 6, 6),
#  ('The Wall', 14, 14, 6),
#  ('The Wall', 11, 11, 6),
#  ('The Riverlands', 13, 13, 6),
#  ('The Riverlands', 14, 14, 6),
#  ('The Riverlands', 16, 16, 6),
#  ('The Riverlands', 17, 17, 6),
#  ('North of the Wall', 30, 30, 6),
#  ('North of the Wall', 31, 31, 6),
#  ('North of the Wall', 1, 1, 6),
#  ('The Riverlands', 27, 27, 6),
#  ('The Riverlands', 29, 29, 6),
#  ('The Riverlands', 15, 15, 6),
#  ('North of the Wall', 18, 18, 6),
#  ('The Riverlands', 32, 32, 6),
#  ('The Crownlands', 58, 58, 6),
#  ('The Crownlands', 59, 59, 6),
#  ('The Crownlands', 61, 61, 6),
#  ('North of the Wall', 44, 44, 6),
#  ('North of the Wall', 28, 28, 6),
#  ('The North', 45, 45, 6),
#  ('The Riverlands', 5, 5, 6),
#  ('North of the Wall', 33, 33, 6),
#  ('North of the Wall', 37, 37, 6),
#  ('North of the Wall', 46, 46, 6),
#  ('North of the Wall', 48, 48, 6),
#  ('The Wall', 37, 37, 6),
#  ('Meereen', 12, 12, 6),
#  ('Meereen', 14, 14, 6),
#  ('Meereen', 15, 15, 6),
#  ('The Wall', 33, 33, 6),
#  ('Meereen', 40, 40, 6),
#  ('Meereen', 43, 43, 6),
#  ('Meereen', 44, 44, 6),
#  ('The Wall', 43, 43, 6),
#  ('Meereen', 45, 45, 6),
#  ('Braavos', 3, 3, 6),
#  ('The Wall', 10, 10, 6),
#  ('The Wall', 4, 4, 6),
#  ('The North', 50, 50, 6),
#  ('The North', 54, 54, 6),
#  ('The North', 56, 56, 6),
#  ('The North', 58, 58, 6),
#  ('The North', 63, 63, 6),
#  ('The North', 65, 65, 6),
#  ('The North', 51, 51, 6),
#  ('The North', 52, 52, 6),
#  ('The North', 60, 60, 6),
#  ('The North', 61, 61, 6),
#  ('The North', 62, 62, 6),
#  ('The North', 66, 66, 6),
#  ('The North', 68, 68, 6),
#  ('North of the Wall', 2, 2, 5),
#  ('The Wall', 27, 27, 5),
#  ('The Wall', 7, 7, 5),
#  ('The Riverlands', 18, 18, 5),
#  ('The Crownlands', 60, 60, 5),
#  ('The Crownlands', 62, 62, 5),
#  ('The Crownlands', 63, 63, 5),
#  ('The Crownlands', 68, 68, 5),
#  ('The Crownlands', 69, 69, 5),
#  ('The Crownlands', 70, 70, 5),
#  ('The Crownlands', 71, 71, 5),
#  ('The Crownlands', 72, 72, 5),
#  ('The Crownlands', 73, 73, 5),
#  ('The Crownlands', 74, 74, 5),
#  ('The Crownlands', 75, 75, 5),
#  ('The Crownlands', 76, 76, 5),
#  ('The Crownlands', 77, 77, 5),
#  ('The Crownlands', 78, 78, 5),
#  ('The Crownlands', 79, 79, 5),
#  ('The Crownlands', 80, 80, 5),
#  ('The Crownlands', 81, 81, 5),
#  ('The Crownlands', 82, 82, 5),
#  ('The Crownlands', 85, 85, 5),
#  ('The Crownlands', 86, 86, 5),
#  ('North of the Wall', 42, 42, 5),
#  ('North of the Wall', 43, 43, 5),
#  ('North of the Wall', 27, 27, 5),
#  ('The Riverlands', 46, 46, 5),
#  ('The Riverlands', 47, 47, 5),
#  ('North of the Wall', 47, 47, 5),
#  ('North of the Wall', 49, 49, 5),
#  ('The Wall', 28, 28, 5),
#  ('The Wall', 32, 32, 5),
#  ('Meereen', 39, 39, 5),
#  ('Meereen', 41, 41, 5),
#  ('The Wall', 41, 41, 5),
#  ('The Wall', 42, 42, 5),
#  ('The Wall', 44, 44, 5),
#  ('Meereen', 46, 46, 5),
#  ('Meereen', 8, 8, 5),
#  ('North of the Wall', 39, 39, 5),
#  ('Braavos', 1, 1, 5),
#  ('Braavos', 2, 2, 5),
#  ('The Wall', 8, 8, 5),
#  ('The Wall', 16, 16, 5),
#  ('The North', 46, 46, 5),
#  ('The North', 47, 47, 5),
#  ('The North', 48, 48, 5),
#  ('The North', 49, 49, 5),
#  ('The North', 53, 53, 5),
#  ('The North', 55, 55, 5),
#  ('The North', 57, 57, 5),
#  ('The North', 59, 59, 5),
#  ('The North', 64, 64, 5),
#  ('The North', 69, 69, 5),
#  ('The North', 70, 70, 5),
#  ('The Wall', 9, 9, 4),
#  ('The Wall', 24, 24, 4),
#  ('The Vale', 17, 17, 4),
#  ('The Vale', 15, 15, 4),
#  ('The Riverlands', 9, 9, 4),
#  ('The Riverlands', 10, 10, 4),
#  ('The Riverlands', 11, 11, 4),
#  ('North of the Wall', 14, 14, 4),
#  ('North of the Wall', 15, 15, 4),
#  ('The Iron Islands', 21, 21, 4),
#  ('The Riverlands', 38, 38, 4),
#  ('The Riverlands', 31, 31, 4),
#  ('The Riverlands', 33, 33, 4),
#  ('North of the Wall', 16, 16, 4),
#  ('The Crownlands', 64, 64, 4),
#  ('The Crownlands', 65, 65, 4),
#  ('The Crownlands', 66, 66, 4),
#  ('The Crownlands', 67, 67, 4),
#  ('The Crownlands', 83, 83, 4),
#  ('The Crownlands', 84, 84, 4),
#  ('North of the Wall', 45, 45, 4),
#  ('North of the Wall', 25, 25, 4),
#  ('North of the Wall', 26, 26, 4),
#  ('North of the Wall', 17, 17, 4),
#  ('The Riverlands', 37, 37, 4),
#  ('The Riverlands', 40, 40, 4),
#  ('The Riverlands', 41, 41, 4),
#  ('North of the Wall', 50, 50, 4),
#  ('Meereen', 16, 16, 4),
#  ('Meereen', 42, 42, 4),
#  ('The Wall', 38, 38, 4),
#  ('The Wall', 40, 40, 4),
#  ('Meereen', 1, 1, 4),
#  ('Meereen', 2, 2, 4),
#  ('Meereen', 6, 6, 4),
#  ('Meereen', 7, 7, 4),
#  ('Meereen', 9, 9, 4),
#  ('Meereen', 10, 10, 4),
#  ('Meereen', 11, 11, 4),
#  ('Braavos', 4, 4, 4),
#  ('Braavos', 5, 5, 4),
#  ('Meereen', 23, 23, 4),
#  ('North of the Wall', 24, 24, 4),
#  ('The Wall', 45, 45, 4),
#  ('Meereen', 35, 35, 4),
#  ('Braavos', 34, 34, 4),
#  ('Braavos', 35, 35, 4),
#  ('The Wall', 34, 34, 4),
#  ('North of the Wall', 57, 57, 4),
#  ('The North', 75, 75, 4),
#  ('The North', 77, 77, 4),
#  ('The North', 81, 81, 4),
#  ('The North', 83, 83, 4),
#  ('The Vale', 23, 23, 3),
#  ('The Vale', 7, 7, 3),
#  ('Vaes Dothrak', 10, 10, 3),
#  ('The Westerlands', 1, 1, 3),
#  ('The Vale', 16, 16, 3),
#  ('The Westerlands', 31, 31, 3),
#  ('The Iron Islands', 20, 20, 3),
#  ('The Iron Islands', 22, 22, 3),
#  ('Qarth', 27, 27, 3),
#  ('Qarth', 28, 28, 3),
#  ('Qarth', 37, 37, 3),
#  ('The Crownlands', 87, 87, 3),
#  ('The Crownlands', 88, 88, 3),
#  ('The Crownlands', 89, 89, 3),
#  ('The Crownlands', 90, 90, 3),
#  ('The Crownlands', 98, 98, 3),
#  ('The Crownlands', 99, 99, 3),
#  ('The Crownlands', 100, 100, 3),
#  ('The Crownlands', 101, 101, 3),
#  ('The Crownlands', 102, 102, 3),
#  ('The Crownlands', 103, 103, 3),
#  ('The Crownlands', 104, 104, 3),
#  ('The Crownlands', 105, 105, 3),
#  ('The Crownlands', 106, 106, 3),
#  ('The Crownlands', 107, 107, 3),
#  ('The Crownlands', 108, 108, 3),
#  ('The Crownlands', 109, 109, 3),
#  ('The Crownlands', 110, 110, 3),
#  ('The Crownlands', 111, 111, 3),
#  ('The Crownlands', 112, 112, 3),
#  ('The Crownlands', 113, 113, 3),
#  ('The Riverlands', 34, 34, 3),
#  ('The Riverlands', 35, 35, 3),
#  ('The Riverlands', 48, 48, 3),
#  ('The Riverlands', 49, 49, 3),
#  ('The Riverlands', 39, 39, 3),
#  ('The Riverlands', 42, 42, 3),
#  ('The Wall', 25, 25, 3),
#  ('The Wall', 26, 26, 3),
#  ('The Riverlands', 44, 44, 3),
#  ('The Riverlands', 45, 45, 3),
#  ('Yunkai', 43, 43, 3),
#  ('The Riverlands', 36, 36, 3),
#  ('The Riverlands', 54, 54, 3),
#  ('The Riverlands', 55, 55, 3),
#  ('The Riverlands', 56, 56, 3),
#  ('The Wall', 36, 36, 3),
#  ('Meereen', 13, 13, 3),
#  ('Meereen', 17, 17, 3),
#  ('Meereen', 18, 18, 3),
#  ('The Wall', 39, 39, 3),
#  ('Meereen', 47, 47, 3),
#  ('Meereen', 48, 48, 3),
#  ('Meereen', 49, 49, 3),
#  ('Meereen', 50, 50, 3),
#  ('Meereen', 51, 51, 3),
#  ('Meereen', 3, 3, 3),
#  ('Meereen', 4, 4, 3),
#  ('Meereen', 5, 5, 3),
#  ('North of the Wall', 40, 40, 3),
#  ('North of the Wall', 41, 41, 3),
#  ('Meereen', 20, 20, 3),
#  ('Meereen', 22, 22, 3),
#  ('The Wall', 35, 35, 3),
#  ('North of the Wall', 56, 56, 3),
#  ('North of the Wall', 58, 58, 3),
#  ('The Wall', 62, 62, 3),
#  ('The Wall', 64, 64, 3),
#  ('The Wall', 65, 65, 3),
#  ('North of the Wall', 66, 66, 3),
#  ('The Wall', 74, 74, 3),
#  ('North of the Wall', 78, 78, 3),
#  ('The Wall', 84, 84, 3),
#  ('The Wall', 86, 86, 3),
#  ('North of the Wall', 22, 22, 3),
#  ('North of the Wall', 23, 23, 3),
#  ('Meereen', 34, 34, 3),
#  ('Meereen', 36, 36, 3),
#  ('Braavos', 36, 36, 3),
#  ('Braavos', 37, 37, 3),
#  ('Meereen', 38, 38, 3),
#  ('Braavos', 6, 6, 3),
#  ('Braavos', 7, 7, 3),
#  ('Braavos', 8, 8, 3),
#  ('Dorne', 24, 24, 3),
#  ('Dorne', 25, 25, 3),
#  ('North of the Wall', 51, 51, 3),
#  ('North of the Wall', 52, 52, 3),
#  ('North of the Wall', 53, 53, 3),
#  ('North of the Wall', 54, 54, 3),
#  ('North of the Wall', 55, 55, 3),
#  ('North of the Wall', 59, 59, 3),
#  ('Braavos', 27, 27, 3),
#  ('Braavos', 28, 28, 3),
#  ('Braavos', 29, 29, 3),
#  ('Braavos', 30, 30, 3),
#  ('Braavos', 31, 31, 3),
#  ('Braavos', 33, 33, 3),
#  ('Braavos', 40, 40, 3),
#  ('Braavos', 41, 41, 3),
#  ('The North', 73, 73, 3),
#  ('The North', 79, 79, 3),
#  ('The North', 85, 85, 3),
#  ('The Reach', 21, 21, 3),
#  ('The North', 84, 84, 3),
#  ('The North', 72, 72, 3),
#  ('The North', 78, 78, 3),
#  ('The Dothraki Sea', 20, 20, 2),
#  ('The Dothraki Sea', 23, 23, 2),
#  ('The Vale', 6, 6, 2),
#  ('The Vale', 22, 22, 2),
#  ('The Vale', 11, 11, 2),
#  ('Vaes Dothrak', 19, 19, 2),
#  ('Vaes Dothrak', 11, 11, 2),
#  ('Vaes Dothrak', 12, 12, 2),
#  ('Vaes Dothrak', 13, 13, 2),
#  ('Vaes Dothrak', 20, 20, 2),
#  ('The Vale', 18, 18, 2),
#  ('The Westerlands', 32, 32, 2),
#  ('The Red Waste', 15, 15, 2),
#  ('The Red Waste', 10, 10, 2),
#  ('The Iron Islands', 23, 23, 2),
#  ('The Iron Islands', 24, 24, 2),
#  ('The Stormlands', 7, 7, 2),
#  ('The Stormlands', 8, 8, 2),
#  ('The Iron Islands', 11, 11, 2),
#  ('The Westerlands', 2, 2, 2),
#  ('The Westerlands', 6, 6, 2),
#  ('The Westerlands', 7, 7, 2),
#  ('The Stormlands', 2, 2, 2),
#  ('The Stormlands', 3, 3, 2),
#  ('North of the Wall', 20, 20, 2),
#  ('Qarth', 29, 29, 2),
#  ('The Westerlands', 34, 34, 2),
#  ('The Westerlands', 36, 36, 2),
#  ('The Westerlands', 37, 37, 2),
#  ('The Westerlands', 39, 39, 2),
#  ('Qarth', 30, 30, 2),
#  ('The Westerlands', 9, 9, 2),
#  ('The Riverlands', 12, 12, 2),
#  ('Qarth', 38, 38, 2),
#  ('The Crownlands', 91, 91, 2),
#  ('The Crownlands', 92, 92, 2),
#  ('The Crownlands', 93, 93, 2),
#  ('The Crownlands', 94, 94, 2),
#  ('The Crownlands', 95, 95, 2),
#  ('The Crownlands', 96, 96, 2),
#  ('The Crownlands', 97, 97, 2),
#  ('The Crownlands', 114, 114, 2),
#  ('The Crownlands', 115, 115, 2),
#  ('The Crownlands', 116, 116, 2),
#  ('The Crownlands', 117, 117, 2),
#  ('The Crownlands', 118, 118, 2),
#  ('The Crownlands', 119, 119, 2),
#  ('The Crownlands', 120, 120, 2),
#  ('The Crownlands', 121, 121, 2),
#  ('The Crownlands', 122, 122, 2),
#  ('The Crownlands', 123, 123, 2),
#  ('The Crownlands', 124, 124, 2),
#  ('The Crownlands', 125, 125, 2),
#  ('The Crownlands', 126, 126, 2),
#  ('The Crownlands', 127, 127, 2),
#  ('The Crownlands', 128, 128, 2),
#  ('The Crownlands', 129, 129, 2),
#  ('The Crownlands', 130, 130, 2),
#  ('The Crownlands', 131, 131, 2),
#  ('The Crownlands', 132, 132, 2),
#  ('The Crownlands', 133, 133, 2),
#  ('Astapor', 47, 47, 2),
#  ('Astapor', 48, 48, 2),
#  ('Astapor', 49, 49, 2),
#  ('Astapor', 50, 50, 2),
#  ('Yunkai', 31, 31, 2),
#  ('Yunkai', 4, 4, 2),
#  ('Yunkai', 5, 5, 2),
#  ('Yunkai', 6, 6, 2),
#  ('Yunkai', 40, 40, 2),
#  ('Yunkai', 41, 41, 2),
#  ('Yunkai', 42, 42, 2),
#  ('Yunkai', 44, 44, 2),
#  ('The Riverlands', 50, 50, 2),
#  ('The Riverlands', 51, 51, 2),
#  ('The Riverlands', 52, 52, 2),
#  ('The Riverlands', 53, 53, 2),
#  ('The Riverlands', 57, 57, 2),
#  ('The Riverlands', 58, 58, 2),
#  ('The Riverlands', 59, 59, 2),
#  ('The Riverlands', 60, 60, 2),
#  ('Meereen', 52, 52, 2),
#  ('Meereen', 53, 53, 2),
#  ('The Vale', 14, 14, 2),
#  ('The Vale', 20, 20, 2),
#  ('Meereen', 21, 21, 2),
#  ('The Vale', 24, 24, 2),
#  ('The Vale', 25, 25, 2),
#  ('The Vale', 26, 26, 2),
#  ('The Vale', 27, 27, 2),
#  ('Meereen', 19, 19, 2),
#  ('The Wall', 23, 23, 2),
#  ('The Wall', 47, 47, 2),
#  ('The Wall', 50, 50, 2),
#  ('The Wall', 51, 51, 2),
#  ('The Wall', 52, 52, 2),
#  ('The Wall', 53, 53, 2),
#  ('The Wall', 59, 59, 2),
#  ('North of the Wall', 60, 60, 2),
#  ('North of the Wall', 61, 61, 2),
#  ('The Wall', 67, 67, 2),
#  ('North of the Wall', 68, 68, 2),
#  ('The Wall', 69, 69, 2),
#  ('North of the Wall', 70, 70, 2),
#  ('The Wall', 72, 72, 2),
#  ('The Wall', 73, 73, 2),
#  ('The Wall', 76, 76, 2),
#  ('The Wall', 77, 77, 2),
#  ('North of the Wall', 80, 80, 2),
#  ('The Wall', 82, 82, 2),
#  ('The Wall', 83, 83, 2),
#  ('Meereen', 32, 32, 2),
#  ('Meereen', 33, 33, 2),
#  ('The Vale', 8, 8, 2),
#  ('The Vale', 9, 9, 2),
#  ('Dorne', 15, 15, 2),
#  ('Dorne', 16, 16, 2),
#  ('Dorne', 17, 17, 2),
#  ('Dorne', 18, 18, 2),
#  ('Braavos', 24, 24, 2),
#  ('Dorne', 29, 29, 2),
#  ('Dorne', 30, 30, 2),
#  ('Dorne', 31, 31, 2),
#  ('Meereen', 37, 37, 2),
#  ('Braavos', 9, 9, 2),
#  ('Dorne', 21, 21, 2),
#  ('Dorne', 22, 22, 2),
#  ('Dorne', 23, 23, 2),
#  ('Meereen', 24, 24, 2),
#  ('Braavos', 26, 26, 2),
#  ('Braavos', 32, 32, 2),
#  ('Braavos', 38, 38, 2),
#  ('The Wall', 60, 60, 2),
#  ('The Wall', 61, 61, 2),
#  ('The Wall', 63, 63, 2),
#  ('Meereen', 28, 28, 2),
#  ('Meereen', 25, 25, 2),
#  ('Meereen', 26, 26, 2),
#  ('The Iron Islands', 28, 28, 2),
#  ('The Iron Islands', 29, 29, 2),
#  ('North of the Wall', 64, 64, 2),
#  ('North of the Wall', 74, 74, 2),
#  ('The Reach', 17, 17, 2),
#  ('The Reach', 22, 22, 2),
#  ('Braavos', 39, 39, 2),
#  ('Braavos', 42, 42, 2),
#  ('Braavos', 43, 43, 2),
#  ('North of the Wall', 79, 79, 2),
#  ('The Reach', 19, 19, 2),
#  ('The Reach', 34, 34, 2),
#  ('The Reach', 35, 35, 2),
#  ('The Narrow Sea', 49, 49, 2),
#  ('North of the Wall', 75, 75, 2),
#  ('The Wall', 80, 80, 2),
#  ('North of the Wall', 91, 91, 2),
#  ('The North', 74, 74, 2),
#  ('The North', 76, 76, 2),
#  ('The North', 80, 80, 2),
#  ('The North', 82, 82, 2),
#  ('The North', 86, 86, 2),
#  ('The North', 87, 87, 2),
#  ('The North', 91, 91, 2),
#  ('The North', 92, 92, 2),
#  ('The North', 93, 93, 2),
#  ('The North', 94, 94, 2),
#  ('The North', 95, 95, 2),
#  ('The North', 96, 96, 2),
#  ('The North', 97, 97, 2),
#  ('Pentos', 25, 25, 1),
#  ('Pentos', 26, 26, 1),
#  ('Pentos', 27, 27, 1),
#  ('Pentos', 33, 33, 1),
#  ('Pentos', 34, 34, 1),
#  ('The Dothraki Sea', 1, 1, 1),
#  ('The Dothraki Sea', 11, 11, 1),
#  ('The Dothraki Sea', 14, 14, 1),
#  ('The Dothraki Sea', 19, 19, 1),
#  ('The Dothraki Sea', 17, 17, 1),
#  ('The Dothraki Sea', 21, 21, 1),
#  ('Vaes Dothrak', 6, 6, 1),
#  ('Vaes Dothrak', 7, 7, 1),
#  ('Vaes Dothrak', 8, 8, 1),
#  ('Vaes Dothrak', 23, 23, 1),
#  ('Vaes Dothrak', 25, 25, 1),
#  ('Vaes Dothrak', 2, 2, 1),
#  ('Vaes Dothrak', 9, 9, 1),
#  ('The Vale', 12, 12, 1),
#  ('Vaes Dothrak', 21, 21, 1),
#  ('The Dothraki Sea', 22, 22, 1),
#  ('The Red Waste', 12, 12, 1),
#  ('The Red Waste', 16, 16, 1),
#  ('The Red Waste', 17, 17, 1),
#  ('The Red Waste', 21, 21, 1),
#  ('The Red Waste', 22, 22, 1),
#  ('The Red Waste', 31, 31, 1),
#  ('The Red Waste', 32, 32, 1),
#  ('The Red Waste', 11, 11, 1),
#  ('The Sunset Sea', 11, 11, 1),
#  ('The Sunset Sea', 12, 12, 1),
#  ('The Stormlands', 9, 9, 1),
#  ('The Iron Islands', 10, 10, 1),
#  ('The Stormlands', 18, 18, 1),
#  ('The Stormlands', 19, 19, 1),
#  ('The Westerlands', 3, 3, 1),
#  ('The Westerlands', 4, 4, 1),
#  ('The Westerlands', 5, 5, 1),
#  ('The Stormlands', 13, 13, 1),
#  ('The Stormlands', 14, 14, 1),
#  ('The Stormlands', 15, 15, 1),
#  ('The Stormlands', 16, 16, 1),
#  ('The Stormlands', 17, 17, 1),
#  ('The Red Waste', 18, 18, 1),
#  ('The Stormlands', 22, 22, 1),
#  ('The Stormlands', 26, 26, 1),
#  ('The Stormlands', 31, 31, 1),
#  ('The Stormlands', 32, 32, 1),
#  ('The Stormlands', 33, 33, 1),
#  ('The Stormlands', 1, 1, 1),
#  ('The Iron Islands', 12, 12, 1),
#  ('The Iron Islands', 13, 13, 1),
#  ('The Iron Islands', 14, 14, 1),
#  ('Qarth', 22, 22, 1),
#  ('Qarth', 23, 23, 1),
#  ('Qarth', 24, 24, 1),
#  ('Qarth', 25, 25, 1),
#  ('Qarth', 26, 26, 1),
#  ('The Stormlands', 30, 30, 1),
#  ('Qarth', 35, 35, 1),
#  ('Qarth', 36, 36, 1),
#  ('The Westerlands', 35, 35, 1),
#  ('Qarth', 45, 45, 1),
#  ('Qarth', 46, 46, 1),
#  ('Qarth', 47, 47, 1),
#  ('Qarth', 10, 10, 1),
#  ('The Westerlands', 12, 12, 1),
#  ('The Westerlands', 13, 13, 1),
#  ('The Westerlands', 14, 14, 1),
#  ('The Westerlands', 15, 15, 1),
#  ('Qarth', 17, 17, 1),
#  ('The Westerlands', 26, 26, 1),
#  ('The Westerlands', 27, 27, 1),
#  ('The Westerlands', 33, 33, 1),
#  ('The Westerlands', 8, 8, 1),
#  ('The Westerlands', 10, 10, 1),
#  ('The Westerlands', 29, 29, 1),
#  ('The Westerlands', 30, 30, 1),
#  ('The Westerlands', 17, 17, 1),
#  ('Qarth', 18, 18, 1),
#  ('Qarth', 19, 19, 1),
#  ('Qarth', 20, 20, 1),
#  ('Qarth', 21, 21, 1),
#  ('Qarth', 31, 31, 1),
#  ('Qarth', 32, 32, 1),
#  ('Qarth', 33, 33, 1),
#  ('Qarth', 34, 34, 1),
#  ('Qarth', 39, 39, 1),
#  ('Qarth', 40, 40, 1),
#  ('Qarth', 41, 41, 1),
#  ('The Summer Sea', 33, 33, 1),
#  ('The Summer Sea', 34, 34, 1),
#  ('The Summer Sea', 35, 35, 1),
#  ('Astapor', 21, 21, 1),
#  ('Astapor', 22, 22, 1),
#  ('Astapor', 23, 23, 1),
#  ('Astapor', 24, 24, 1),
#  ('Astapor', 25, 25, 1),
#  ('Astapor', 26, 26, 1),
#  ('Astapor', 27, 27, 1),
#  ('Astapor', 42, 42, 1),
#  ('Astapor', 43, 43, 1),
#  ('Astapor', 44, 44, 1),
#  ('Astapor', 45, 45, 1),
#  ('Astapor', 46, 46, 1),
#  ('Yunkai', 27, 27, 1),
#  ('Yunkai', 28, 28, 1),
#  ('Yunkai', 29, 29, 1),
#  ('Yunkai', 30, 30, 1),
#  ('Yunkai', 14, 14, 1),
#  ('Yunkai', 15, 15, 1),
#  ('Yunkai', 16, 16, 1),
#  ('Yunkai', 17, 17, 1),
#  ('Yunkai', 18, 18, 1),
#  ('Yunkai', 19, 19, 1),
#  ('Yunkai', 20, 20, 1),
#  ('Yunkai', 21, 21, 1),
#  ('The Riverlands', 43, 43, 1),
#  ('Yunkai', 3, 3, 1),
#  ('Yunkai', 12, 12, 1),
#  ('Yunkai', 13, 13, 1),
#  ('Yunkai', 39, 39, 1),
#  ('Yunkai', 32, 32, 1),
#  ('Yunkai', 33, 33, 1),
#  ('Yunkai', 34, 34, 1),
#  ('Yunkai', 35, 35, 1),
#  ('The Riverlands', 61, 61, 1),
#  ('The Riverlands', 62, 62, 1),
#  ('The Riverlands', 63, 63, 1),
#  ('The Riverlands', 64, 64, 1),
#  ('The Riverlands', 65, 65, 1),
#  ('The Riverlands', 66, 66, 1),
#  ('The Riverlands', 67, 67, 1),
#  ('The Riverlands', 68, 68, 1),
#  ('The Riverlands', 69, 69, 1),
#  ('The Riverlands', 70, 70, 1),
#  ('The Riverlands', 71, 71, 1),
#  ('The Iron Islands', 19, 19, 1),
#  ('Yunkai', 45, 45, 1),
#  ('Yunkai', 46, 46, 1),
#  ('Yunkai', 47, 47, 1),
#  ('Meereen', 54, 54, 1),
#  ('Meereen', 55, 55, 1),
#  ('The Vale', 13, 13, 1),
#  ('The Wall', 49, 49, 1),
#  ('The Wall', 54, 54, 1),
#  ('The Wall', 55, 55, 1),
#  ('The Wall', 57, 57, 1),
#  ('North of the Wall', 63, 63, 1),
#  ('The Wall', 71, 71, 1),
#  ('The Wall', 75, 75, 1),
#  ('The Wall', 79, 79, 1),
#  ('The Wall', 81, 81, 1),
#  ('The Wall', 85, 85, 1),
#  ('The Vale', 30, 30, 1),
#  ('The Vale', 31, 31, 1),
#  ('The Vale', 32, 32, 1),
#  ('The Vale', 33, 33, 1),
#  ('The Vale', 34, 34, 1),
#  ('The Vale', 35, 35, 1),
#  ('The Vale', 43, 43, 1),
#  ('The Vale', 44, 44, 1),
#  ('The Vale', 45, 45, 1),
#  ('Pentos', 5, 5, 1),
#  ('Pentos', 6, 6, 1),
#  ('The Vale', 19, 19, 1),
#  ('The Vale', 21, 21, 1),
#  ('Pentos', 30, 30, 1),
#  ('Pentos', 31, 31, 1),
#  ('The Wall', 46, 46, 1),
#  ('The Vale', 5, 5, 1),
#  ('Dorne', 14, 14, 1),
#  ('Pentos', 24, 24, 1),
#  ('Braavos', 18, 18, 1),
#  ('Braavos', 19, 19, 1),
#  ('Braavos', 20, 20, 1),
#  ('Braavos', 21, 21, 1),
#  ('Braavos', 22, 22, 1),
#  ('Braavos', 23, 23, 1),
#  ('Volantis', 45, 45, 1),
#  ('Volantis', 46, 46, 1),
#  ('Volantis', 47, 47, 1),
#  ('Volantis', 48, 48, 1),
#  ('Volantis', 49, 49, 1),
#  ('Volantis', 50, 50, 1),
#  ('Volantis', 51, 51, 1),
#  ('Volantis', 52, 52, 1),
#  ('Volantis', 53, 53, 1),
#  ('Volantis', 54, 54, 1),
#  ('Volantis', 55, 55, 1),
#  ('Volantis', 1, 1, 1),
#  ('Dorne', 27, 27, 1),
#  ('Dorne', 28, 28, 1),
#  ('Dorne', 32, 32, 1),
#  ('Dorne', 33, 33, 1),
#  ('Volantis', 34, 34, 1),
#  ('Valyria', 42, 42, 1),
#  ('Valyria', 43, 43, 1),
#  ('Valyria', 44, 44, 1),
#  ('Valyria', 45, 45, 1),
#  ('Valyria', 46, 46, 1),
#  ('Valyria', 47, 47, 1),
#  ('Valyria', 48, 48, 1),
#  ('Valyria', 4, 4, 1),
#  ('Valyria', 10, 10, 1),
#  ('Valyria', 11, 11, 1),
#  ('Valyria', 12, 12, 1),
#  ('Dorne', 19, 19, 1),
#  ('Dorne', 20, 20, 1),
#  ('Dorne', 36, 36, 1),
#  ('Dorne', 37, 37, 1),
#  ('Dorne', 39, 39, 1),
#  ('Dorne', 40, 40, 1),
#  ('Dorne', 41, 41, 1),
#  ('Dorne', 42, 42, 1),
#  ('The Dothraki Sea', 47, 47, 1),
#  ('The Dothraki Sea', 48, 48, 1),
#  ('The Wall', 58, 58, 1),
#  ('Dorne', 26, 26, 1),
#  ('Meereen', 29, 29, 1),
#  ('Meereen', 30, 30, 1),
#  ('Meereen', 31, 31, 1),
#  ('The Dothraki Sea', 34, 34, 1),
#  ('The Dothraki Sea', 35, 35, 1),
#  ('The Dothraki Sea', 36, 36, 1),
#  ('The Dothraki Sea', 37, 37, 1),
#  ('The Dothraki Sea', 38, 38, 1),
#  ('The Dothraki Sea', 39, 39, 1),
#  ('Meereen', 27, 27, 1),
#  ('The Iron Islands', 38, 38, 1),
#  ('The Iron Islands', 39, 39, 1),
#  ('The Iron Islands', 40, 40, 1),
#  ('The Reach', 5, 5, 1),
#  ('Dorne', 6, 6, 1),
#  ('Dorne', 7, 7, 1),
#  ('Dorne', 8, 8, 1),
#  ('Braavos', 25, 25, 1),
#  ('The Vale', 10, 10, 1),
#  ('Vaes Dothrak', 16, 16, 1),
#  ('Vaes Dothrak', 17, 17, 1),
#  ('Vaes Dothrak', 18, 18, 1),
#  ('Vaes Dothrak', 35, 35, 1),
#  ('Vaes Dothrak', 36, 36, 1),
#  ('Vaes Dothrak', 37, 37, 1),
#  ('Vaes Dothrak', 38, 38, 1),
#  ('Vaes Dothrak', 39, 39, 1),
#  ('Vaes Dothrak', 40, 40, 1),
#  ('Vaes Dothrak', 41, 41, 1),
#  ('Vaes Dothrak', 42, 42, 1),
#  ('Vaes Dothrak', 43, 43, 1),
#  ('Vaes Dothrak', 44, 44, 1),
#  ('Vaes Dothrak', 45, 45, 1),
#  ('Vaes Dothrak', 46, 46, 1),
#  ('The Iron Islands', 25, 25, 1),
#  ('The Iron Islands', 26, 26, 1),
#  ('The Iron Islands', 27, 27, 1),
#  ('The Iron Islands', 30, 30, 1),
#  ('The Iron Islands', 31, 31, 1),
#  ('Vaes Dothrak', 32, 32, 1),
#  ('Vaes Dothrak', 33, 33, 1),
#  ('North of the Wall', 62, 62, 1),
#  ('North of the Wall', 69, 69, 1),
#  ('North of the Wall', 72, 72, 1),
#  ('North of the Wall', 76, 76, 1),
#  ('North of the Wall', 82, 82, 1),
#  ('North of the Wall', 84, 84, 1),
#  ('The Reach', 13, 13, 1),
#  ('The Reach', 14, 14, 1),
#  ('The Reach', 15, 15, 1),
#  ('The Reach', 16, 16, 1),
#  ('The Reach', 23, 23, 1),
#  ('The Reach', 24, 24, 1),
#  ('The Reach', 25, 25, 1),
#  ('The Reach', 26, 26, 1),
#  ('Braavos', 44, 44, 1),
#  ('Braavos', 45, 45, 1),
#  ('Braavos', 46, 46, 1),
#  ('The Dothraki Sea', 58, 58, 1),
#  ('The Dothraki Sea', 59, 59, 1),
#  ('The Dothraki Sea', 60, 60, 1),
#  ('Volantis', 29, 29, 1),
#  ('Volantis', 30, 30, 1),
#  ('Volantis', 31, 31, 1),
#  ('Braavos', 48, 48, 1),
#  ('Braavos', 49, 49, 1),
#  ('Braavos', 50, 50, 1),
#  ('Braavos', 51, 51, 1),
#  ('Braavos', 52, 52, 1),
#  ('Braavos', 53, 53, 1),
#  ('The Reach', 62, 62, 1),
#  ('The Reach', 63, 63, 1),
#  ('The Reach', 64, 64, 1),
#  ('The Reach', 65, 65, 1),
#  ('Dorne', 71, 71, 1),
#  ('Dorne', 72, 72, 1),
#  ('Meereen', 73, 73, 1),
#  ('Meereen', 74, 74, 1),
#  ('The Riverlands', 75, 75, 1),
#  ('The Riverlands', 76, 76, 1),
#  ('Dorne', 80, 80, 1),
#  ('Dorne', 81, 81, 1),
#  ('Dorne', 82, 82, 1),
#  ('The Summer Sea', 87, 87, 1),
#  ('The Summer Sea', 88, 88, 1),
#  ('The Summer Sea', 89, 89, 1),
#  ('The Reach', 20, 20, 1),
#  ('The Reach', 33, 33, 1),
#  ('The Reach', 10, 10, 1),
#  ('The Reach', 11, 11, 1),
#  ('The Reach', 18, 18, 1),
#  ('The Narrow Sea', 36, 36, 1),
#  ('The Narrow Sea', 37, 37, 1),
#  ('The Narrow Sea', 38, 38, 1),
#  ('The Narrow Sea', 39, 39, 1),
#  ('The Narrow Sea', 40, 40, 1),
#  ('The Narrow Sea', 41, 41, 1),
#  ('The Narrow Sea', 42, 42, 1),
#  ('The Narrow Sea', 43, 43, 1),
#  ('The Narrow Sea', 44, 44, 1),
#  ('The Narrow Sea', 45, 45, 1),
#  ('The Narrow Sea', 46, 46, 1),
#  ('The Narrow Sea', 47, 47, 1),
#  ('The Narrow Sea', 48, 48, 1),
#  ('The Narrow Sea', 50, 50, 1),
#  ('The Narrow Sea', 51, 51, 1),
#  ('The Narrow Sea', 52, 52, 1),
#  ('The Narrow Sea', 53, 53, 1),
#  ('The Narrow Sea', 54, 54, 1),
#  ('The Narrow Sea', 55, 55, 1),
#  ('The Narrow Sea', 56, 56, 1),
#  ('The Narrow Sea', 57, 57, 1),
#  ('The Narrow Sea', 58, 58, 1),
#  ('The Narrow Sea', 59, 59, 1),
#  ('The Narrow Sea', 11, 11, 1),
#  ('The Reach', 36, 36, 1),
#  ('The Westerlands', 38, 38, 1),
#  ('The Westerlands', 40, 40, 1),
#  ('The Westerlands', 42, 42, 1),
#  ('The Westerlands', 43, 43, 1),
#  ('The Westerlands', 44, 44, 1),
#  ('The Westerlands', 45, 45, 1),
#  ('The Reach', 46, 46, 1),
#  ('The Reach', 47, 47, 1),
#  ('The Reach', 48, 48, 1),
#  ('The Reach', 49, 49, 1),
#  ('The Reach', 50, 50, 1),
#  ('The Reach', 1, 1, 1),
#  ('The Reach', 2, 2, 1),
#  ('The Reach', 3, 3, 1),
#  ('The Reach', 4, 4, 1),
#  ('The Reach', 41, 41, 1),
#  ('The Reach', 42, 42, 1),
#  ('The Reach', 43, 43, 1),
#  ('North of the Wall', 21, 21, 1),
#  ('The Wall', 68, 68, 1),
#  ('The Shivering Sea', 72, 72, 1),
#  ('The Shivering Sea', 73, 73, 1),
#  ('Dorne', 63, 63, 1),
#  ('The Narrow Sea', 64, 64, 1),
#  ('The Narrow Sea', 65, 65, 1),
#  ('The Narrow Sea', 66, 66, 1),
#  ('Dorne', 67, 67, 1),
#  ('The Narrow Sea', 68, 68, 1),
#  ('The Narrow Sea', 69, 69, 1),
#  ('The Narrow Sea', 70, 70, 1),
#  ('North of the Wall', 77, 77, 1),
#  ('The Wall', 78, 78, 1),
#  ('North of the Wall', 81, 81, 1),
#  ('North of the Wall', 83, 83, 1),
#  ('North of the Wall', 85, 85, 1),
#  ('North of the Wall', 87, 87, 1),
#  ('The Wall', 88, 88, 1),
#  ('North of the Wall', 89, 89, 1),
#  ('The Wall', 90, 90, 1),
#  ('The Wall', 92, 92, 1),
#  ('North of the Wall', 93, 93, 1),
#  ('The Wall', 94, 94, 1),
#  ('North of the Wall', 95, 95, 1),
#  ('The Wall', 96, 96, 1),
#  ('North of the Wall', 97, 97, 1),
#  ('The Wall', 98, 98, 1),
#  ('North of the Wall', 99, 99, 1),
#  ('North of the Wall', 100, 100, 1),
#  ('The Wall', 101, 101, 1),
#  ('The Wall', 102, 102, 1),
#  ('The Wall', 103, 103, 1),
#  ('The Wall', 104, 104, 1),
#  ('The North', 88, 88, 1),
#  ('The North', 89, 89, 1),
#  ('The North', 90, 90, 1),
#  ('The North', 98, 98, 1),
#  ('The North', 99, 99, 1),
#  ('The North', 100, 100, 1),
#  ('The North', 101, 101, 1),
#  ('The North', 102, 102, 1),
#  ('The North', 103, 103, 1),
#  ('The North', 104, 104, 1),
#  ('The North', 105, 105, 1),
#  ('The North', 106, 106, 1),
#  ('The North', 107, 107, 1),
#  ('The North', 108, 108, 1),
#  ('The North', 109, 109, 1),
#  ('The North', 110, 110, 1),
#  ('The North', 111, 111, 1),
#  ('The North', 112, 112, 1),
#  ('The North', 113, 113, 1),
#  ('The North', 114, 114, 1),
#  ('The North', 115, 115, 1),
#  ('The North', 116, 116, 1),
#  ('The North', 117, 117, 1),
#  ...]

# %% [markdown]
# ## Task 5
#
# ### Programming

# %% [markdown]
# #### Data Processing and Cleansing
#
#
# - The ```scene``` information in ```episodes.json``` complements and extend some of the information about character interactions and relationships. An example is:
#
# ```
#             {
#                "sceneStart":"0:50:24",
#                "sceneEnd":"0:55:54",
#                "location":"The Crownlands",
#                "subLocation":"King's Landing",
#                "characters":[
#                   {
#                      "name":"Arya Stark",
#                      "weapon":[
#                         {"action":"has", "name":"Needle"}
#                      ]
#                   },
#                   {
#                      "name":"Eddard Stark",
#                      "title":"Hand",
#                      "alive":false,
#                      "mannerOfDeath":"Decapitation",
#                      "killedBy":[
#                         "Ilyn Payne"
#                      ]
#                   },
#                   {"name":"Yoren"},
#                   {"name":"Sansa Stark"},
#                   {"name":"Petyr Baelish"},
#                   {"name":"Cersei Lannister"},
#                   {"name":"Joffrey Baratheon", "title":"King"},
#                   {"name":"Grand Maester Pycelle"},
#                   {"name":"Lord Varys"},
#                   {"name":"Sandor Clegane"},
#                   {
#                      "name":"Ilyn Payne",
#                      "weapon":[
#                         {"action":"has", "name":"Ice"}
#                      ]
#                   }
#                ]
#             }
#          ]
# ```
#
#
# - A little data processing determines that the top-level elements of a ```character``` in a scene are:
#
# ```Top level keys in characters in scenes are:
# 	 sex
# 	 name
# 	 weapon
# 	 born
# 	 married
# 	 killedBy
# 	 mannerOfDeath
# 	 title
# 	 alive
# ```

# %% [markdown]
# - Your data processing and cleanse tasks is to create a table of the form:
#     - ```seasonNum```
#     - ```episodeNum```
#     - ```sceneNo```
#     - ```character_id_1```
#     - ```action```
#     - ```character_id_2```
#
#
# - You can get access to information that maps ```characterName``` to ```character_id``` using the following code.

# %%
import pymysql
cloud_conn = pymysql.connect(
    host="columbia8013.cqgsme1nmjms.us-east-1.rds.amazonaws.com",
    user="gotuser",
    password="gotusergotuser",
    db="W4111GoTSolutionClean",
    cursorclass=pymysql.cursors.DictCursor)

# %%
def get_character_info(c_name):
    
    sql = "select * from characters where characterName=%s"
    cur = cloud_conn.cursor()
    res = cur.execute(sql, (c_name))
    res = cur.fetchall()
    return res

# %%
import pandas 
sql = \
    "select characterName_1, characterName_2," + \
    " scene_count from W4111GoTSolutionClean.character_interactions order by scene_count desc;"
df = pandas.read_sql(sql,cloud_conn)

# %%
df
# Out:
#        characterName_1     characterName_2  scene_count
# 0   Daenerys Targaryen              Drogon          172
# 1        Jorah Mormont  Daenerys Targaryen          148
# 2             Jon Snow  Tormund Giantsbane          145
# 3           Lord Varys    Tyrion Lannister          141
# 4             Jon Snow      Davos Seaworth          136
# 5            Missandei  Daenerys Targaryen          131
# 6             Jon Snow  Daenerys Targaryen          119
# 7     Tyrion Lannister  Daenerys Targaryen          116
# 8            Missandei    Tyrion Lannister           97
# 9      Jaime Lannister    Brienne of Tarth           91
# 10           Missandei           Grey Worm           86
# 11            Jon Snow    Tyrion Lannister           82
# 12  Daenerys Targaryen           Grey Worm           82
# 13    Tyrion Lannister    Cersei Lannister           82
# 14       Podrick Payne    Brienne of Tarth           81
# 15     Jaime Lannister    Cersei Lannister           81
# 16            Jon Snow     Eddison Tollett           81
# 17            Jon Snow       Samwell Tarly           80
# 18         Sansa Stark    Tyrion Lannister           80
# 19               Hodor          Bran Stark           76
# 20       Podrick Payne    Tyrion Lannister           75
# 21     Jaime Lannister    Tyrion Lannister           74
# 22    Tyrion Lannister      Davos Seaworth           70
# 23          Meera Reed          Bran Stark           68
# 24    Cersei Lannister      Gregor Clegane           67
# 25          Arya Stark      Sandor Clegane           67
# 26    Tyrion Lannister           Grey Worm           65
# 27    Tommen Baratheon    Cersei Lannister           65
# 28          Lord Varys  Daenerys Targaryen           64
# 29       Jorah Mormont           Missandei           64
# 30          Lord Varys           Missandei           64
# 31            Jon Snow         Sansa Stark           64
# 32             Rhaegal              Drogon           64
# 33     Barristan Selmy  Daenerys Targaryen           62
# 34       Samwell Tarly               Gilly           62
# 35   Joffrey Baratheon    Cersei Lannister           60
# 36             Rhaegal  Daenerys Targaryen           59
# 37               Bronn    Tyrion Lannister           59
# 38       Petyr Baelish         Sansa Stark           58
# 39              Qyburn    Cersei Lannister           58
# 40     Tywin Lannister    Cersei Lannister           57
# 41       Jorah Mormont    Tyrion Lannister           57
# 42            Jon Snow       Jorah Mormont           56
# 43      Daario Naharis  Daenerys Targaryen           56
# 44    Beric Dondarrion      Sandor Clegane           53
# 45   Joffrey Baratheon    Tyrion Lannister           52
# 46   Joffrey Baratheon         Sansa Stark           51
# 47               Hodor          Meera Reed           51

# %%
get_character_info("Sansa Stark")
# Out:
# [{'id': 300,
#   'characterName': 'Sansa Stark',
#   'characterLink': '/character/ch0158137/',
#   'actorName': 'Sophie Turner',
#   'actorLink': '/name/nm3849842/',
#   'character_id': 'CH_300',
#   'royal': 1,
#   'characterImageThumb': 'https://images-na.ssl-images-amazon.com/images/M/MV5BNjAwMjE2NDExNF5BMl5BanBnXkFtZTcwODAwODg4OQ@@._V1._SX100_SY140_.jpg',
#   'characterImageFull': 'https://images-na.ssl-images-amazon.com/images/M/MV5BNjAwMjE2NDExNF5BMl5BanBnXkFtZTcwODAwODg4OQ@@._V1_SY1000_CR0,0,806,1000_AL_.jpg',
#   'nickname': None,
#   'kingsguard': 0}]

# %% [markdown]
# #### Answer

# %% [markdown]
# <u>Table Definition</u>

# %%
import os
import json
import pymysql
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

filename ='/Users/kelanox/Desktop/IntroToDB/HW1C/GoTHW/Data/json/episodes.json'
with open(filename) as f:
    df = json.load(f)
df=df['episodes']

# %%
res = []
for item in df:
    scenes = item['scenes']
    for i in range(len(scenes)):
        scene = scenes[i]
        sceneNo = i + 1
        characters = scene['characters']
        for character in characters:
            if 'killedBy' in character or 'sex' in character or 'married' in character:
                obj = {}
                obj['seasonNum'] = item['seasonNum']
                obj['episodeNum'] = item['episodeNum']
                obj['sceneNo'] = sceneNo
                if 'killedBy' in character and character['killedBy']:
                    obj['characterName_1'] = character['name']
                    obj['action'] = 'killedBy'
                    obj['characterName_2'] = character['killedBy'][0]
                 

                elif 'sex' in character and character['sex']:
                    obj['characterName_1'] = character['name']
                    obj['action'] = 'sex'
                    obj['characterName_2'] = character['sex']['with'][0]
                    

                elif 'married' in character and character['married']:
                    obj['characterName_1'] = character['name']
                    obj['action'] = 'married'
                    obj['characterName_2'] = character['married']['to']
                  
                res.append(obj)

events = pd.DataFrame(res)
events.to_csv('events.csv')

# %% [markdown]
# <u>Sample Query</u>

# %%
# %%sql CREATE TABLE W4111GoTSolutionClean.events
#     AS SELECT * FROM W4111GoTSolution.events
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 376 rows affected.
# []

# %%
# %sql SELECT * FROM events;
# Out:
#    mysql+pymysql://dbuser:***@localhost/W4111GoTSolution
#  * mysql+pymysql://dbuser:***@localhost/W4111GoTSolutionClean
# 376 rows affected.
# [(1, 1, 10, 'Waymar Royce', 'killedBy', 'White Walker'),
#  (1, 1, 13, 'Gared', 'killedBy', 'White Walker'),
#  (1, 1, 15, 'Will', 'killedBy', 'Eddard Stark'),
#  (1, 1, 17, 'Jon Arryn', 'killedBy', 'Lysa Arryn'),
#  (1, 1, 23, 'Tyrion Lannister', 'sex', 'Ros'),
#  (1, 1, 23, 'Ros', 'sex', 'Tyrion Lannister'),
#  (1, 1, 33, 'Khal Drogo', 'married', 'Daenerys Targaryen'),
#  (1, 1, 33, 'Daenerys Targaryen', 'married', 'Khal Drogo'),
#  (1, 1, 34, 'Khal Drogo', 'sex', 'Daenerys Targaryen'),
#  (1, 1, 34, 'Daenerys Targaryen', 'sex', 'Khal Drogo'),
#  (1, 1, 36, 'Jaime Lannister', 'sex', 'Cersei Lannister'),
#  (1, 1, 36, 'Cersei Lannister', 'sex', 'Jaime Lannister'),
#  (1, 2, 11, 'Khal Drogo', 'sex', 'Daenerys Targaryen'),
#  (1, 2, 11, 'Daenerys Targaryen', 'sex', 'Khal Drogo'),
#  (1, 2, 13, 'Catspaw Assassin', 'killedBy', 'Summer'),
#  (1, 2, 20, 'Khal Drogo', 'sex', 'Daenerys Targaryen'),
#  (1, 2, 20, 'Daenerys Targaryen', 'sex', 'Khal Drogo'),
#  (1, 2, 26, 'Mycah', 'killedBy', 'Sandor Clegane'),
#  (1, 2, 30, 'Lady', 'killedBy', 'Eddard Stark'),
#  (1, 3, 23, 'Daenerys Targaryen', 'sex', 'Khal Drogo'),
#  (1, 3, 23, 'Khal Drogo', 'sex', 'Daenerys Targaryen'),
#  (1, 4, 8, 'Viserys Targaryen', 'sex', 'Doreah'),
#  (1, 4, 8, 'Doreah', 'sex', 'Viserys Targaryen'),
#  (1, 4, 26, 'Hugh of the Vale', 'killedBy', 'Gregor Clegane'),
#  (1, 5, 8, 'Ros', 'sex', 'Theon Greyjoy'),
#  (1, 5, 8, 'Theon Greyjoy', 'sex', 'Ros'),
#  (1, 5, 24, 'Renly Baratheon', 'sex', 'Loras Tyrell'),
#  (1, 5, 24, 'Loras Tyrell', 'sex', 'Renly Baratheon'),
#  (1, 5, 28, 'Jory Cassel', 'killedBy', 'Jaime Lannister'),
#  (1, 6, 6, 'Stiv', 'killedBy', 'Theon Greyjoy'),
#  (1, 6, 6, 'Wallen', 'killedBy', 'Robb Stark'),
#  (1, 6, 15, 'Vardis Egen', 'killedBy', 'Bronn'),
#  (1, 6, 19, 'Viserys Targaryen', 'killedBy', 'Khal Drogo'),
#  (1, 7, 3, 'Ros', 'sex', 'Armeca'),
#  (1, 7, 3, 'Armeca', 'sex', 'Ros'),
#  (1, 7, 22, 'Robert Baratheon', 'killedBy', 'Boar'),
#  (1, 8, 4, 'Vayon Poole', 'killedBy', 'Lannister Guard'),
#  (1, 8, 6, 'Syrio Forel', 'killedBy', 'Meryn Trant'),
#  (1, 8, 9, 'Red Keep Stableboy', 'killedBy', 'Arya Stark'),
#  (1, 8, 21, 'Othor', 'killedBy', 'Jon Snow'),
#  (1, 8, 23, 'Mago', 'killedBy', 'Khal Drogo'),
#  (1, 9, 14, 'Tyrion Lannister', 'sex', 'Shae'),
#  (1, 9, 14, 'Shae', 'sex', 'Tyrion Lannister'),
#  (1, 9, 15, 'Qotho', 'killedBy', 'Jorah Mormont'),
#  (1, 9, 16, 'Tyrion Lannister', 'sex', 'Shae'),
#  (1, 9, 16, 'Shae', 'sex', 'Tyrion Lannister'),
#  (1, 9, 25, 'Eddard Stark', 'killedBy', 'Ilyn Payne'),
#  (1, 10, 12, 'Cersei Lannister', 'sex', 'Lancel Lannister'),
#  (1, 10, 12, 'Lancel Lannister', 'sex', 'Cersei Lannister'),
#  (1, 10, 19, 'Shae', 'sex', 'Tyrion Lannister'),
#  (1, 10, 19, 'Tyrion Lannister', 'sex', 'Shae'),
#  (1, 10, 22, 'Khal Drogo', 'killedBy', 'Daenerys Targaryen'),
#  (1, 10, 23, 'Grand Maester Pycelle', 'sex', 'Ros'),
#  (1, 10, 23, 'Ros', 'sex', 'Grand Maester Pycelle'),
#  (1, 10, 31, 'Mirri Maz Duur', 'killedBy', 'Daenerys Targaryen'),
#  (2, 1, 18, 'Maester Cressen', 'killedBy', 'Maester Cressen'),
#  (2, 1, 27, 'Barra', 'killedBy', 'Janos Slynt'),
#  (2, 2, 12, 'Theon Greyjoy', 'sex', "Captain's Daughter"),
#  (2, 2, 12, "Captain's Daughter", 'sex', 'Theon Greyjoy'),
#  (2, 2, 13, 'Brothel Customer', 'sex', 'Armeca'),
#  (2, 2, 13, 'Armeca', 'sex', 'Brothel Customer'),
#  (2, 2, 29, 'Stannis Baratheon', 'sex', 'Melisandre'),
#  (2, 2, 29, 'Melisandre', 'sex', 'Stannis Baratheon'),
#  (2, 3, 7, 'Renly Baratheon', 'married', 'Margaery Tyrell'),
#  (2, 3, 7, 'Margaery Tyrell', 'married', 'Renly Baratheon'),
#  (2, 3, 18, 'Renly Baratheon', 'sex', 'Loras Tyrell'),
#  (2, 3, 18, 'Loras Tyrell', 'sex', 'Renly Baratheon'),
#  (2, 3, 24, 'Grand Maester Pycelle', 'sex', 'Daisy'),
#  (2, 3, 24, 'Daisy', 'sex', 'Grand Maester Pycelle'),
#  (2, 3, 28, 'Yoren', 'killedBy', 'Amory Lorch'),
#  (2, 3, 29, 'Lommy Greenhands', 'killedBy', 'Polliver'),
#  (2, 4, 1, 'Rennick', 'killedBy', 'Grey Wind'),
#  (2, 4, 12, 'Ros', 'sex', 'Daisy'),
#  (2, 4, 12, 'Daisy', 'sex', 'Ros'),
#  (2, 4, 28, 'Tortured Prisoner', 'killedBy', 'The Tickler'),
#  (2, 5, 1, 'Renly Baratheon', 'killedBy', 'Melisandre'),
#  (2, 5, 38, 'The Tickler', 'killedBy', "Jaqen H'ghar"),
#  (2, 6, 6, 'Rodrik Cassel', 'killedBy', 'Theon Greyjoy'),
#  (2, 6, 17, 'High Septon', 'killedBy', "King's Landing Mob"),
#  (2, 6, 24, "King's Landing Rioter #1", 'killedBy', 'Sandor Clegane'),
#  (2, 6, 24, "King's Landing Rioter #2", 'killedBy', 'Sandor Clegane'),
#  (2, 6, 24, "King's Landing Rioter #3", 'killedBy', 'Sandor Clegane'),
#  (2, 6, 33, 'Amory Lorch', 'killedBy', "Jaqen H'ghar"),
#  (2, 6, 40, 'Theon Greyjoy', 'sex', 'Osha'),
#  (2, 6, 40, 'Osha', 'sex', 'Theon Greyjoy'),
#  (2, 6, 43, 'Drennan', 'killedBy', 'Osha'),
#  (2, 6, 46, 'Irri', 'killedBy', 'Doreah'),
#  (2, 7, 26, 'Alton Lannister', 'killedBy', 'Jaime Lannister'),
#  (2, 7, 27, 'Torrhen Karstark', 'killedBy', 'Jaime Lannister'),
#  (2, 7, 29, 'Spice King', 'killedBy', 'Pyat Pree'),
#  (2, 7, 29, 'Silk King', 'killedBy', 'Pyat Pree'),
#  (2, 8, 31, 'Robb Stark', 'sex', 'Talisa Maegyr'),
#  (2, 8, 31, 'Talisa Maegyr', 'sex', 'Robb Stark'),
#  (2, 9, 5, 'Tyrion Lannister', 'sex', 'Shae'),
#  (2, 9, 5, 'Shae', 'sex', 'Tyrion Lannister'),
#  (2, 9, 45, 'Matthos Seaworth', 'killedBy', 'Bronn'),
#  (2, 9, 115, 'Mandon Moore', 'killedBy', 'Podrick Payne'),
#  (2, 10, 8, 'Soldier Tom', 'killedBy', 'Brienne of Tarth'),
#  (2, 10, 8, 'Stark Soldier', 'killedBy', 'Brienne of Tarth'),
#  (2, 10, 17, 'Robb Stark', 'married', 'Talisa Maegyr'),
#  (2, 10, 17, 'Talisa Maegyr', 'married', 'Robb Stark'),
#  (2, 10, 28, 'Maester Luwin', 'killedBy', 'Osha'),
#  (2, 10, 34, 'Pyat Pree', 'killedBy', 'Daenerys Targaryen'),
#  (2, 10, 35, 'Qhorin Halfhand', 'killedBy', 'Jon Snow'),
#  (2, 10, 37, 'Xaro Xhoan Daxos', 'sex', 'Doreah'),
#  (2, 10, 37, 'Doreah', 'sex', 'Xaro Xhoan Daxos'),
#  (2, 10, 38, 'Xaro Xhoan Daxos', 'killedBy', 'Daenerys Targaryen'),
#  (2, 10, 38, 'Doreah', 'killedBy', 'Daenerys Targaryen'),
#  (3, 1, 3, 'Man of the Nightswatch', 'killedBy', 'White Walker'),
#  (3, 1, 6, 'White Walker', 'killedBy', 'Jeor Mormont'),
#  (3, 2, 36, 'Tyrion Lannister', 'sex', 'Shae'),
#  (3, 2, 36, 'Shae', 'sex', 'Tyrion Lannister'),
#  (3, 3, 32, 'Podrick Payne', 'sex', 'Genna'),
#  (3, 3, 32, 'Genna', 'sex', 'Podrick Payne'),
#  (3, 3, 32, 'Marei', 'sex', 'Podrick Payne'),
#  (3, 3, 32, 'Kayla', 'sex', 'Podrick Payne'),
#  (3, 3, 36, 'Master Torturer', 'killedBy', 'Ramsay Snow'),
#  (3, 4, 33, 'Craster', 'killedBy', 'Karl Tanner'),
#  (3, 4, 36, 'Jeor Mormont', 'killedBy', 'Rast'),
#  (3, 4, 44, 'Kraznys mo Nakloz', 'killedBy', 'Daenerys Targaryen'),
#  (3, 5, 1, 'Beric Dondarrion', 'killedBy', 'Sandor Clegane'),
#  (3, 5, 5, 'Jon Snow', 'sex', 'Ygritte'),
#  (3, 5, 5, 'Ygritte', 'sex', 'Jon Snow'),
#  (3, 5, 14, 'Martyn Lannister', 'killedBy', 'Rickard Karstark'),
#  (3, 5, 14, 'Willem Lannister', 'killedBy', 'Rickard Karstark'),
#  (3, 5, 18, 'Rickard Karstark', 'killedBy', 'Robb Stark'),
#  (3, 5, 34, 'Loras Tyrell', 'sex', 'Olyvar'),
#  (3, 5, 34, 'Olyvar', 'sex', 'Loras Tyrell'),
#  (3, 6, 23, 'Ros', 'killedBy', 'Joffrey Baratheon'),
#  (3, 7, 6, 'Talisa Maegyr', 'sex', 'Robb Stark'),
#  (3, 7, 6, 'Robb Stark', 'sex', 'Talisa Maegyr'),
#  (3, 7, 34, 'Theon Greyjoy', 'sex', 'Myranda'),
#  (3, 7, 34, 'Myranda', 'sex', 'Theon Greyjoy'),
#  (3, 7, 34, 'Violet', 'sex', 'Theon Greyjoy'),
#  (3, 8, 19, 'Sansa Stark', 'married', 'Tyrion Lannister'),
#  (3, 8, 19, 'Tyrion Lannister', 'married', 'Sansa Stark'),
#  (3, 8, 20, 'Gendry', 'sex', 'Melisandre'),
#  (3, 8, 20, 'Melisandre', 'sex', 'Gendry'),
#  (3, 8, 43, 'Mero', 'killedBy', 'Daario Naharis'),
#  (3, 8, 43, 'Prendahl na Ghezn', 'killedBy', 'Daario Naharis'),
#  (3, 8, 49, 'White Walker', 'killedBy', 'Samwell Tarly'),
#  (3, 9, 25, 'Old Man', 'killedBy', 'Ygritte'),
#  (3, 9, 29, 'Orell', 'killedBy', 'Jon Snow'),
#  (3, 9, 37, 'Edmure Tully', 'married', 'Roslin Frey'),
#  (3, 9, 37, 'Roslin Frey', 'married', 'Edmure Tully'),
#  (3, 9, 60, 'Wendel Manderly', 'killedBy', 'Walder Frey'),
#  (3, 9, 65, 'Grey Wind', 'killedBy', 'Frey Soldiers'),
#  (3, 9, 68, 'Talisa Maegyr', 'killedBy', 'Lothar Frey'),
#  (3, 9, 70, 'Robb Stark', 'killedBy', 'Roose Bolton'),
#  (3, 9, 71, 'Catelyn Stark', 'killedBy', 'Black Walder Rivers'),
#  (3, 9, 71, 'Joyeuse Erenford', 'killedBy', 'Catelyn Stark'),
#  (3, 10, 28, 'Frey Soldier #1', 'killedBy', 'Arya Stark'),
#  (3, 10, 28, 'Frey Soldier #2', 'killedBy', 'Sandor Clegane'),
#  (4, 1, 55, 'Polliver', 'killedBy', 'Arya Stark'),
#  (4, 2, 1, 'Tansy', 'killedBy', "Ramsay's hounds"),
#  (4, 2, 6, 'Roose Bolton', 'married', 'Walda Bolton'),
#  (4, 2, 6, 'Walda Bolton', 'married', 'Ramsay Snow'),
#  (4, 2, 23, 'Axell Florent', 'killedBy', 'Melisandre'),
#  (4, 2, 45, 'Joffrey Baratheon', 'married', 'Margaery Tyrell'),
#  (4, 2, 45, 'Margaery Tyrell', 'married', 'Joffrey Baratheon'),
#  (4, 2, 81, 'Joffrey Baratheon', 'killedBy', 'Olenna Tyrell'),
#  (4, 3, 8, 'Dontos Hollard', 'killedBy', 'Petyr Baelish'),
#  (4, 3, 18, 'Cersei Lannister', 'sex', 'Jaime Lannister'),
#  (4, 3, 18, 'Jaime Lannister', 'sex', 'Cersei Lannister'),
#  (4, 3, 33, 'Ellaria Sand', 'sex', 'Olyvar'),
#  (4, 3, 33, 'Olyvar', 'sex', 'Ellaria Sand'),
#  (4, 3, 33, 'Marei', 'sex', 'Ellaria Sand'),
#  (4, 3, 33, "King's Landing Whore", 'sex', 'Ellaria Sand'),
#  (4, 3, 33, 'Oberyn Martell', 'sex', 'Ellaria Sand'),
#  (4, 3, 38, 'Guymon', 'killedBy', 'Ygritte'),
#  (4, 3, 39, "Olly's Mother", 'killedBy', 'Styr'),
#  (4, 3, 54, 'Oznak zo Pahl', 'killedBy', 'Daario Naharis'),
#  (4, 5, 16, 'Lysa Arryn', 'sex', 'Petyr Baelish'),
#  (4, 5, 16, 'Petyr Baelish', 'sex', 'Lysa Arryn'),
#  (4, 5, 40, 'Locke', 'killedBy', 'Hodor'),
#  (4, 5, 45, 'Karl Tanner', 'killedBy', 'Jon Snow'),
#  (4, 5, 48, 'Rast', 'killedBy', 'Ghost'),
#  (4, 6, 7, 'Myranda', 'sex', 'Ramsay Snow'),
#  (4, 6, 7, 'Ramsay Snow', 'sex', 'Myranda'),
#  (4, 6, 9, 'Myranda', 'sex', 'Ramsay Snow'),
#  (4, 6, 9, 'Ramsay Snow', 'sex', 'Myranda'),
#  (4, 6, 11, 'Myranda', 'sex', 'Ramsay Snow'),
#  (4, 6, 11, 'Ramsay Snow', 'sex', 'Myranda'),
#  (4, 6, 13, 'Myranda', 'sex', 'Ramsay Snow'),
#  (4, 6, 13, 'Ramsay Snow', 'sex', 'Myranda'),
#  (4, 7, 4, 'Old Man', 'killedBy', 'Sandor Clegane'),
#  (4, 7, 5, 'Biter', 'killedBy', 'Sandor Clegane'),
#  (4, 7, 6, 'Rorge', 'killedBy', 'Arya Stark'),
#  (4, 7, 12, 'Daenerys Targaryen', 'sex', 'Daario Naharis'),
#  (4, 7, 12, 'Daario Naharis', 'sex', 'Daenerys Targaryen'),
#  (4, 7, 27, 'Lysa Arryn', 'killedBy', 'Petyr Baelish'),
#  (4, 8, 3, "Mole's Town Whore", 'killedBy', 'Ygritte'),
#  (4, 8, 3, 'Kegs', 'killedBy', 'Styr'),
#  (4, 8, 3, 'Black Jack Bulwer', 'killedBy', 'Tormund Giantsbane'),
#  (4, 8, 3, 'Mully', 'killedBy', 'Styr'),
#  (4, 8, 11, 'Ralf Kenning', 'killedBy', 'Adrack Humble'),
#  (4, 8, 13, 'Adrack Humble', 'killedBy', 'Ramsay Snow'),
#  (4, 8, 33, 'Oberyn Martell', 'killedBy', 'Gregor Clegane'),
#  (4, 9, 41, 'Pypar', 'killedBy', 'Ygritte'),
#  (4, 9, 53, 'Thenn Warg', 'killedBy', 'Samwell Tarly'),
#  (4, 9, 75, 'Styr', 'killedBy', 'Jon Snow'),
#  (4, 9, 77, 'Ygritte', 'killedBy', 'Olly'),
#  (4, 9, 85, 'Grenn', 'killedBy', 'Mag the Mighty'),
#  (4, 9, 85, 'Donnel Hill', 'killedBy', 'Mag the Mighty'),
#  (4, 9, 85, 'Cooper', 'killedBy', 'Mag the Mighty'),
#  (4, 9, 85, 'Mag the Mighty', 'killedBy', 'Grenn'),
#  (4, 10, 13, 'Jaime Lannister', 'sex', 'Cersei Lannister'),
#  (4, 10, 13, 'Cersei Lannister', 'sex', 'Jaime Lannister'),
#  (4, 10, 26, 'Jojen Reed', 'killedBy', 'Meera Reed'),
#  (4, 10, 38, 'Shae', 'killedBy', 'Tyrion Lannister'),
#  (4, 10, 40, 'Tywin Lannister', 'killedBy', 'Tyrion Lannister'),
#  (5, 1, 9, 'White Rat', 'killedBy', 'Son of the Harpy'),
#  (5, 1, 27, 'Loras Tyrell', 'sex', 'Olyvar'),
#  (5, 1, 27, 'Olyvar', 'sex', 'Loras Tyrell'),
#  (5, 1, 34, 'Daario Naharis', 'sex', 'Daenerys Targaryen'),
#  (5, 1, 34, 'Daenerys Targaryen', 'sex', 'Daario Naharis'),
#  (5, 1, 46, 'Mance Rayder', 'killedBy', 'Jon Snow'),
#  (5, 2, 9, 'Eyrie Guard', 'killedBy', 'Brienne of Tarth'),
#  (5, 2, 39, 'Son of the Harpy', 'killedBy', 'Mossador'),
#  (5, 2, 42, 'Mossador', 'killedBy', 'Daario Naharis'),
#  (5, 3, 3, 'Despondent Man', 'killedBy', "Jaqen H'ghar"),
#  (5, 3, 6, 'Tommen Baratheon', 'married', 'Margaery Tyrell'),
#  (5, 3, 6, 'Margaery Tyrell', 'married', 'Tommen Baratheon'),
#  (5, 3, 7, 'Tommen Baratheon', 'sex', 'Margaery Tyrell'),
#  (5, 3, 7, 'Margaery Tyrell', 'sex', 'Tommen Baratheon'),
#  (5, 3, 28, 'Janos Slynt', 'killedBy', 'Jon Snow'),
#  (5, 4, 30, 'Lead Dornish Guard', 'killedBy', 'Bronn'),
#  (5, 4, 33, 'Merchant Captain', 'killedBy', 'Obara Sand'),
#  (5, 4, 44, 'Second Son', 'killedBy', 'Son of the Harpy'),
#  (5, 4, 45, '', '', ''),
#  (5, 4, 51, 'Barristan Selmy', 'killedBy', 'Sons of the Harpy'),
#  (5, 5, 4, 'Great Master #1', 'killedBy', 'Daenerys Targaryen'),
#  (5, 5, 17, 'Myranda', 'sex', 'Ramsay Snow'),
#  (5, 5, 17, 'Ramsay Snow', 'sex', 'Myranda'),
#  (5, 6, 8, 'Ghita', 'killedBy', 'Arya Stark'),
#  (5, 6, 38, 'Sansa Stark', 'married', 'Ramsay Snow'),
#  (5, 6, 38, 'Ramsay Snow', 'married', 'Sansa Stark'),
#  (5, 6, 39, 'Sansa Stark', 'sex', 'Ramsay Snow'),
#  (5, 6, 39, 'Ramsay Snow', 'sex', 'Sansa Stark'),
#  (5, 7, 13, 'Old Woman', 'killedBy', 'Ramsay Snow'),
#  (5, 7, 21, 'Gilly', 'sex', 'Samwell Tarly'),
#  (5, 7, 21, 'Samwell Tarly', 'sex', 'Gilly'),
#  (5, 7, 24, 'Daenerys Targaryen', 'sex', 'Daario Naharis'),
#  (5, 7, 24, 'Daario Naharis', 'sex', 'Daenerys Targaryen'),
#  (5, 8, 24, 'Rattleshirt', 'killedBy', 'Tormund Giantsbane'),
#  (5, 8, 44, 'Loboda', 'killedBy', 'White Walker'),
#  (5, 8, 45, 'White Walker', 'killedBy', 'Jon Snow'),
#  (5, 8, 47, 'Karsi', 'killedBy', 'Wight children'),
#  (5, 9, 34, 'Meryn Trant', 'sex', 'Aya'),
#  (5, 9, 34, 'Aya', 'sex', 'Meryn Trant'),
#  (5, 9, 39, 'Shireen Baratheon', 'killedBy', 'Melisandre'),
#  (5, 9, 47, 'Hizdahr zo Loraq', 'killedBy', 'Sons of the Harpy'),
#  (5, 10, 5, 'Selyse Baratheon', 'killedBy', 'Selyse Baratheon'),
#  (5, 10, 24, 'Gordy', 'killedBy', 'Stannis Baratheon'),
#  (5, 10, 24, 'Simpson', 'killedBy', 'Stannis Baratheon'),
#  (5, 10, 26, 'Stannis Baratheon', 'killedBy', 'Brienne of Tarth'),
#  (5, 10, 30, 'Myranda', 'killedBy', 'Theon Greyjoy'),
#  (5, 10, 35, 'Meryn Trant', 'killedBy', 'Arya Stark'),
#  (5, 10, 37, "Jaqen H'ghar", 'killedBy', "Jaqen H'ghar"),
#  (5, 10, 40, 'Myrcella Baratheon', 'killedBy', 'Ellaria Sand'),
#  (5, 10, 64, 'Jon Snow', 'killedBy', 'Olly'),
#  (6, 1, 14, 'Bolton Officer', 'killedBy', 'Brienne of Tarth'),
#  (6, 1, 14, 'Bolton Soldier', 'killedBy', 'Podrick Payne'),
#  (6, 1, 25, 'Areo Hotah', 'killedBy', 'Tyene Sand'),
#  (6, 1, 25, 'Maester Caleotte', 'killedBy', 'Tyene Sand'),
#  (6, 1, 26, 'Doran Martell', 'killedBy', 'Ellaria Sand'),
#  (6, 1, 27, 'Trystane Martell', 'killedBy', 'Obara Sand'),
#  (6, 2, 17, "King's Landing Boaster", 'killedBy', 'Gregor Clegane'),
#  (6, 2, 33, 'Roose Bolton', 'killedBy', 'Ramsay Snow'),
#  (6, 2, 34, 'Walda Bolton', 'killedBy', 'Ramsay Snow'),
#  (6, 2, 34, 'Newborn Bolton', 'killedBy', 'Ramsay Snow'),
#  (6, 2, 39, 'Balon Greyjoy', 'killedBy', 'Euron Greyjoy'),
#  (6, 3, 6, 'Gerold Hightower', 'killedBy', 'Young Ned Stark'),
#  (6, 3, 7, 'Arthur Dayne', 'killedBy', 'Howland Reed'),
#  (6, 3, 32, 'Shaggydog', 'killedBy', 'Smalljon Umber'),
#  (6, 3, 35, 'Alliser Thorne', 'killedBy', 'Jon Snow'),
#  (6, 3, 35, 'Othell Yarwyck', 'killedBy', 'Jon Snow'),
#  (6, 3, 35, 'Bowen Marsh', 'killedBy', 'Jon Snow'),
#  (6, 3, 35, 'Olly', 'killedBy', 'Jon Snow'),
#  (6, 4, 17, 'Dothraki Woman Having Sex', 'sex', 'Dothraki Man Having Sex'),
#  (6, 4, 17, 'Dothraki Man Having Sex', 'sex', 'Dothraki Woman Having Sex'),
#  (6, 4, 18, 'Akho', 'killedBy', 'Daario Naharis'),
#  (6, 4, 18, 'Iggo', 'killedBy', 'Daario Naharis'),
#  (6, 4, 30, 'Osha', 'killedBy', 'Ramsay Snow'),
#  (6, 4, 39, 'Khal Moro', 'killedBy', 'Daenerys Targaryen'),
#  (6, 4, 39, 'Dothraki Bloodrider #1', 'killedBy', 'Daenerys Targaryen'),
#  (6, 4, 39, 'Dothraki Bloodrider #2', 'killedBy', 'Daenerys Targaryen'),
#  (6, 4, 39, 'Khal Forzho', 'killedBy', 'Daenerys Targaryen'),
#  (6, 4, 39, 'Khal Brozho', 'killedBy', 'Daenerys Targaryen'),
#  (6, 4, 39, 'Khal Rhalko', 'killedBy', 'Daenerys Targaryen'),
#  (6, 4, 39, 'Khal Qorro', 'killedBy', 'Daenerys Targaryen'),
#  (6, 5, 28, 'Euron Greyjoy', 'killedBy', 'Aeron Greyjoy'),
#  (6, 5, 59, 'White Walker', 'killedBy', 'Meera Reed'),
#  (6, 5, 60, 'Summer', 'killedBy', 'Wights'),
#  (6, 5, 67, 'Three-Eyed Raven', 'killedBy', 'The Night King'),
#  (6, 5, 69, 'Leaf', 'killedBy', 'Wights'),
#  (6, 5, 84, 'Hodor', 'killedBy', 'Wights'),
#  (6, 6, 56, 'Jaime Lannister', 'sex', 'Cersei Lannister'),
#  (6, 6, 56, 'Cersei Lannister', 'sex', 'Jaime Lannister'),
#  (6, 7, 46, 'Brother Ray', 'killedBy', 'Lem Lemoncloak'),
#  (6, 8, 5, 'Steve', 'killedBy', 'Sandor Clegane'),
#  (6, 8, 6, 'Morgan', 'killedBy', 'Sandor Clegane'),
#  (6, 8, 6, 'Riddell', 'killedBy', 'Sandor Clegane'),
#  (6, 8, 7, 'Gatins', 'killedBy', 'Sandor Clegane'),
#  (6, 8, 46, 'Lem Lemoncloak', 'killedBy', 'Sandor Clegane'),
#  (6, 8, 50, 'Lady Crane', 'killedBy', 'The Waif'),
#  (6, 8, 51, 'The Waif', 'killedBy', 'Arya Stark'),
#  (6, 9, 12, 'Razdal mo Eraz', 'killedBy', 'Grey Worm'),
#  (6, 9, 12, 'Belicho Paenymion', 'killedBy', 'Grey Worm'),
#  (6, 9, 36, 'Rickon Stark', 'killedBy', 'Ramsay Snow'),
#  (6, 9, 57, 'Smalljon Umber', 'killedBy', 'Tormund Giantsbane'),
#  (6, 9, 63, 'Wun Wun', 'killedBy', 'Ramsay Snow'),
#  (6, 9, 71, 'Ramsay Snow', 'killedBy', 'Sansa Stark'),
#  (6, 10, 9, 'Grand Maester Pycelle', 'sex', 'Marei'),
#  (6, 10, 9, 'Marei', 'sex', 'Grand Maester Pycelle'),
#  (6, 10, 30, 'Grand Maester Pycelle', 'killedBy', 'Frances'),
#  (6, 10, 48, 'Lancel Lannister', 'killedBy', 'Cersei Lannister'),
#  (6, 10, 49, 'Margaery Tyrell', 'killedBy', 'Cersei Lannister'),
#  (6, 10, 49, 'High Sparrow', 'killedBy', 'Cersei Lannister'),
#  (6, 10, 49, 'Loras Tyrell', 'killedBy', 'Cersei Lannister'),
#  (6, 10, 49, 'Mace Tyrell', 'killedBy', 'Cersei Lannister'),
#  (6, 10, 49, 'Kevan Lannister', 'killedBy', 'Cersei Lannister'),
#  (6, 10, 55, 'Tommen Baratheon', 'killedBy', 'Tommen Baratheon'),
#  (6, 10, 75, 'Lothar Frey', 'killedBy', 'Arya Stark'),
#  (6, 10, 75, 'Black Walder Rivers', 'killedBy', 'Arya Stark'),
#  (6, 10, 76, 'Walder Frey', 'killedBy', 'Arya Stark'),
#  (7, 2, 16, 'Grey Worm', 'sex', 'Missandei'),
#  (7, 2, 16, 'Missandei', 'sex', 'Grey Worm'),
#  (7, 2, 48, 'Obara Sand', 'killedBy', 'Euron Greyjoy'),
#  (7, 2, 49, 'Nymeria Sand', 'killedBy', 'Euron Greyjoy'),
#  (7, 3, 17, 'Tyene Sand', 'killedBy', 'Cersei Lannister'),
#  (7, 3, 19, 'Jaime Lannister', 'sex', 'Cersei Lannister'),
#  (7, 3, 19, 'Cersei Lannister', 'sex', 'Jaime Lannister'),
#  (7, 3, 50, 'Olenna Tyrell', 'killedBy', 'Jaime Lannister'),
#  (7, 5, 6, 'Randyll Tarly', 'killedBy', 'Daenerys Targaryen'),
#  (7, 5, 6, 'Dickon Tarly', 'killedBy', 'Daenerys Targaryen'),
#  (7, 5, 33, 'Kevin Eldon', 'killedBy', 'Gendry'),
#  (7, 5, 33, 'Laurence Spellman', 'killedBy', 'Gendry'),
#  (7, 6, 27, 'White Walker', 'killedBy', 'Jon Snow'),
#  (7, 6, 48, 'Viserion', 'killedBy', 'The Night King'),
#  (7, 6, 58, 'Benjen Stark', 'killedBy', 'Wights'),
#  (7, 7, 49, 'Harrag', 'killedBy', 'Theon Greyjoy'),
#  (7, 7, 52, 'Petyr Baelish', 'killedBy', 'Arya Stark'),
#  (7, 7, 63, 'Lyanna Stark', 'married', 'Rhaegar Targaryen'),
#  (7, 7, 63, 'Rhaegar Targaryen', 'married', 'Lyanna Stark'),
#  (7, 7, 68, 'Jon Snow', 'sex', 'Daenerys Targaryen'),
#  (7, 7, 68, 'Daenerys Targaryen', 'sex', 'Jon Snow'),
#  (8, 1, 39, 'Bronn', 'sex', 'Marei'),
#  (8, 1, 39, 'Marei', 'sex', 'Bronn'),
#  (8, 1, 44, 'Cersei Lannister', 'sex', 'Euron Greyjoy'),
#  (8, 1, 44, 'Euron Greyjoy', 'sex', 'Cersei Lannister'),
#  (8, 1, 83, 'Ned Umber', 'killedBy', 'The Night King'),
#  (8, 2, 56, 'Arya Stark', 'sex', 'Gendry'),
#  (8, 2, 56, 'Gendry', 'sex', 'Arya Stark'),
#  (8, 3, 120, 'Eddison Tollett', 'killedBy', 'Wight'),
#  (8, 3, 213, 'Lyanna Mormont', 'killedBy', 'Wun Wun Wight'),
#  (8, 3, 213, 'Wun Wun Wight', 'killedBy', 'Lyanna Mormont'),
#  (8, 3, 223, 'Beric Dondarrion', 'killedBy', 'Wights'),
#  (8, 3, 272, 'Theon Greyjoy', 'killedBy', 'The Night King'),
#  (8, 3, 279, 'The Night King', 'killedBy', 'Arya Stark'),
#  (8, 3, 279, 'White Walker', 'killedBy', 'Arya Stark'),
#  (8, 3, 280, 'Viserion', 'killedBy', 'Arya Stark'),
#  (8, 3, 288, 'Jorah Mormont', 'killedBy', 'Wights'),
#  (8, 4, 46, 'Jaime Lannister', 'sex', 'Brienne of Tarth'),
#  (8, 4, 46, 'Brienne of Tarth', 'sex', 'Jaime Lannister'),
#  (8, 4, 71, 'Rhaegal', 'killedBy', 'Euron Greyjoy'),
#  (8, 4, 111, 'Missandei', 'killedBy', 'Gregor Clegane'),
#  (8, 5, 14, 'Lord Varys', 'killedBy', 'Daenerys Targaryen'),
#  (8, 5, 78, 'Harry Strickland', 'killedBy', 'Grey Worm'),
#  (8, 5, 173, 'Euron Greyjoy', 'killedBy', 'Jaime Lannister'),
#  (8, 5, 178, 'Qyburn', 'killedBy', 'Gregor Clegane'),
#  (8, 5, 204, 'Sandor Clegane', 'killedBy', 'Sandor Clegane'),
#  (8, 5, 204, 'Gregor Clegane', 'killedBy', 'Sandor Clegane'),
#  (8, 5, 216, 'Eleanor', 'killedBy', 'Daenerys Targaryen'),
#  (8, 5, 216, "Eleanor's Daughter", 'killedBy', 'Daenerys Targaryen'),
#  (8, 6, 40, 'Daenerys Targaryen', 'killedBy', 'Jon Snow')]

# %% [markdown]
# <u>Python Code</u>

# %% [markdown]
# ### Data Access Abstraction
#
# - A common API and abstraction for manipulating different database types and schema simplifies the development of web applications and other applications. There are many abstractions.
#
# | <img src="./Lecture_4_ER_SQL_Relational_GoT_9.jpg"> |
# | :---: |
# | __Data Access Objects__ |
#
# - The second programming tasks is to implement our own abstraction. This is RDBDataTable, which implements an abstraction we will use in subsequent homework assignments, and which we will use to enable our web application.
#
#
# - You can find the implementation template in the ```src``` directory of the project template.
#
#
# - For HW 1, Part C, you can copy your implementation code into this notebook and test again the cloud databases.
#
#
# - __I strongly suggest that you develop and test in PyCharm, and then copy your code into the notebook. The cells below just show you where to place your code. You should copy your code over from PyCharm.__

# %% [markdown]
# #### Implementation
#
# - ```BaseDataTable``` defines the common abstraction we will use. You do not need to do anything to this class.

# %%
# Import package to enable defining abstract classes in Python.
# Do not worry about understanding abstract base classes. This is just a class that defines
# some methods that subclasses must implement.
from abc import ABC, abstractmethod


class DataTableException(Exception):
    """
    A simple class that maps underlying implementation exceptions to generic exceptions.
    """

    invalid_method = 1001

    # General
    def __init__(self, code, message):
        self.code = code
        self.message = message

    def __str__(self):
        result = (
            type(self), {"code": self.code, "message": self.message}
        )
        result = str(result)
        return result


class BaseDataTable(ABC):
    """
    The implementation classes (XXXDataTable) for CSV database, relational, etc. will extend the
    base class and implement the abstract methods.
    """

    def __init__(self, entity_type_name, connect_info, key_columns=None, context=None):
        """

        :param entity_type_name: Name of the logcal entity type. This maps to various abstractions in
            underlying stores, e.g. file names, RDB tables, Neo4j Labels, ...
        :param connect_info: Dictionary of parameters necessary to connect to the data. See examples in subclasses.
        :param key_columns: List, in order, of the columns (fields) that comprise the primary key.
            A primary key is a set of columns whose values are unique and uniquely identify a row. For Appearances,
            the columns are ['playerID', 'teamID', 'yearID']
        :param contex: Holds context and environment information.
        """
        self._table_name = entity_type_name
        self._connect_info = connect_info
        self._key_columns = key_columns
        self._context = context

    @abstractmethod
    def find_by_primary_key(self, key_fields, field_list=None, context=None):
        """

        :param key_fields: The values for the key_columns, in order, to use to find a record. For example,
            for Appearances this could be ['willite01', 'BOS', '1960']
        :param field_list: A subset of the fields of the record to return. The CSV file or RDB table may have many
            additional columns, but the caller only requests this subset.
        :return: None, or a dictionary containing the columns/values for the row.
        """
        pass

    @abstractmethod
    def find_by_template(self, template, field_list=None, limit=None, offset=None, order_by=None, context=None):
        """

        :param template: A dictionary of the form { "field1" : value1, "field2": value2, ...}. The function will return
            a derived table containing the rows that match the template.
        :param field_list: A list of requested fields of the form, ['fielda', 'fieldb', ...]
        :param limit: Do not worry about this for now.
        :param offset: Do not worry about this for now.
        :param order_by: Do not worry about this for now.
        :return: A derived table containing the computed rows.
        """
        pass

    @abstractmethod
    def insert(self, new_entity, context=None):
        """

        :param new_record: A dictionary representing a row to add to the set of records. Raises an exception if this
            creates a duplicate primary key.
        :return: None
        """
        pass

    @abstractmethod
    def delete_by_template(self, template, context=None):
        """

        Deletes all records that match the template.

        :param template: A template.
        :return: A count of the rows deleted.
        """
        pass

    @abstractmethod
    def delete_by_key(self, key_fields, Context=None):
        """

        Delete record with corresponding key.

        :param key_fields: List containing the values for the key columns
        :return: A count of the rows deleted.
        """
        pass

    @abstractmethod
    def update_by_template(self, template, new_values, context=None):
        """

        :param template: A template that defines which matching rows to update.
        :param new_values: A dictionary containing fields and the values to set for the corresponding fields
            in the records. This returns an error if the update would create a duplicate primary key. NO ROWS are
            update on this error.
        :return: The number of rows updates.
        """
        pass

    @abstractmethod
    def update_by_key(self, key_fields, new_values, context=None):
        """

        :param key_fields: List of values for primary key fields
        :param new_values: A dictionary containing fields and the values to set for the corresponding fields
            in the records. This returns an error if the update would create a duplicate primary key. NO ROWS are
            update on this error.
        :return: The number of rows updates.
        """
        pass

    @abstractmethod
    def query(self, query_statement, args, context=None):
        """
        Passed through/executes a raw query in the native implementation language of the backend.
        :param query_statement: Query statement as a string.
        :param args: Args to insert into query if it is a template
        :param context:
        :return: A JSON object containing the result of the operation.
        """
        pass

    @abstractmethod
    def load(self, rows=None):
        """
        Loads data into the data table.
        :param rows:
        :return: Number of rows loaded.
        """

    @abstractmethod
    def save(self, context):
        """
        Writes any cached data to a backing store.
        :param context:
        :return:
        """

# %% [markdown]
# __RDBDataTable__
#
#
# - You only need to implement the following methods:
#     - ```__init__```
#     - ```__str__```
#     - ```find_by_template``` You only need to implement the parameters
#         - ```template```
#         - ```field_list```
#     - ```find_by_primary_key``` You only need to implement the parameters
#         - ```key_fields```
#         - ```field_list```
#
#
# - The logical behavior of the ```find_by_template``` API is the following:
#     - If you create an ```RDBDataTable``` instance for a SQL table ```GoTSolutionClean.scenes_characters,```
#     - The call<br>
# ```
#     characters_tbl.find_by_template(
#             template={
#                 'seasonNum': 1,
#                 'episodeNum': 2
#                 },
#             field_list = ['seasonNum', 'episodeNum', 'sceneNo', 'character_id']
#             )
# ```
#     - Is equivalent to
# ```
#     select seasonNum, episodeNum, sceneNo, character_id
#         from GoTSolutionClean.scenes_characters
#         where
#             seasonNum=1 and episodeNum=1
# ```
#     - And returns the same dictionary.

# %% [markdown]
# - The logical behavior of the ```find_by_primary_key``` API is the following:
#     - If you create an ```RDBDataTable``` instance for a SQL table ```GoTSolutionClean.episodes,```
#     - The primary key columns are ```seasonNum, episodeNum.```
#     - The invocation would be ```find_by_primary_key([1,3],field_list=['seasonNum','episodeNum','title'])```
#     - This would get converted into
# ```
# select seasonNum, episodeNum, title
#         from W4111GoTSolutionClean.episodes
#         where
#             seasonNum=1 and episodeNum=1
# ```
#     - Your class implementation MUST run a database query to determine the primary key columns and their order to form the ```where``` clause.
#     - The result is a single dictionary containing the query result.
#
#
# - We will provide tests.

# %%
from src.data_tables.BaseDataTable import BaseDataTable

import pandas as pd
import pymysql

import logging

logger = logging.getLogger()


class RDBDataTable(BaseDataTable):
    """
    RDBDataTable is relation DB implementation of the BaseDataTable.
    """

    # Default connection information in case the code does not pass an object
    # specific connection on object creation.
    _default_connect_info = pymysql.connect(
        host="columbia8013.cqgsme1nmjms.us-east-1.rds.amazonaws.com",
        user="gotuser",
        password="gotusergotuser",
        db="W4111GoTSolutionClean",
        cursorclass=pymysql.cursors.DictCursor)

    _default_cnx = None

    def _get_cnx(self):

        if self._cnx is None:
            if self._connect_info is None:
                c_info = RDBDataTable._default_connect_info
            else:
                c_info = self._connect_info

            self._cnx = pymysql.connect(
                host=c_info['host'],
                user=c_info['user'],
                password=c_info['password'],
                db=c_info['db'],
                charset='utf8mb4',
                cursorclass=pymysql.cursors.DictCursor)

        return self._cnx
    

    @classmethod
    def _get_default_cnx(cls):

        if RDBDataTable._default_cnx is None:
            # Create a connection to use inside this object. In general, this is not the right approach.
            # There would be a connection pool shared across many classes and applications.
            cls._default_cnx = pymysql.connect(
                host="columbia8013.cqgsme1nmjms.us-east-1.rds.amazonaws.com",
                user="gotuser",
                password="gotusergotuser",
                db="W4111GoTSolutionClean",
                cursorclass=pymysql.cursors.DictCursor)

            return cls._default_cnx

    def __init__(self, table_name, key_columns=None, connect_info=None):
        """

        :param table_name: The name of the RDB table.
        :param connect_info: Dictionary of parameters necessary to connect to the data.
        :param key_columns: List, in order, of the columns (fields) that comprise the primary key.
            This is for compatibility with other types of data table. Any value other than None is an error.
        """

        # If there is not explicit connect information, use the defaults.
        
        ####### Your Code Goes Here #########
        
        self._cnx = None
        self._connect_info = None
        
        if key_columns is not None:
            raise ValueError("This is an RDB Data Table. We figure out the keys by querying the DB.")
        
        if connect_info:
            self.conn = pymysql.connect(**connect_info)
            self._connect_info = connect_info
        else:
            self.conn = self._default_cnx
            self._connect_info = self._default_connect_info

        self._key_columns = key_columns
        self._table_name = table_name

        print("="*10, " connecting " + self._connect_info.__str__(), "="*10)

        
        ####### Your Code Goes Here #########
        
    def get_row_count(self):
        sql = "select count(*) as count from " + self._table_name
        res = self._run_q(sql, fetch = True)
        return res[0]["count"]
        
    def __str__(self):
        """

        :return: String representation of the table's metadata.
        """
        ####### Your Code Goes Here #########
        
        result = "RDBDataTable" + self._table_name
        result += "\n\tRow Count = " + str(self.get_row_count())
        result += "n\tColumns:"
        for c in self._columns:
            result +="n\t\t" + str(c)
        
        q = "select * from" + self._table_name + "limit" +str(BaseDataTable._rows_to_show)
        res = self._run_q(q)
        dt = pd.DaraFrame(res)
        result += "n\Some rows:\n"
        result += str(dt)
        return result
        
        ####### Your Code Goes Here #########


    @classmethod
    def _run_q(cls, q, args=None, fields=None, fetch=True, cnx=None, cursor=None, commit=True):
        """

        :param q: An SQL query string that may have %s slots for argument insertion. The string
            may also have {} after select for columns to choose.
        :param args: A tuple of values to insert in the %s slots.
        :param fetch: If true, return the result.
        :param cnx: A database connection. May be None
        :param cncursor: Do not worry about this for now.
        :param commit: Do not worry about this for now. This is more wizard stuff.
        :return: A result set or None.
        """

        r = None

        cursor_created = False

        if cnx is None:
            cnx = cls._get_default_cnx()

        try:
            # Use the connection in the object if no connection provided.


            # Convert the list of columns into the form "col1, col2, ..." for following SELECT.
            if fields:
                q = q.format(",".join(fields))

            if cursor is None:
                cursor = cnx.cursor()  # Just ignore this for now.
                cursor_created = True

            # If debugging is turned on, will print the query sent to the database.
            #self.debug_message("Query = ", cursor.mogrify(q, args))

            cursor.execute(q, args)  # Execute the query.

            # Technically, INSERT, UPDATE and DELETE do not return results.
            # Sometimes the connector libraries return the number of created/deleted rows.
            if fetch:
                r = cursor.fetchall()  # Return all elements of the result.
            else:
                r = None

            if commit:                  # Do not worry about this for now.
                cnx.commit()

            if cursor_created:
                cursor.close()

        except Exception as e:
            print("Exception e = ", e)
            if commit:
                cnx.rollback()
            if cursor_created:
                cursor.close()

        return r

    def _run_insert(self, table_name, column_list, values_list, cnx=None, commit=True):
        """

        :param table_name: Name of the table to insert data. Probably should just get from the object data.
        :param column_list: List of columns for insert.
        :param values_list: List of column values.
        :param cnx: Ignore this for now.
        :param commit: Ignore this for now.
        :return:
        """
        try:
            q = "insert into " + table_name + " "

            # If the column list is not None, form the (col1, col2, ...) part of the statement.
            if column_list is not None:
                q += "(" + ",".join(column_list) + ") "

            # We will use query parameters. For a term of the form values(%s, %s, ...) with one slot for
            # each value to insert.
            values = ["%s"] * len(values_list)

            # Form the values(%s, %s, ...) part of the statement.
            values = " ( " + ",".join(values) + ") "
            values = "values" + values

            # Put all together.
            q += values

            self._run_q(q, args=values_list, fields=None, fetch=False, cnx=cnx, commit=commit)

        except Exception as e:
            print("Got exception = ", e)
            raise e

    @classmethod
    def get_folders(cls):
        pass

    def find_by_primary_key(self, key_fields, field_list=None, context=None):
        """

        :param key_fields: The values for the key_columns, in order, to use to find a record.
        :param field_list: A subset of the fields of the record to return.
        :return: None, or a dictionary containing the request fields for the record identified
            by the key.
        """
        
        
        ####### Your Code Goes Here #########
        
        pkList = self.get_key_columns()
        if len(key_fields) != len(pkList):
            raise DataTableException(0,
                 "the length of key_fields is different from the number of primary keys\n\tpk: %s" % ", ".join(pkList)
             )
        sql = "SELECT " + ", ".join(field_list) + " FROM " + self._table_name
        sql += " WHERE " + " AND ".join([c + "=" + str(v)for c, v in zip(pkList, key_fields)])
        return self._run_q(sql)
    
        ####### Your Code Goes Here #########

    def _template_to_where_clause(self, t):
        """
        Convert a query template into a WHERE clause.
        :param t: Query template.
        :return: (WHERE clause, arg values for %s in clause)
        """
        w_clause=None
        args = None
        
        ####### Your Code Goes Here #########
        
        w_clause = ""
        args = []
        colNames = []

        for k, v in t.items():
            colNames.append(k + ' = %s')
            args.append(v)
            
        w_clause = 'WHERE ' + (' AND '.join(colNames))
        args = tuple(args)
        
        ####### Your Code Goes Here #########

        return w_clause, args

    def find_by_template(self, template, field_list=None, limit=None, offset=None, order_by=None, commit=True):
        """

        :param template: A dictionary of the form { "field1" : value1, "field2": value2, ...}
        :param field_list: A list of request fields of the form, ['fielda', 'fieldb', ...]
        :param limit: Do not worry about this for now.
        :param offset: Do not worry about this for now.
        :param order_by: Do not worry about this for now.
        :return: A list containing dictionaries. A dictionary is in the list representing each record
            that matches the template. The dictionary only contains the requested fields.
        """
        ####### Your Code Goes Here #########
        
        extractDict = " AND ".join([k + '=' + str(v) for k, v in template.items()])
        sql = "SELECT " + ", ".join(field_list) + " FROM " + self._table_name
        sql += " WHERE " + extractDict
        return self._run_q(sql)
        
        ####### Your Code Goes Here #########



    def insert(self, new_record):
        """

        :param new_record: A dictionary representing a row to add to the set of records.
        :return: None
        """
        pass

    def delete_by_template(self, template):
        """

        Deletes all records that match the template.

        :param template: A template.
        :return: A count of the rows deleted.
        """
        pass

    def delete_by_key(self, key_fields):
        """

        Delete record with corresponding key.

        :param key_fields: List containing the values for the key columns
        :return: A count of the rows deleted.
        """
        pass

    def update_by_template(self, template, new_values):
        """

        :param template: A template that defines which matching rows to update.
        :param new_values: A dictionary containing fields and the values to set for the corresponding fields
            in the records. This returns an error if the update would create a duplicate primary key. NO ROWS are
            update on this error.
        :return: The number of rows updates.
        """
        pass

    def update_by_key(self, key_fields, new_values):
        """

        :param key_fields: List of values for primary key fields
        :param new_values: A dictionary containing fields and the values to set for the corresponding fields
            in the records. This returns an error if the update would create a duplicate primary key. NO ROWS are
            update on this error.
        :return: The number of rows updates.
        """
        pass

    def load(self):
        pass

    def save(self):
        pass

    def query(self, query_statement, args, context=None):
        pass

# %%
from src.data_tables.BaseDataTable import BaseDataTable, DataTableException

import pandas as pd
import pymysql

import logging

logger = logging.getLogger()


class RDBDataTable(BaseDataTable):
    """
    RDBDataTable is relation DB implementation of the BaseDataTable.
    """

    # Default connection information in case the code does not pass an object
    # specific connection on object creation.
    _default_connect_info = {
        'host': "columbia8013.cqgsme1nmjms.us-east-1.rds.amazonaws.com",
        'user': "gotuser",
        'password': "gotusergotuser",
        'db': "W4111GoTSolutionClean",
        'cursorclass': pymysql.cursors.DictCursor
    }

    _default_cnx = None
    
    def _get_cnx(self):

        if self._cnx is None:
            if self._connect_info is None:
                c_info = RDBDataTable._default_connect_info
            else:
                c_info = self._connect_info

            self._cnx = pymysql.connect(
                host=c_info['host'],
                user=c_info['user'],
                password=c_info['password'],
                db=c_info['db'],
                charset='utf8mb4',
                cursorclass=pymysql.cursors.DictCursor)

        return self._cnx

    def __init__(self, table_name, key_columns=None, connect_info=None):
        """

        :param table_name: The name of the RDB table.
        :param connect_info: Dictionary of parameters necessary to connect to the data.
        :param key_columns: List, in order, of the columns (fields) that comprise the primary key.
            This is for compatibility with other types of data table. Any value other than None is an error.
        """

        # If there is not explicit connect information, use the defaults.
        self._cnx = None
        self._connect_info = None

        if key_columns is not None:
            raise ValueError("This is an RDB Data Table. We figure out the keys by querying the DB.")

        ####### Your Code Goes Here #########
        
        if connect_info:
            self.conn = pymysql.connect(**connect_info)
            self._connect_info = connect_info
        else:
            self.conn = self._default_cnx
            self._connect_info = self._default_connect_info

        self._key_columns = key_columns
        self._table_name = table_name

        print("="*10, " connecting " + self._connect_info.__str__(), "="*10)


        ####### Your Code Goes Here #########


    def get_row_count(self):
        sql = "SELECT COUNT(*) AS count FROM %s" % self._table_name
        res = self._run_q(sql, fetch=True)
        return res[0]['count']


    def __str__(self):
        """

        :return: String representation of the table's metadata.
        """
        ####### Your Code Goes Here #########
        result = "RDBTable %s \n\tRow Count: %s" % (self._table_name, str(self.get_row_count()))
        return result

        ####### Your Code Goes Here #########

    def _run_q(self, q, args=None, fields=None, fetch=True, cnx=None, cursor=None, commit=True):
        """

        :param q: An SQL query string that may have %s slots for argument insertion. The string
            may also have {} after select for columns to choose.
        :param args: A tuple of values to insert in the %s slots.
        :param fetch: If true, return the result.
        :param cnx: A database connection. May be None
        :param cncursor: Do not worry about this for now.
        :param commit: Do not worry about this for now. This is more wizard stuff.
        :return: A result set or None.
        """

        r = None

        cursor_created = False

        if cnx is None:
            cnx = self._get_cnx()

        try:
            # Use the connection in the object if no connection provided.

            # Convert the list of columns into the form "col1, col2, ..." for following SELECT.
            if fields:
                q = q.format(",".join(fields))
            else:
                q = q.format('*')

            if cursor is None:
                cursor = cnx.cursor()  # Just ignore this for now.
                cursor_created = True

            # If debugging is turned on, will print the query sent to the database.
            #self.debug_message("Query = ", cursor.mogrify(q, args))

            cursor.execute(q, args)  # Execute the query.

            # Technically, INSERT, UPDATE and DELETE do not return results.
            # Sometimes the connector libraries return the number of created/deleted rows.
            if fetch:
                r = cursor.fetchall()  # Return all elements of the result.
            else:
                r = None

            if commit:                  # Do not worry about this for now.
                cnx.commit()

            if cursor_created:
                cursor.close()

        except Exception as e:
            print("Exception e = ", e)
            if commit:
                cnx.rollback()
            if cursor_created:
                cursor.close()

        return r

    def _run_insert(self, table_name, column_list, values_list, cnx=None, commit=True):
        """

        :param table_name: Name of the table to insert data. Probably should just get from the object data.
        :param column_list: List of columns for insert.
        :param values_list: List of column values.
        :param cnx: Ignore this for now.
        :param commit: Ignore this for now.
        :return:
        """
        try:
            q = "insert into " + table_name + " "

            # If the column list is not None, form the (col1, col2, ...) part of the statement.
            if column_list is not None:
                q += "(" + ",".join(column_list) + ") "

            # We will use query parameters. For a term of the form values(%s, %s, ...) with one slot for
            # each value to insert.
            values = ["%s"] * len(values_list)

            # Form the values(%s, %s, ...) part of the statement.
            values = " ( " + ",".join(values) + ") "
            values = "values" + values

            # Put all together.
            q += values

            self._run_q(q, args=values_list, fields=None, fetch=False, cnx=cnx, commit=commit)

        except Exception as e:
            print("Got exception = ", e)
            raise e

    def get_folders(self):
        pass

    def get_key_columns(self):
        sql = "SHOW INDEX FROM %s WHERE Key_name = 'PRIMARY';" % self._table_name
        pkList = self._run_q(sql)
        pkList = sorted([(p['Seq_in_index'], p['Column_name']) for p in pkList], key=lambda x: x[0])
        pkList = [i[1] for i in pkList]
        return pkList

    def find_by_primary_key(self, key_fields, field_list=None, context=None):
        """

        :param key_fields: The values for the key_columns, in order, to use to find a record.
        :param field_list: A subset of the fields of the record to return.
        :return: None, or a dictionary containing the request fields for the record identified
            by the key.
        """
        ####### Your Code Goes Here #########
     
        pkList = self.get_key_columns()
        if len(key_fields) != len(pkList):
            raise DataTableException(0,
                 "the length of key_fields is different from the number of primary keys\n\tpk: %s" % ", ".join(pkList)
             )
        sql = "SELECT " + ", ".join(field_list) + " FROM " + self._table_name
        sql += " WHERE " + " AND ".join([c + "=" + str(v)for c, v in zip(pkList, key_fields)])
        return self._run_q(sql)

        ####### Your Code Goes Here #########

    def _template_to_where_clause(self, t):
        """
        Convert a query template into a WHERE clause.
        :param t: Query template.
        :return: (WHERE clause, arg values for %s in clause)
        """
        ####### Your Code Goes Here #########

        if t is None or t == {}:
            result = (None, None)
        else:
            args = []
            terms = []

            for k, v in t.items():
                terms.append(" " + k + "=%s ")
                args.append(v)

            w_clause = "AND".join(terms)
            w_clause = " WHERE " + w_clause

            result = (w_clause, args)

        return result

        ####### Your Code Goes Here #########

        return w_clause, args
    
    def get_folders(self):
        pass

    def find_by_template(self, template, field_list=None, limit=None, offset=None, order_by=None, commit=True,
                         context=None):
        """

        :param template: A dictionary of the form { "field1" : value1, "field2": value2, ...}
        :param field_list: A list of request fields of the form, ['fielda', 'fieldb', ...]
        :param limit: Do not worry about this for now.
        :param offset: Do not worry about this for now.
        :param order_by: Do not worry about this for now.
        :return: A list containing dictionaries. A dictionary is in the list representing each record
            that matches the template. The dictionary only contains the requested fields.
        """
        ####### Your Code Goes Here #########
        
        q = "select {} from" + self._table_name
        w_clause, args = self._template_to_where_clause(template)
        q += " "+ w_clause
        
        result = self._run_q(q,args,field_list,fetch=True)
        return result
    
        ####### Your Code Goes Here #########

    def insert(self, new_record, context=None):
        """

        :param new_record: A dictionary representing a row to add to the set of records.
        :return: None
        """
        pass

    def delete_by_template(self, template, context=None):
        """

        Deletes all records that match the template.

        :param template: A template.
        :return: A count of the rows deleted.
        """
        pass

    def delete_by_key(self, key_fields, context=None):
        """

        Delete record with corresponding key.

        :param key_fields: List containing the values for the key columns
        :return: A count of the rows deleted.
        """
        pass

    def update_by_template(self, template, new_values, context=None):
        """

        :param template: A template that defines which matching rows to update.
        :param new_values: A dictionary containing fields and the values to set for the corresponding fields
            in the records. This returns an error if the update would create a duplicate primary key. NO ROWS are
            update on this error.
        :return: The number of rows updates.
        """
        pass

    def update_by_key(self, key_fields, new_values, context=None):
        """

        :param key_fields: List of values for primary key fields
        :param new_values: A dictionary containing fields and the values to set for the corresponding fields
            in the records. This returns an error if the update would create a duplicate primary key. NO ROWS are
            update on this error.
        :return: The number of rows updates.
        """
        pass

    def load(self, rows=None):
        pass

    def save(self, context=None):
        pass

    def query(self, query_statement, args, context=None):
        pass

# %% [markdown]
# __Tests__
#
# Test your code below.

# %%
import json
import pymysql


connect_info = {
    'host': '127.0.0.1',
    'user': 'dbuser',
    'password': 'dbuserdbuser',
    'db': 'W4111GoTSolutionClean',
    'charset': 'utf8mb4',
    'cursorclass': pymysql.cursors.DictCursor
}

def t1():

    print("\n************** t1 **************\n")

    tbl = RDBDataTable("W4111GoTSolutionClean.episdes", connect_info=connect_info)
    print("Table = ", tbl)
    print("\n")
    tbl = RDBDataTable("W4111GoTSolutionClean.episodes")
    print("Table = ", tbl)

    print("\n************** t1 **************\n")

    
    
def t2():

    print("\n************** t2 **************\n")

    tbl = RDBDataTable("W4111GoTSolutionClean.episodes")

    res = tbl.find_by_template(
        {"seasonNum": 1},
        field_list=['seasonNum', 'episodeNum', 'episodeTitle']
    )

    print("Answer = ")
    print(json.dumps(res, indent=2, default=str))

    print("\n************** t2 **************\n")


def t3():


    print("\n************** t3 **************\n")

    tbl = RDBDataTable("W4111GoTSolutionClean.scenes")

    res = tbl.find_by_primary_key([3,1, 11],
        field_list=['seasonNum', 'episodeNum', 'sceneNo', "location", "subLocation"]
    )

    print("Answer = \n")
    print(json.dumps(res, indent=2, default=str))


    print("\n************** t3 **************\n")


def t5():

    print("\n************** t5 **************\n")

    tbl = RDBDataTable("W4111GoTSolutionClean.scenes")

    k = tbl.get_key_columns()
    print("Key columns = ", k)

    print("\n************** t5 **************\n")

# %%
t1()
# Out:
# ************** t1 **************
#
# ==========  connecting {'host': '127.0.0.1', 'user': 'dbuser', 'password': 'dbuserdbuser', 'db': 'W4111GoTSolutionClean', 'charset': 'utf8mb4', 'cursorclass': <class 'pymysql.cursors.DictCursor'>} ==========
# Table =  RDBTable W4111GoTSolutionClean.episdes
# 	Row Count: 73
#
#
# ==========  connecting {'host': 'columbia8013.cqgsme1nmjms.us-east-1.rds.amazonaws.com', 'user': 'gotuser', 'password': 'gotusergotuser', 'db': 'W4111GoTSolutionClean', 'cursorclass': <class 'pymysql.cursors.DictCursor'>} ==========
# Table =  RDBTable W4111GoTSolutionClean.episodes
# 	Row Count: 73
#
# ************** t1 **************

# %%
t2()
# Out:
# ************** t2 **************
#
# ==========  connecting {'host': 'columbia8013.cqgsme1nmjms.us-east-1.rds.amazonaws.com', 'user': 'gotuser', 'password': 'gotusergotuser', 'db': 'W4111GoTSolutionClean', 'cursorclass': <class 'pymysql.cursors.DictCursor'>} ==========
# Exception e =  (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near '.episodes  WHERE  seasonNum=1' at line 1")
# Answer =
# null
#
# ************** t2 **************

# %%
t3()
# Out:
# ************** t3 **************
#
# ==========  connecting {'host': 'columbia8013.cqgsme1nmjms.us-east-1.rds.amazonaws.com', 'user': 'gotuser', 'password': 'gotusergotuser', 'db': 'W4111GoTSolutionClean', 'cursorclass': <class 'pymysql.cursors.DictCursor'>} ==========
# Answer =
#
# [
#   {
#     "seasonNum": 3,
#     "episodeNum": 1,
#     "sceneNo": 11,
#     "location": "North of the Wall",
#     "subLocation": "Frostfang Mountains"
#   }
# ]
#
# ************** t3 **************

# %%
t5()
# Out:
# ************** t5 **************
#
# ==========  connecting {'host': 'columbia8013.cqgsme1nmjms.us-east-1.rds.amazonaws.com', 'user': 'gotuser', 'password': 'gotusergotuser', 'db': 'W4111GoTSolutionClean', 'cursorclass': <class 'pymysql.cursors.DictCursor'>} ==========
# Key columns =  ['seasonNum', 'episodeNum', 'sceneNo']
#
# ************** t5 **************
